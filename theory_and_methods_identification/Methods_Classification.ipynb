# %% [markdown]
# # Theory Framework Classification Using Section Classifier Framework
#
# This notebook demonstrates the use of the new section classifier framework for analyzing theoretical frameworks in physics education research articles.

# %% [markdown]
# ## Initial Setup

# %%
import pandas as pd
import json

from LLM_classifier import (
    load_categories_from_json,
    save_categories_to_json,
    create_timestamped_path,
    CostEstimationWrapper,
    Section
)
from methods_classifiers import MethodsSectionClassifier

import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from python_code import helpers


from IPython.display import Markdown # type: ignore

# %%
api_key = helpers.safe_load_env_variable("OPENAI_API_KEY", "../.env.secret")
# Initialize the classifier with loaded frameworks
classifier = MethodsSectionClassifier(
    api_key = api_key,
    temperature=0.6,
    max_tokens=15000,
    general_model="gpt-4.1-mini",
    reasoning_model="o3-mini"
)

# %% [markdown]
# ## Data loading

# %%
# Load the data
df = pd.read_pickle("../section_type_classification/data/classified_sections_light_gpt-4.1-mini_20250716_122412.pkl")

# Load existing theory categories
methods = load_categories_from_json("./methods_data/initial_categories_20250807_104053.json")
# Out:
# Successfully loaded 25 categories from ./methods_data/initial_categories_20250807_104053.json

# %% [markdown]
# ## Filter Research Methods Sections

# %%
# Helper function to filter DataFrame by category
def filter_df_by_category(
    df,
    value: str,
    column: str = "classification_highest_prob_gpt-4.1-mini"
):
    """
    Returns a DataFrame filtered to only rows where the specified column matches the given value.
    """
    mask = df[column] == value
    return df[mask].copy()

# Filter for theoretical framework sections
methods_df = filter_df_by_category(df, "Methods")
print(f"Found {len(methods_df)} methods sections")
# Out:
# Found 1541 methods sections

# %% [markdown]
# ## Discover Methods

# %%
def to_string(section: Section):
    return f"""Section title: {section.title}
Content: {section.text}"""

sections = classifier._df_to_sections(methods_df)

preped_data = [to_string(el) for el in sections]

discovered_categories = classifier.discover_categories(preped_data[400:])

print(f"Discovered {len(discovered_categories)} categories!")
# Out:
# Category discovery using model: gpt-4.1-mini
# Input tokens used: 105256
# Output tokens used: 261
# Discovered 51 categories!

# %%
review_result = classifier.review_and_clean_categories(discovered_categories)
reviewed_disc_categories = review_result.cleaned_categories
# Out:
# Category review using model: o3-mini
# Reviewing 51 categories
# Input tokens used: 1811
# Output tokens used: 4842
# Review summary:
#   - Original categories: 51
#   - Cleaned categories: 25
#   - Removed categories: 15
#   - Merge suggestions: 5
#   - Removed: Recording System Requirements, Technology for Educational Recording, System Setup for Recording, Component Layout for Recording Systems, Hardware Considerations for Recording, Instructional Conceptions and Practices Framework, Data Collection and Analysis, Modeling and Theoretical Frameworks, Data Analysis Methods, Educational Context, Assessment Instruments, Curriculum and Instructional Materials, Validation and Reliability Measures, Participant Demographics, Research Questions and Objectives
#   - Suggested merges: Survey Methodology in Physics Education, Experimental Design in Physics Education, Qualitative Interview Methodology in Physics Education, Instructional Study Methods in Physics Education, Data Collection Methods in Physics Education

# %%
save_categories_to_json(reviewed_disc_categories, "methods_data/initial_categories.json")
# Out:
# Categories saved to methods_data/initial_categories_20250807_104053.json

# %%
# methods = reviewed_disc_categories

# %% [markdown]
# ## Batch Classify Sections

# %% [markdown]
# #### Estimate costs

# %%
cost_estimator = CostEstimationWrapper(classifier)

data = classifier._df_to_sections(methods_df)

est = cost_estimator.estimate_full_workflow(data, methods)

display(Markdown(cost_estimator.generate_cost_report(est)))
# Out:
# # Cost Estimation Report
# Generated: 2025-08-06 00:21:54
#
# ## Category Review
#
# - **Cost**: $0.0029
# - **Model**: o3-mini
# - **Input Tokens**: 6,589
# - **Output Tokens**: 3,170
#
# ## Batch Classification
#
# - **Total Cost**: $1.3243
# - **Items Processed**: 589
# - **Average Cost per Item**: $0.0022
# - **Total Input Tokens**: 5,108,903
# - **Total Output Tokens**: 47,120
#
# ## Summary
#
# - **Total Estimated Cost**: $1.3272
# - **Total Input Tokens**: 5,115,492
# - **Total Output Tokens**: 50,290
#
# *Note: These are estimates based on current pricing and may vary.*

# %% [markdown]
# #### Do the actual classification

# %% [markdown]
# Run the classification. the `category_creation_temperature` parampeter decides how aggressive the model is in creating new categories.

# %%
# Run batch classification
result_df, updated_categories, errors = classifier.batch_classify_sections_df(methods_df, methods, category_creation_temperature="balanced")
# Out:
# Processing element 1/1541
# Input tokens used: 2517
# Output tokens used: 566
# Processing element 2/1541
# Input tokens used: 2183
# Output tokens used: 486
# Processing element 3/1541
# Input tokens used: 3073
# Output tokens used: 362
# Processing element 4/1541
# Input tokens used: 2630
# Output tokens used: 483
# Processing element 5/1541
# Input tokens used: 2706
# Output tokens used: 376
# Processing element 6/1541
# Input tokens used: 2058
# Output tokens used: 282
# Processing element 7/1541
# Input tokens used: 2235
# Output tokens used: 282
# Processing element 8/1541
# Input tokens used: 2404
# Output tokens used: 249
# Processing element 9/1541
# Input tokens used: 2180
# Output tokens used: 93
# Processing element 10/1541
# Input tokens used: 4508
# Output tokens used: 169
# Processing element 11/1541
# Input tokens used: 2042
# Output tokens used: 337
# Processing element 12/1541
# Input tokens used: 2506
# Output tokens used: 401
# Processing element 13/1541
# Input tokens used: 1692
# Output tokens used: 256
# Processing element 14/1541
# Input tokens used: 7585
# Output tokens used: 606
# Processing element 15/1541
# Input tokens used: 2720
# Output tokens used: 404
# Processing element 16/1541
# Input tokens used: 3618
# Output tokens used: 373
# Processing element 17/1541
# Input tokens used: 5946
# Output tokens used: 752
# Processing element 18/1541
# Input tokens used: 2413
# Output tokens used: 320
# Processing element 19/1541
# Input tokens used: 6331
# Output tokens used: 468
# Processing element 20/1541
# Input tokens used: 2090
# Output tokens used: 406
# Processing element 21/1541
# Input tokens used: 1637
# Output tokens used: 275
# Processing element 22/1541
# Input tokens used: 3857
# Output tokens used: 385
# Processing element 23/1541
# Input tokens used: 3287
# Output tokens used: 278
# Processing element 24/1541
# Input tokens used: 2859
# Output tokens used: 593
# Processing element 25/1541
# Input tokens used: 3286
# Output tokens used: 349
# Processing element 26/1541
# Input tokens used: 8376
# Output tokens used: 493
# Processing element 27/1541
# Input tokens used: 2256
# Output tokens used: 239
# Processing element 28/1541
# Input tokens used: 3109
# Output tokens used: 353
# Processing element 29/1541
# Input tokens used: 1964
# Output tokens used: 356
# Processing element 30/1541
# Input tokens used: 9921
# Output tokens used: 340
# Processing element 31/1541
# Input tokens used: 1680
# Output tokens used: 274
# Processing element 32/1541
# Input tokens used: 1988
# Output tokens used: 318
# Processing element 33/1541
# Input tokens used: 1908
# Output tokens used: 146
# Processing element 34/1541
# Input tokens used: 1499
# Output tokens used: 349
# Processing element 35/1541
# Input tokens used: 3447
# Output tokens used: 338
# Processing element 36/1541
# Input tokens used: 2466
# Output tokens used: 459
# Processing element 37/1541
# Input tokens used: 3282
# Output tokens used: 565
# Processing element 38/1541
# Input tokens used: 3010
# Output tokens used: 420
# Processing element 39/1541
# Input tokens used: 2462
# Output tokens used: 328
# Processing element 40/1541
# Input tokens used: 3123
# Output tokens used: 566
# Processing element 41/1541
# Input tokens used: 2897
# Output tokens used: 295
# Processing element 42/1541
# Input tokens used: 3098
# Output tokens used: 676
# Processing element 43/1541
# Input tokens used: 1583
# Output tokens used: 196
# Processing element 44/1541
# Input tokens used: 7090
# Output tokens used: 417
# Processing element 45/1541
# Input tokens used: 6959
# Output tokens used: 450
# Processing element 46/1541
# Input tokens used: 4834
# Output tokens used: 306
# Processing element 47/1541
# Input tokens used: 2748
# Output tokens used: 355
# Processing element 48/1541
# Input tokens used: 1646
# Output tokens used: 329
# Processing element 49/1541
# Input tokens used: 4245
# Output tokens used: 360
# Processing element 50/1541
# Input tokens used: 2232
# Output tokens used: 439
# Processing element 51/1541
# Input tokens used: 2503
# Output tokens used: 346
# Processing element 52/1541
# Input tokens used: 2025
# Output tokens used: 403
# Processing element 53/1541
# Input tokens used: 4129
# Output tokens used: 415
# Processing element 54/1541
# Input tokens used: 3802
# Output tokens used: 339
# Processing element 55/1541
# Input tokens used: 5868
# Output tokens used: 371
# Processing element 56/1541
# Input tokens used: 3123
# Output tokens used: 319
# Processing element 57/1541
# Input tokens used: 1786
# Output tokens used: 257
# Processing element 58/1541
# Input tokens used: 1710
# Output tokens used: 278
# Processing element 59/1541
# Input tokens used: 1584
# Output tokens used: 350
# Processing element 60/1541
# Input tokens used: 2927
# Output tokens used: 285
# Processing element 61/1541
# Input tokens used: 3804
# Output tokens used: 344
# Processing element 62/1541
# Input tokens used: 2326
# Output tokens used: 310
# Processing element 63/1541
# Input tokens used: 2273
# Output tokens used: 463
# Processing element 64/1541
# Input tokens used: 1644
# Output tokens used: 279
# Processing element 65/1541
# Input tokens used: 1783
# Output tokens used: 275
# Processing element 66/1541
# Input tokens used: 2367
# Output tokens used: 487
# Processing element 67/1541
# Input tokens used: 1991
# Output tokens used: 348
# Processing element 68/1541
# Input tokens used: 1716
# Output tokens used: 1001
# Processing element 69/1541
# Input tokens used: 1325
# Output tokens used: 191
# Processing element 70/1541
# Input tokens used: 2116
# Output tokens used: 287
# Processing element 71/1541
# Input tokens used: 3251
# Output tokens used: 393
# Processing element 72/1541
# Input tokens used: 2970
# Output tokens used: 515
# Processing element 73/1541
# Input tokens used: 2586
# Output tokens used: 384
# Processing element 74/1541
# Input tokens used: 2205
# Output tokens used: 307
# Processing element 75/1541
# Input tokens used: 1438
# Output tokens used: 212
# Processing element 76/1541
# Input tokens used: 1822
# Output tokens used: 322
# Processing element 77/1541
# Input tokens used: 1509
# Output tokens used: 353
# Processing element 78/1541
# Input tokens used: 5938
# Output tokens used: 303
# Processing element 79/1541
# Input tokens used: 3413
# Output tokens used: 318
# Processing element 80/1541
# Input tokens used: 2457
# Output tokens used: 442
# Processing element 81/1541
# Input tokens used: 2105
# Output tokens used: 211
# Processing element 82/1541
# Input tokens used: 3220
# Output tokens used: 470
# Processing element 83/1541
# Input tokens used: 2574
# Output tokens used: 312
# Processing element 84/1541
# Input tokens used: 5751
# Output tokens used: 509
# Processing element 85/1541
# Input tokens used: 7671
# Output tokens used: 187
# Processing element 86/1541
# Input tokens used: 3250
# Output tokens used: 292
# Processing element 87/1541
# Input tokens used: 2575
# Output tokens used: 399
# Processing element 88/1541
# Input tokens used: 3330
# Output tokens used: 722
# Processing element 89/1541
# Input tokens used: 2208
# Output tokens used: 435
# Processing element 90/1541
# Input tokens used: 1931
# Output tokens used: 450
# Processing element 91/1541
# Input tokens used: 2180
# Output tokens used: 299
# Processing element 92/1541
# Input tokens used: 2268
# Output tokens used: 307
# Processing element 93/1541
# Input tokens used: 5119
# Output tokens used: 323
# Processing element 94/1541
# Input tokens used: 1709
# Output tokens used: 323
# Processing element 95/1541
# Input tokens used: 5987
# Output tokens used: 499
# Processing element 96/1541
# Input tokens used: 1841
# Output tokens used: 359
# Processing element 97/1541
# Input tokens used: 9677
# Output tokens used: 723
# Processing element 98/1541
# Input tokens used: 1713
# Output tokens used: 364
# Processing element 99/1541
# Input tokens used: 5358
# Output tokens used: 478
# Processing element 100/1541
# Input tokens used: 1670
# Output tokens used: 441
# Processing element 101/1541
# Input tokens used: 2012
# Output tokens used: 464
# Processing element 102/1541
# Input tokens used: 2473
# Output tokens used: 272
# Processing element 103/1541
# Input tokens used: 2928
# Output tokens used: 211
# Processing element 104/1541
# Input tokens used: 2395
# Output tokens used: 342
# Processing element 105/1541
# Input tokens used: 2319
# Output tokens used: 440
# Processing element 106/1541
# Input tokens used: 2099
# Output tokens used: 369
# Processing element 107/1541
# Input tokens used: 8008
# Output tokens used: 214
# Processing element 108/1541
# Input tokens used: 1648
# Output tokens used: 297
# Processing element 109/1541
# Input tokens used: 7844
# Output tokens used: 504
# Processing element 110/1541
# Input tokens used: 2365
# Output tokens used: 426
# Processing element 111/1541
# Input tokens used: 8406
# Output tokens used: 362
# Processing element 112/1541
# Input tokens used: 2523
# Output tokens used: 406
# Processing element 113/1541
# Input tokens used: 2528
# Output tokens used: 321
# Processing element 114/1541
# Input tokens used: 2527
# Output tokens used: 299
# Processing element 115/1541
# Input tokens used: 2363
# Output tokens used: 294
# Processing element 116/1541
# Input tokens used: 1783
# Output tokens used: 302
# Processing element 117/1541
# Input tokens used: 2141
# Output tokens used: 361
# Processing element 118/1541
# Input tokens used: 1973
# Output tokens used: 301
# Processing element 119/1541
# Input tokens used: 3038
# Output tokens used: 321
# Processing element 120/1541
# Input tokens used: 2207
# Output tokens used: 449
# Processing element 121/1541
# Input tokens used: 4240
# Output tokens used: 468
# Processing element 122/1541
# Input tokens used: 1926
# Output tokens used: 367
# Processing element 123/1541
# Input tokens used: 2796
# Output tokens used: 350
# Processing element 124/1541
# Input tokens used: 2566
# Output tokens used: 453
# Processing element 125/1541
# Input tokens used: 2045
# Output tokens used: 362
# Processing element 126/1541
# Input tokens used: 5795
# Output tokens used: 360
# Processing element 127/1541
# Input tokens used: 2337
# Output tokens used: 329
# Processing element 128/1541
# Input tokens used: 4406
# Output tokens used: 425
# Processing element 129/1541
# Input tokens used: 1804
# Output tokens used: 487
# Processing element 130/1541
# Input tokens used: 2908
# Output tokens used: 430
# Processing element 131/1541
# Input tokens used: 3638
# Output tokens used: 528
# Processing element 132/1541
# Input tokens used: 1450
# Output tokens used: 235
# Processing element 133/1541
# Input tokens used: 1929
# Output tokens used: 334
# Processing element 134/1541
# Input tokens used: 2578
# Output tokens used: 230
# Processing element 135/1541
# Input tokens used: 2532
# Output tokens used: 417
# Processing element 136/1541
# Input tokens used: 2317
# Output tokens used: 346
# Processing element 137/1541
# Input tokens used: 3186
# Output tokens used: 433
# Processing element 138/1541
# Input tokens used: 3694
# Output tokens used: 347
# Processing element 139/1541
# Input tokens used: 2165
# Output tokens used: 338
# Processing element 140/1541
# Input tokens used: 6797
# Output tokens used: 288
# Processing element 141/1541
# Input tokens used: 9340
# Output tokens used: 337
# Processing element 142/1541
# Input tokens used: 3894
# Output tokens used: 319
# Processing element 143/1541
# Input tokens used: 2709
# Output tokens used: 345
# Processing element 144/1541
# Input tokens used: 4885
# Output tokens used: 464
# Processing element 145/1541
# Input tokens used: 3856
# Output tokens used: 668
# Processing element 146/1541
# Input tokens used: 2436
# Output tokens used: 422
# Processing element 147/1541
# Input tokens used: 1832
# Output tokens used: 198
# Processing element 148/1541
# Input tokens used: 2056
# Output tokens used: 287
# Processing element 149/1541
# Input tokens used: 1476
# Output tokens used: 245
# Processing element 150/1541
# Input tokens used: 2448
# Output tokens used: 481
# Processing element 151/1541
# Input tokens used: 2486
# Output tokens used: 312
# Processing element 152/1541
# Input tokens used: 5050
# Output tokens used: 333
# Processing element 153/1541
# Input tokens used: 2793
# Output tokens used: 195
# Processing element 154/1541
# Input tokens used: 1882
# Output tokens used: 435
# Processing element 155/1541
# Input tokens used: 2157
# Output tokens used: 266
# Processing element 156/1541
# Input tokens used: 2851
# Output tokens used: 268
# Processing element 157/1541
# Input tokens used: 3778
# Output tokens used: 370
# Processing element 158/1541
# Input tokens used: 3744
# Output tokens used: 487
# Processing element 159/1541
# Input tokens used: 1978
# Output tokens used: 384
# Processing element 160/1541
# Input tokens used: 4303
# Output tokens used: 977
# Processing element 161/1541
# Input tokens used: 2512
# Output tokens used: 348
# Processing element 162/1541
# Input tokens used: 1581
# Output tokens used: 186
# Processing element 163/1541
# Input tokens used: 1760
# Output tokens used: 317
# Processing element 164/1541
# Input tokens used: 2911
# Output tokens used: 459
# Processing element 165/1541
# Input tokens used: 3104
# Output tokens used: 252
# Processing element 166/1541
# Input tokens used: 2275
# Output tokens used: 303
# Processing element 167/1541
# Input tokens used: 2382
# Output tokens used: 196
# Processing element 168/1541
# Input tokens used: 2317
# Output tokens used: 336
# Processing element 169/1541
# Input tokens used: 3637
# Output tokens used: 372
# Processing element 170/1541
# Input tokens used: 6329
# Output tokens used: 540
# Processing element 171/1541
# Input tokens used: 2698
# Output tokens used: 404
# Processing element 172/1541
# Input tokens used: 4547
# Output tokens used: 397
# Processing element 173/1541
# Input tokens used: 3125
# Output tokens used: 403
# Processing element 174/1541
# Input tokens used: 1915
# Output tokens used: 666
# Processing element 175/1541
# Input tokens used: 4134
# Output tokens used: 463
# Processing element 176/1541
# Input tokens used: 2937
# Output tokens used: 480
# Processing element 177/1541
# Input tokens used: 3603
# Output tokens used: 408
# Processing element 178/1541
# Input tokens used: 2003
# Output tokens used: 366
# Processing element 179/1541
# Input tokens used: 4283
# Output tokens used: 304
# Processing element 180/1541
# Input tokens used: 3503
# Output tokens used: 396
# Processing element 181/1541
# Input tokens used: 1648
# Output tokens used: 145
# Processing element 182/1541
# Input tokens used: 3748
# Output tokens used: 427
# Processing element 183/1541
# Input tokens used: 4062
# Output tokens used: 419
# Processing element 184/1541
# Input tokens used: 2750
# Output tokens used: 421
# Processing element 185/1541
# Input tokens used: 2300
# Output tokens used: 347
# Processing element 186/1541
# Input tokens used: 5824
# Output tokens used: 346
# Processing element 187/1541
# Input tokens used: 2254
# Output tokens used: 288
# Processing element 188/1541
# Input tokens used: 2361
# Output tokens used: 395
# Processing element 189/1541
# Input tokens used: 2713
# Output tokens used: 326
# Processing element 190/1541
# Input tokens used: 2962
# Output tokens used: 386
# Processing element 191/1541
# Input tokens used: 3527
# Output tokens used: 436
# Processing element 192/1541
# Input tokens used: 2218
# Output tokens used: 326
# Processing element 193/1541
# Input tokens used: 5156
# Output tokens used: 356
# Processing element 194/1541
# Input tokens used: 4044
# Output tokens used: 449
# Processing element 195/1541
# Input tokens used: 6991
# Output tokens used: 309
# Processing element 196/1541
# Input tokens used: 1954
# Output tokens used: 322
# Processing element 197/1541
# Input tokens used: 1830
# Output tokens used: 315
# Processing element 198/1541
# Input tokens used: 6215
# Output tokens used: 369
# Processing element 199/1541
# Input tokens used: 2816
# Output tokens used: 766
# Processing element 200/1541
# Input tokens used: 1714
# Output tokens used: 315
# Processing element 201/1541
# Input tokens used: 4266
# Output tokens used: 500
# Processing element 202/1541
# Input tokens used: 4906
# Output tokens used: 255
# Processing element 203/1541
# Input tokens used: 3988
# Output tokens used: 307
# Processing element 204/1541
# Input tokens used: 2578
# Output tokens used: 329
# Processing element 205/1541
# Input tokens used: 3313
# Output tokens used: 516
# Processing element 206/1541
# Input tokens used: 1820
# Output tokens used: 165
# Processing element 207/1541
# Input tokens used: 1639
# Output tokens used: 335
# Processing element 208/1541
# Input tokens used: 4055
# Output tokens used: 327
# Processing element 209/1541
# Input tokens used: 2146
# Output tokens used: 232
# Processing element 210/1541
# Input tokens used: 2286
# Output tokens used: 287
# Processing element 211/1541
# Input tokens used: 2909
# Output tokens used: 270
# Processing element 212/1541
# Input tokens used: 5696
# Output tokens used: 346
# Processing element 213/1541
# Input tokens used: 4807
# Output tokens used: 549
# Processing element 214/1541
# Input tokens used: 4156
# Output tokens used: 385
# Processing element 215/1541
# Input tokens used: 4768
# Output tokens used: 347
# Processing element 216/1541
# Input tokens used: 2807
# Output tokens used: 399
# Processing element 217/1541
# Input tokens used: 2111
# Output tokens used: 441
# Processing element 218/1541
# Input tokens used: 4018
# Output tokens used: 464
# Classifications contains values that does not exist as category: ['Statistical Analysis in Physics Education']
# Probability distribution contains keys that are not available category: ['Statistical Analysis in Physics Education']
# Retrying 2/5...
# Input tokens used: 4056
# Output tokens used: 418
# Processing element 219/1541
# Input tokens used: 2948
# Output tokens used: 652
# Processing element 220/1541
# Input tokens used: 2907
# Output tokens used: 532
# Processing element 221/1541
# Input tokens used: 4530
# Output tokens used: 324
# Processing element 222/1541
# Input tokens used: 3516
# Output tokens used: 340
# Processing element 223/1541
# Input tokens used: 3435
# Output tokens used: 415
# Processing element 224/1541
# Input tokens used: 2020
# Output tokens used: 212
# Processing element 225/1541
# Input tokens used: 3270
# Output tokens used: 443
# Processing element 226/1541
# Input tokens used: 8521
# Output tokens used: 424
# Processing element 227/1541
# Input tokens used: 2949
# Output tokens used: 331
# Processing element 228/1541
# Input tokens used: 4003
# Output tokens used: 432
# Added new category: Ethnographic Observation and Field Notes Analysis
# Added new category: Educational Psychology Framework Application
# Added new category: Instructional Practice Comparative Study
# Processing element 229/1541
# Input tokens used: 3104
# Output tokens used: 219
# Processing element 230/1541
# Input tokens used: 8009
# Output tokens used: 296
# Processing element 231/1541
# Input tokens used: 3074
# Output tokens used: 352
# Processing element 232/1541
# Input tokens used: 4712
# Output tokens used: 436
# Processing element 233/1541
# Input tokens used: 1908
# Output tokens used: 287
# Processing element 234/1541
# Input tokens used: 7105
# Output tokens used: 458
# Processing element 235/1541
# Input tokens used: 2565
# Output tokens used: 413
# Processing element 236/1541
# Input tokens used: 2552
# Output tokens used: 335
# Processing element 237/1541
# Input tokens used: 2724
# Output tokens used: 168
# Processing element 238/1541
# Input tokens used: 1768
# Output tokens used: 303
# Processing element 239/1541
# Input tokens used: 4189
# Output tokens used: 425
# Processing element 240/1541
# Input tokens used: 1960
# Output tokens used: 391
# Processing element 241/1541
# Input tokens used: 3284
# Output tokens used: 459
# Processing element 242/1541
# Input tokens used: 3752
# Output tokens used: 442
# Processing element 243/1541
# Input tokens used: 2535
# Output tokens used: 554
# Processing element 244/1541
# Input tokens used: 5878
# Output tokens used: 412
# Processing element 245/1541
# Input tokens used: 3352
# Output tokens used: 370
# Processing element 246/1541
# Input tokens used: 2465
# Output tokens used: 299
# Processing element 247/1541
# Input tokens used: 3502
# Output tokens used: 264
# Processing element 248/1541
# Input tokens used: 4646
# Output tokens used: 260
# Processing element 249/1541
# Input tokens used: 4614
# Output tokens used: 372
# Processing element 250/1541
# Input tokens used: 2679
# Output tokens used: 531
# Processing element 251/1541
# Input tokens used: 4452
# Output tokens used: 444
# Processing element 252/1541
# Input tokens used: 3332
# Output tokens used: 2047
# Processing element 253/1541
# Input tokens used: 3378
# Output tokens used: 243
# Processing element 254/1541
# Input tokens used: 3345
# Output tokens used: 334
# Processing element 255/1541
# Input tokens used: 2073
# Output tokens used: 377
# Processing element 256/1541
# Input tokens used: 3399
# Output tokens used: 455
# Processing element 257/1541
# Input tokens used: 3508
# Output tokens used: 442
# Processing element 258/1541
# Input tokens used: 3084
# Output tokens used: 426
# Added new category: Content Analysis in Physics Education
# Processing element 259/1541
# Input tokens used: 5939
# Output tokens used: 376
# Processing element 260/1541
# Input tokens used: 5697
# Output tokens used: 487
# Processing element 261/1541
# Input tokens used: 1927
# Output tokens used: 190
# Processing element 262/1541
# Input tokens used: 10816
# Output tokens used: 126
# Processing element 263/1541
# Input tokens used: 2558
# Output tokens used: 417
# Processing element 264/1541
# Input tokens used: 4238
# Output tokens used: 450
# Processing element 265/1541
# Input tokens used: 2953
# Output tokens used: 306
# Processing element 266/1541
# Input tokens used: 2629
# Output tokens used: 338
# Processing element 267/1541
# Input tokens used: 2164
# Output tokens used: 335
# Processing element 268/1541
# Input tokens used: 1745
# Output tokens used: 197
# Processing element 269/1541
# Input tokens used: 2371
# Output tokens used: 346
# Processing element 270/1541
# Input tokens used: 3735
# Output tokens used: 509
# Processing element 271/1541
# Input tokens used: 3342
# Output tokens used: 446
# Processing element 272/1541
# Input tokens used: 1780
# Output tokens used: 359
# Processing element 273/1541
# Input tokens used: 3613
# Output tokens used: 574
# Processing element 274/1541
# Input tokens used: 3260
# Output tokens used: 337
# Processing element 275/1541
# Input tokens used: 3408
# Output tokens used: 335
# Processing element 276/1541
# Input tokens used: 2644
# Output tokens used: 320
# Processing element 277/1541
# Input tokens used: 2943
# Output tokens used: 356
# Processing element 278/1541
# Input tokens used: 2167
# Output tokens used: 340
# Processing element 279/1541
# Input tokens used: 2962
# Output tokens used: 353
# Processing element 280/1541
# Input tokens used: 1752
# Output tokens used: 290
# Processing element 281/1541
# Input tokens used: 6443
# Output tokens used: 334
# Processing element 282/1541
# Input tokens used: 2913
# Output tokens used: 220
# Processing element 283/1541
# Input tokens used: 6048
# Output tokens used: 397
# Processing element 284/1541
# Input tokens used: 12200
# Output tokens used: 356
# Processing element 285/1541
# Input tokens used: 3106
# Output tokens used: 513
# Processing element 286/1541
# Input tokens used: 4214
# Output tokens used: 360
# Processing element 287/1541
# Input tokens used: 2899
# Output tokens used: 235
# Processing element 288/1541
# Input tokens used: 2942
# Output tokens used: 298
# Processing element 289/1541
# Input tokens used: 4309
# Output tokens used: 400
# Processing element 290/1541
# Input tokens used: 4258
# Output tokens used: 458
# Processing element 291/1541
# Input tokens used: 2174
# Output tokens used: 228
# Processing element 292/1541
# Input tokens used: 3039
# Output tokens used: 378
# Processing element 293/1541
# Input tokens used: 4931
# Output tokens used: 323
# Processing element 294/1541
# Input tokens used: 1989
# Output tokens used: 224
# Processing element 295/1541
# Input tokens used: 4350
# Output tokens used: 344
# Processing element 296/1541
# Input tokens used: 3670
# Output tokens used: 603
# Processing element 297/1541
# Input tokens used: 3799
# Output tokens used: 576
# Processing element 298/1541
# Input tokens used: 2496
# Output tokens used: 537
# Processing element 299/1541
# Input tokens used: 2010
# Output tokens used: 303
# Processing element 300/1541
# Input tokens used: 2084
# Output tokens used: 371
# Processing element 301/1541
# Input tokens used: 2896
# Output tokens used: 346
# Processing element 302/1541
# Input tokens used: 6259
# Output tokens used: 452
# Processing element 303/1541
# Input tokens used: 3732
# Output tokens used: 370
# Processing element 304/1541
# Input tokens used: 2338
# Output tokens used: 377
# Processing element 305/1541
# Input tokens used: 6492
# Output tokens used: 342
# Processing element 306/1541
# Input tokens used: 3801
# Output tokens used: 271
# Processing element 307/1541
# Input tokens used: 10478
# Output tokens used: 326
# Processing element 308/1541
# Input tokens used: 2248
# Output tokens used: 223
# Processing element 309/1541
# Input tokens used: 1640
# Output tokens used: 174
# Processing element 310/1541
# Input tokens used: 3612
# Output tokens used: 267
# Processing element 311/1541
# Input tokens used: 2816
# Output tokens used: 240
# Processing element 312/1541
# Input tokens used: 2302
# Output tokens used: 403
# Processing element 313/1541
# Input tokens used: 4280
# Output tokens used: 461
# Processing element 314/1541
# Input tokens used: 3653
# Output tokens used: 547
# Processing element 315/1541
# Input tokens used: 3221
# Output tokens used: 408
# Processing element 316/1541
# Input tokens used: 5168
# Output tokens used: 295
# Processing element 317/1541
# Input tokens used: 3043
# Output tokens used: 307
# Processing element 318/1541
# Input tokens used: 4648
# Output tokens used: 239
# Processing element 319/1541
# Input tokens used: 2542
# Output tokens used: 405
# Processing element 320/1541
# Input tokens used: 2695
# Output tokens used: 370
# Processing element 321/1541
# Input tokens used: 3188
# Output tokens used: 504
# Processing element 322/1541
# Input tokens used: 9679
# Output tokens used: 322
# Processing element 323/1541
# Input tokens used: 2430
# Output tokens used: 357
# Processing element 324/1541
# Input tokens used: 4651
# Output tokens used: 270
# Processing element 325/1541
# Input tokens used: 4530
# Output tokens used: 437
# Processing element 326/1541
# Input tokens used: 4493
# Output tokens used: 332
# Processing element 327/1541
# Input tokens used: 3138
# Output tokens used: 389
# Processing element 328/1541
# Input tokens used: 2865
# Output tokens used: 317
# Processing element 329/1541
# Input tokens used: 2330
# Output tokens used: 475
# Processing element 330/1541
# Input tokens used: 3252
# Output tokens used: 406
# Processing element 331/1541
# Input tokens used: 2615
# Output tokens used: 381
# Processing element 332/1541
# Input tokens used: 2291
# Output tokens used: 417
# Processing element 333/1541
# Input tokens used: 2566
# Output tokens used: 377
# Processing element 334/1541
# Input tokens used: 5154
# Output tokens used: 420
# Processing element 335/1541
# Input tokens used: 8476
# Output tokens used: 825
# Processing element 336/1541
# Input tokens used: 2462
# Output tokens used: 342
# Processing element 337/1541
# Input tokens used: 2471
# Output tokens used: 308
# Processing element 338/1541
# Input tokens used: 2157
# Output tokens used: 373
# Processing element 339/1541
# Input tokens used: 4642
# Output tokens used: 473
# Processing element 340/1541
# Input tokens used: 1830
# Output tokens used: 375
# Processing element 341/1541
# Input tokens used: 4454
# Output tokens used: 510
# Processing element 342/1541
# Input tokens used: 2514
# Output tokens used: 230
# Processing element 343/1541
# Input tokens used: 3421
# Output tokens used: 436
# Processing element 344/1541
# Input tokens used: 4921
# Output tokens used: 343
# Processing element 345/1541
# Input tokens used: 1831
# Output tokens used: 272
# Processing element 346/1541
# Input tokens used: 3710
# Output tokens used: 279
# Processing element 347/1541
# Input tokens used: 3095
# Output tokens used: 585
# Classifications contains values that does not exist as category: ['Instructional Context Analysis']
# Probability distribution contains keys that are not available category: ['Instructional Context Analysis']
# Retrying 2/5...
# Input tokens used: 3131
# Output tokens used: 485
# Processing element 348/1541
# Input tokens used: 2372
# Output tokens used: 215
# Processing element 349/1541
# Input tokens used: 2175
# Output tokens used: 426
# Processing element 350/1541
# Input tokens used: 2558
# Output tokens used: 294
# Processing element 351/1541
# Input tokens used: 2788
# Output tokens used: 397
# Processing element 352/1541
# Input tokens used: 4771
# Output tokens used: 406
# Processing element 353/1541
# Input tokens used: 4703
# Output tokens used: 375
# Processing element 354/1541
# Input tokens used: 3480
# Output tokens used: 402
# Processing element 355/1541
# Input tokens used: 3332
# Output tokens used: 292
# Processing element 356/1541
# Input tokens used: 2869
# Output tokens used: 275
# Processing element 357/1541
# Input tokens used: 1592
# Output tokens used: 384
# Processing element 358/1541
# Input tokens used: 4219
# Output tokens used: 685
# Processing element 359/1541
# Input tokens used: 4075
# Output tokens used: 464
# Processing element 360/1541
# Input tokens used: 5403
# Output tokens used: 440
# Processing element 361/1541
# Input tokens used: 3028
# Output tokens used: 373
# Processing element 362/1541
# Input tokens used: 3838
# Output tokens used: 234
# Processing element 363/1541
# Input tokens used: 3150
# Output tokens used: 264
# Processing element 364/1541
# Input tokens used: 2502
# Output tokens used: 278
# Processing element 365/1541
# Input tokens used: 6756
# Output tokens used: 485
# Processing element 366/1541
# Input tokens used: 2333
# Output tokens used: 327
# Processing element 367/1541
# Input tokens used: 4893
# Output tokens used: 336
# Processing element 368/1541
# Input tokens used: 1834
# Output tokens used: 310
# Processing element 369/1541
# Input tokens used: 3170
# Output tokens used: 530
# Processing element 370/1541
# Input tokens used: 2303
# Output tokens used: 288
# Processing element 371/1541
# Input tokens used: 2226
# Output tokens used: 404
# Processing element 372/1541
# Input tokens used: 1949
# Output tokens used: 186
# Processing element 373/1541
# Input tokens used: 1556
# Output tokens used: 158
# Processing element 374/1541
# Input tokens used: 2119
# Output tokens used: 538
# Processing element 375/1541
# Input tokens used: 2866
# Output tokens used: 516
# Processing element 376/1541
# Input tokens used: 3679
# Output tokens used: 502
# Processing element 377/1541
# Input tokens used: 4148
# Output tokens used: 513
# Processing element 378/1541
# Input tokens used: 4118
# Output tokens used: 456
# Processing element 379/1541
# Input tokens used: 2931
# Output tokens used: 400
# Processing element 380/1541
# Input tokens used: 2557
# Output tokens used: 439
# Processing element 381/1541
# Input tokens used: 3939
# Output tokens used: 330
# Processing element 382/1541
# Input tokens used: 1522
# Output tokens used: 144
# Processing element 383/1541
# Input tokens used: 2813
# Output tokens used: 357
# Processing element 384/1541
# Input tokens used: 1894
# Output tokens used: 276
# Processing element 385/1541
# Input tokens used: 3946
# Output tokens used: 451
# Processing element 386/1541
# Input tokens used: 5888
# Output tokens used: 208
# Processing element 387/1541
# Input tokens used: 2374
# Output tokens used: 382
# Processing element 388/1541
# Input tokens used: 3902
# Output tokens used: 668
# Processing element 389/1541
# Input tokens used: 2858
# Output tokens used: 626
# Processing element 390/1541
# Input tokens used: 5722
# Output tokens used: 329
# Processing element 391/1541
# Input tokens used: 5725
# Output tokens used: 488
# Processing element 392/1541
# Input tokens used: 2369
# Output tokens used: 378
# Processing element 393/1541
# Input tokens used: 3643
# Output tokens used: 332
# Processing element 394/1541
# Input tokens used: 1845
# Output tokens used: 339
# Processing element 395/1541
# Input tokens used: 3090
# Output tokens used: 402
# Processing element 396/1541
# Input tokens used: 4216
# Output tokens used: 353
# Added new category: Instructional Context Description
# Processing element 397/1541
# Input tokens used: 2004
# Output tokens used: 323
# Processing element 398/1541
# Input tokens used: 3891
# Output tokens used: 497
# Processing element 399/1541
# Input tokens used: 3187
# Output tokens used: 466
# Processing element 400/1541
# Input tokens used: 7254
# Output tokens used: 458
# Processing element 401/1541
# Input tokens used: 2767
# Output tokens used: 509
# Processing element 402/1541
# Input tokens used: 3195
# Output tokens used: 425
# Processing element 403/1541
# Input tokens used: 2308
# Output tokens used: 468
# Processing element 404/1541
# Input tokens used: 2594
# Output tokens used: 286
# Processing element 405/1541
# Input tokens used: 5856
# Output tokens used: 367
# Processing element 406/1541
# Input tokens used: 5273
# Output tokens used: 343
# Processing element 407/1541
# Input tokens used: 2987
# Output tokens used: 471
# Processing element 408/1541
# Input tokens used: 2624
# Output tokens used: 240
# Processing element 409/1541
# Input tokens used: 6845
# Output tokens used: 381
# Processing element 410/1541
# Input tokens used: 3012
# Output tokens used: 468
# Processing element 411/1541
# Input tokens used: 2117
# Output tokens used: 520
# Processing element 412/1541
# Input tokens used: 2146
# Output tokens used: 375
# Processing element 413/1541
# Input tokens used: 2931
# Output tokens used: 337
# Processing element 414/1541
# Input tokens used: 2677
# Output tokens used: 283
# Processing element 415/1541
# Input tokens used: 3190
# Output tokens used: 360
# Processing element 416/1541
# Input tokens used: 3116
# Output tokens used: 338
# Processing element 417/1541
# Input tokens used: 1831
# Output tokens used: 364
# Processing element 418/1541
# Input tokens used: 3739
# Output tokens used: 264
# Processing element 419/1541
# Input tokens used: 3328
# Output tokens used: 402
# Processing element 420/1541
# Input tokens used: 7237
# Output tokens used: 335
# Processing element 421/1541
# Input tokens used: 3433
# Output tokens used: 238
# Processing element 422/1541
# Input tokens used: 2991
# Output tokens used: 354
# Processing element 423/1541
# Input tokens used: 1943
# Output tokens used: 359
# Processing element 424/1541
# Input tokens used: 2047
# Output tokens used: 419
# Processing element 425/1541
# Input tokens used: 4287
# Output tokens used: 392
# Processing element 426/1541
# Input tokens used: 2284
# Output tokens used: 605
# Processing element 427/1541
# Input tokens used: 4520
# Output tokens used: 497
# Processing element 428/1541
# Input tokens used: 1815
# Output tokens used: 446
# Processing element 429/1541
# Input tokens used: 2257
# Output tokens used: 359
# Processing element 430/1541
# Input tokens used: 1909
# Output tokens used: 333
# Processing element 431/1541
# Input tokens used: 1814
# Output tokens used: 418
# Processing element 432/1541
# Input tokens used: 3596
# Output tokens used: 469
# Processing element 433/1541
# Input tokens used: 8374
# Output tokens used: 367
# Processing element 434/1541
# Input tokens used: 4230
# Output tokens used: 391
# Processing element 435/1541
# Input tokens used: 3933
# Output tokens used: 251
# Processing element 436/1541
# Input tokens used: 2006
# Output tokens used: 340
# Processing element 437/1541
# Input tokens used: 2181
# Output tokens used: 280
# Processing element 438/1541
# Input tokens used: 6097
# Output tokens used: 362
# Processing element 439/1541
# Input tokens used: 3142
# Output tokens used: 474
# Processing element 440/1541
# Input tokens used: 4120
# Output tokens used: 434
# Processing element 441/1541
# Input tokens used: 2841
# Output tokens used: 287
# Processing element 442/1541
# Input tokens used: 9941
# Output tokens used: 382
# Processing element 443/1541
# Input tokens used: 2424
# Output tokens used: 353
# Processing element 444/1541
# Input tokens used: 5126
# Output tokens used: 552
# Processing element 445/1541
# Input tokens used: 2546
# Output tokens used: 439
# Processing element 446/1541
# Input tokens used: 1714
# Output tokens used: 268
# Processing element 447/1541
# Input tokens used: 1870
# Output tokens used: 339
# Processing element 448/1541
# Input tokens used: 1843
# Output tokens used: 237
# Processing element 449/1541
# Input tokens used: 6281
# Output tokens used: 379
# Processing element 450/1541
# Input tokens used: 3356
# Output tokens used: 462
# Added new category: Mixed-Methods Study: Simulation and Qualitative Coding
# Processing element 451/1541
# Input tokens used: 4154
# Output tokens used: 328
# Processing element 452/1541
# Input tokens used: 3097
# Output tokens used: 322
# Processing element 453/1541
# Input tokens used: 2670
# Output tokens used: 231
# Processing element 454/1541
# Input tokens used: 2862
# Output tokens used: 289
# Processing element 455/1541
# Input tokens used: 3847
# Output tokens used: 332
# Processing element 456/1541
# Input tokens used: 3465
# Output tokens used: 479
# Processing element 457/1541
# Input tokens used: 2439
# Output tokens used: 247
# Processing element 458/1541
# Input tokens used: 4405
# Output tokens used: 315
# Processing element 459/1541
# Input tokens used: 10737
# Output tokens used: 374
# Processing element 460/1541
# Input tokens used: 3181
# Output tokens used: 316
# Processing element 461/1541
# Input tokens used: 6836
# Output tokens used: 484
# Processing element 462/1541
# Input tokens used: 2707
# Output tokens used: 271
# Processing element 463/1541
# Input tokens used: 4108
# Output tokens used: 336
# Processing element 464/1541
# Input tokens used: 3333
# Output tokens used: 391
# Processing element 465/1541
# Input tokens used: 2598
# Output tokens used: 330
# Processing element 466/1541
# Input tokens used: 2714
# Output tokens used: 256
# Processing element 467/1541
# Input tokens used: 2493
# Output tokens used: 442
# Processing element 468/1541
# Input tokens used: 2541
# Output tokens used: 297
# Processing element 469/1541
# Input tokens used: 2661
# Output tokens used: 502
# Processing element 470/1541
# Input tokens used: 4672
# Output tokens used: 508
# Processing element 471/1541
# Input tokens used: 4253
# Output tokens used: 682
# Processing element 472/1541
# Input tokens used: 3362
# Output tokens used: 338
# Processing element 473/1541
# Input tokens used: 5409
# Output tokens used: 639
# Processing element 474/1541
# Input tokens used: 3879
# Output tokens used: 480
# Processing element 475/1541
# Input tokens used: 2134
# Output tokens used: 393
# Processing element 476/1541
# Input tokens used: 1781
# Output tokens used: 354
# Processing element 477/1541
# Input tokens used: 5148
# Output tokens used: 346
# Processing element 478/1541
# Input tokens used: 2859
# Output tokens used: 464
# Processing element 479/1541
# Input tokens used: 5358
# Output tokens used: 318
# Processing element 480/1541
# Input tokens used: 7002
# Output tokens used: 415
# Processing element 481/1541
# Input tokens used: 2990
# Output tokens used: 628
# Processing element 482/1541
# Input tokens used: 3439
# Output tokens used: 336
# Processing element 483/1541
# Input tokens used: 2659
# Output tokens used: 489
# Processing element 484/1541
# Input tokens used: 3317
# Output tokens used: 492
# Processing element 485/1541
# Input tokens used: 1538
# Output tokens used: 118
# Processing element 486/1541
# Input tokens used: 2706
# Output tokens used: 237
# Processing element 487/1541
# Input tokens used: 3534
# Output tokens used: 416
# Processing element 488/1541
# Input tokens used: 3327
# Output tokens used: 478
# Processing element 489/1541
# Input tokens used: 2531
# Output tokens used: 317
# Processing element 490/1541
# Input tokens used: 6094
# Output tokens used: 340
# Processing element 491/1541
# Input tokens used: 2715
# Output tokens used: 636
# Processing element 492/1541
# Input tokens used: 2257
# Output tokens used: 491
# Processing element 493/1541
# Input tokens used: 3801
# Output tokens used: 428
# Processing element 494/1541
# Input tokens used: 5261
# Output tokens used: 314
# Processing element 495/1541
# Input tokens used: 3479
# Output tokens used: 494
# Processing element 496/1541
# Input tokens used: 2389
# Output tokens used: 334
# Processing element 497/1541
# Input tokens used: 5116
# Output tokens used: 463
# Processing element 498/1541
# Input tokens used: 2834
# Output tokens used: 353
# Processing element 499/1541
# Input tokens used: 2087
# Output tokens used: 508
# Processing element 500/1541
# Input tokens used: 2974
# Output tokens used: 344
# Processing element 501/1541
# Input tokens used: 2948
# Output tokens used: 314
# Processing element 502/1541
# Input tokens used: 6002
# Output tokens used: 624
# Processing element 503/1541
# Input tokens used: 3260
# Output tokens used: 412
# Processing element 504/1541
# Input tokens used: 2999
# Output tokens used: 249
# Processing element 505/1541
# Input tokens used: 2441
# Output tokens used: 328
# Processing element 506/1541
# Input tokens used: 2004
# Output tokens used: 290
# Processing element 507/1541
# Input tokens used: 3058
# Output tokens used: 346
# Processing element 508/1541
# Input tokens used: 3118
# Output tokens used: 350
# Processing element 509/1541
# Input tokens used: 2007
# Output tokens used: 299
# Processing element 510/1541
# Input tokens used: 2652
# Output tokens used: 292
# Processing element 511/1541
# Input tokens used: 2699
# Output tokens used: 427
# Processing element 512/1541
# Input tokens used: 2005
# Output tokens used: 527
# Processing element 513/1541
# Input tokens used: 3169
# Output tokens used: 356
# Processing element 514/1541
# Input tokens used: 3290
# Output tokens used: 616
# Processing element 515/1541
# Input tokens used: 2570
# Output tokens used: 477
# Processing element 516/1541
# Input tokens used: 1827
# Output tokens used: 304
# Processing element 517/1541
# Input tokens used: 3120
# Output tokens used: 386
# Processing element 518/1541
# Input tokens used: 4435
# Output tokens used: 567
# Processing element 519/1541
# Input tokens used: 2629
# Output tokens used: 435
# Processing element 520/1541
# Input tokens used: 2884
# Output tokens used: 271
# Processing element 521/1541
# Input tokens used: 2609
# Output tokens used: 255
# Processing element 522/1541
# Input tokens used: 2020
# Output tokens used: 207
# Processing element 523/1541
# Input tokens used: 2653
# Output tokens used: 415
# Processing element 524/1541
# Input tokens used: 5556
# Output tokens used: 680
# Processing element 525/1541
# Input tokens used: 3979
# Output tokens used: 484
# Processing element 526/1541
# Input tokens used: 4035
# Output tokens used: 691
# Processing element 527/1541
# Input tokens used: 3456
# Output tokens used: 417
# Processing element 528/1541
# Input tokens used: 6587
# Output tokens used: 597
# Processing element 529/1541
# Input tokens used: 5218
# Output tokens used: 252
# Processing element 530/1541
# Input tokens used: 3935
# Output tokens used: 555
# Processing element 531/1541
# Input tokens used: 2929
# Output tokens used: 182
# Processing element 532/1541
# Input tokens used: 5491
# Output tokens used: 332
# Processing element 533/1541
# Input tokens used: 3591
# Output tokens used: 551
# Processing element 534/1541
# Input tokens used: 5187
# Output tokens used: 722
# Processing element 535/1541
# Input tokens used: 3639
# Output tokens used: 300
# Processing element 536/1541
# Input tokens used: 8118
# Output tokens used: 326
# Processing element 537/1541
# Input tokens used: 7814
# Output tokens used: 409
# Processing element 538/1541
# Input tokens used: 3263
# Output tokens used: 478
# Added new category: Cross-Sequential Longitudinal Study Design
# Processing element 539/1541
# Input tokens used: 3661
# Output tokens used: 365
# Processing element 540/1541
# Input tokens used: 5938
# Output tokens used: 655
# Processing element 541/1541
# Input tokens used: 4422
# Output tokens used: 546
# Processing element 542/1541
# Input tokens used: 5204
# Output tokens used: 253
# Processing element 543/1541
# Input tokens used: 3370
# Output tokens used: 344
# Processing element 544/1541
# Input tokens used: 3536
# Output tokens used: 373
# Processing element 545/1541
# Input tokens used: 4864
# Output tokens used: 612
# Processing element 546/1541
# Input tokens used: 2035
# Output tokens used: 260
# Processing element 547/1541
# Input tokens used: 2143
# Output tokens used: 564
# Processing element 548/1541
# Input tokens used: 3719
# Output tokens used: 534
# Processing element 549/1541
# Input tokens used: 4278
# Output tokens used: 424
# Processing element 550/1541
# Input tokens used: 4239
# Output tokens used: 273
# Processing element 551/1541
# Input tokens used: 3062
# Output tokens used: 277
# Processing element 552/1541
# Input tokens used: 2864
# Output tokens used: 327
# Processing element 553/1541
# Input tokens used: 2145
# Output tokens used: 492
# Processing element 554/1541
# Input tokens used: 3387
# Output tokens used: 373
# Processing element 555/1541
# Input tokens used: 2999
# Output tokens used: 372
# Processing element 556/1541
# Input tokens used: 3121
# Output tokens used: 393
# Processing element 557/1541
# Input tokens used: 3716
# Output tokens used: 319
# Processing element 558/1541
# Input tokens used: 4496
# Output tokens used: 460
# Processing element 559/1541
# Input tokens used: 4322
# Output tokens used: 495
# Processing element 560/1541
# Input tokens used: 1776
# Output tokens used: 219
# Processing element 561/1541
# Input tokens used: 3118
# Output tokens used: 398
# Processing element 562/1541
# Input tokens used: 5600
# Output tokens used: 413
# Processing element 563/1541
# Input tokens used: 5735
# Output tokens used: 640
# Processing element 564/1541
# Input tokens used: 5395
# Output tokens used: 360
# Processing element 565/1541
# Input tokens used: 7379
# Output tokens used: 501
# Processing element 566/1541
# Input tokens used: 4818
# Output tokens used: 393
# Processing element 567/1541
# Input tokens used: 1984
# Output tokens used: 403
# Processing element 568/1541
# Input tokens used: 6099
# Output tokens used: 428
# Processing element 569/1541
# Input tokens used: 2872
# Output tokens used: 438
# Processing element 570/1541
# Input tokens used: 4028
# Output tokens used: 399
# Processing element 571/1541
# Input tokens used: 3722
# Output tokens used: 323
# Processing element 572/1541
# Input tokens used: 2189
# Output tokens used: 381
# Processing element 573/1541
# Input tokens used: 4889
# Output tokens used: 500
# Processing element 574/1541
# Input tokens used: 4094
# Output tokens used: 577
# Processing element 575/1541
# Input tokens used: 2400
# Output tokens used: 329
# Processing element 576/1541
# Input tokens used: 6015
# Output tokens used: 480
# Processing element 577/1541
# Input tokens used: 4542
# Output tokens used: 583
# Processing element 578/1541
# Input tokens used: 8123
# Output tokens used: 346
# Processing element 579/1541
# Input tokens used: 2289
# Output tokens used: 376
# Processing element 580/1541
# Input tokens used: 1992
# Output tokens used: 220
# Processing element 581/1541
# Input tokens used: 2421
# Output tokens used: 312
# Processing element 582/1541
# Input tokens used: 2475
# Output tokens used: 376
# Processing element 583/1541
# Input tokens used: 2911
# Output tokens used: 492
# Processing element 584/1541
# Input tokens used: 2150
# Output tokens used: 295
# Processing element 585/1541
# Input tokens used: 2407
# Output tokens used: 287
# Processing element 586/1541
# Input tokens used: 2712
# Output tokens used: 264
# Processing element 587/1541
# Input tokens used: 5814
# Output tokens used: 877
# Processing element 588/1541
# Input tokens used: 3459
# Output tokens used: 426
# Processing element 589/1541
# Input tokens used: 4110
# Output tokens used: 359
# Processing element 590/1541
# Input tokens used: 2247
# Output tokens used: 346
# Processing element 591/1541
# Input tokens used: 4700
# Output tokens used: 501
# Processing element 592/1541
# Input tokens used: 4752
# Output tokens used: 385
# Processing element 593/1541
# Input tokens used: 2900
# Output tokens used: 359
# Processing element 594/1541
# Input tokens used: 2938
# Output tokens used: 340
# Processing element 595/1541
# Input tokens used: 2929
# Output tokens used: 413
# Processing element 596/1541
# Input tokens used: 6279
# Output tokens used: 383
# Processing element 597/1541
# Input tokens used: 8307
# Output tokens used: 458
# Processing element 598/1541
# Input tokens used: 3987
# Output tokens used: 418
# Processing element 599/1541
# Input tokens used: 3670
# Output tokens used: 524
# Processing element 600/1541
# Input tokens used: 2502
# Output tokens used: 336
# Processing element 601/1541
# Input tokens used: 3439
# Output tokens used: 362
# Processing element 602/1541
# Input tokens used: 1782
# Output tokens used: 218
# Processing element 603/1541
# Input tokens used: 2810
# Output tokens used: 366
# Processing element 604/1541
# Input tokens used: 3289
# Output tokens used: 352
# Processing element 605/1541
# Input tokens used: 3315
# Output tokens used: 466
# Processing element 606/1541
# Input tokens used: 5409
# Output tokens used: 394
# Processing element 607/1541
# Input tokens used: 5625
# Output tokens used: 391
# Processing element 608/1541
# Input tokens used: 5059
# Output tokens used: 608
# Processing element 609/1541
# Input tokens used: 2159
# Output tokens used: 250
# Processing element 610/1541
# Input tokens used: 2194
# Output tokens used: 274
# Processing element 611/1541
# Input tokens used: 5509
# Output tokens used: 275
# Processing element 612/1541
# Input tokens used: 3725
# Output tokens used: 614
# Processing element 613/1541
# Input tokens used: 2231
# Output tokens used: 381
# Processing element 614/1541
# Input tokens used: 2661
# Output tokens used: 647
# Processing element 615/1541
# Input tokens used: 3651
# Output tokens used: 620
# Processing element 616/1541
# Input tokens used: 3206
# Output tokens used: 424
# Processing element 617/1541
# Input tokens used: 7080
# Output tokens used: 486
# Processing element 618/1541
# Input tokens used: 7414
# Output tokens used: 313
# Processing element 619/1541
# Input tokens used: 1978
# Output tokens used: 272
# Processing element 620/1541
# ...
# Processing element 1362/1541
# Input tokens used: 3180
# Output tokens used: 437
# Processing element 1363/1541
# Input tokens used: 3017
# Output tokens used: 595
# Processing element 1364/1541
# Input tokens used: 3104
# Output tokens used: 446
# Processing element 1365/1541
# Input tokens used: 2475
# Output tokens used: 354
# Processing element 1366/1541
# Input tokens used: 5157
# Output tokens used: 785
# Processing element 1367/1541
# Input tokens used: 2634
# Output tokens used: 274
# Processing element 1368/1541
# Input tokens used: 7488
# Output tokens used: 490
# Processing element 1369/1541
# Input tokens used: 4721
# Output tokens used: 711
# Processing element 1370/1541
# Input tokens used: 7742
# Output tokens used: 463
# Processing element 1371/1541
# Input tokens used: 8922
# Output tokens used: 628
# Processing element 1372/1541
# Input tokens used: 4442
# Output tokens used: 614
# Processing element 1373/1541
# Input tokens used: 2919
# Output tokens used: 418
# Processing element 1374/1541
# Input tokens used: 3900
# Output tokens used: 451
# Processing element 1375/1541
# Input tokens used: 3000
# Output tokens used: 379
# Processing element 1376/1541
# Input tokens used: 4953
# Output tokens used: 315
# Processing element 1377/1541
# Input tokens used: 6233
# Output tokens used: 332
# Processing element 1378/1541
# Input tokens used: 4194
# Output tokens used: 433
# Processing element 1379/1541
# Input tokens used: 7626
# Output tokens used: 466
# Processing element 1380/1541
# Input tokens used: 2564
# Output tokens used: 258
# Classifications contains values that does not exist as category: ['Course Context Description']
# Probability distribution contains keys that are not available category: ['Course Context Description']
# Retrying 2/5...
# Input tokens used: 2598
# Output tokens used: 235
# Processing element 1381/1541
# Input tokens used: 6687
# Output tokens used: 566
# Processing element 1382/1541
# Input tokens used: 5579
# Output tokens used: 423
# Processing element 1383/1541
# Input tokens used: 2134
# Output tokens used: 318
# Processing element 1384/1541
# Input tokens used: 3018
# Output tokens used: 408
# Processing element 1385/1541
# Input tokens used: 4095
# Output tokens used: 368
# Processing element 1386/1541
# Input tokens used: 3462
# Output tokens used: 355
# Processing element 1387/1541
# Input tokens used: 3538
# Output tokens used: 499
# Processing element 1388/1541
# Input tokens used: 2893
# Output tokens used: 351
# Processing element 1389/1541
# Input tokens used: 3301
# Output tokens used: 452
# Added new category: Professional Development in Physics Education
# Processing element 1390/1541
# Input tokens used: 3582
# Output tokens used: 451
# Classifications contains values that does not exist as category: ['Mixed-Methods Study']
# Probability distribution contains keys that are not available category: ['Mixed-Methods Study']
# Retrying 2/5...
# Input tokens used: 3618
# Output tokens used: 506
# Processing element 1391/1541
# Input tokens used: 4278
# Output tokens used: 452
# Processing element 1392/1541
# Input tokens used: 4838
# Output tokens used: 652
# Processing element 1393/1541
# Input tokens used: 4938
# Output tokens used: 372
# Processing element 1394/1541
# Input tokens used: 5195
# Output tokens used: 508
# Classifications contains values that does not exist as category: ['Mixed-Methods Study']
# Probability distribution contains keys that are not available category: ['Mixed-Methods Study']
# Retrying 2/5...
# Input tokens used: 5231
# Output tokens used: 450
# Classifications contains values that does not exist as category: ['Mixed-Methods Study']
# Probability distribution contains keys that are not available category: ['Mixed-Methods Study']
# Retrying 3/5...
# Input tokens used: 5267
# Output tokens used: 455
# Processing element 1395/1541
# Input tokens used: 5479
# Output tokens used: 471
# Processing element 1396/1541
# Input tokens used: 3448
# Output tokens used: 474
# Processing element 1397/1541
# Input tokens used: 3437
# Output tokens used: 344
# Processing element 1398/1541
# Input tokens used: 3393
# Output tokens used: 146
# Processing element 1399/1541
# Input tokens used: 3386
# Output tokens used: 353
# Processing element 1400/1541
# Input tokens used: 4382
# Output tokens used: 139
# Processing element 1401/1541
# Input tokens used: 3902
# Output tokens used: 458
# Processing element 1402/1541
# Input tokens used: 5371
# Output tokens used: 438
# Processing element 1403/1541
# Input tokens used: 7219
# Output tokens used: 499
# Processing element 1404/1541
# Input tokens used: 2153
# Output tokens used: 249
# Processing element 1405/1541
# Input tokens used: 3576
# Output tokens used: 340
# Processing element 1406/1541
# Input tokens used: 2816
# Output tokens used: 357
# Processing element 1407/1541
# Input tokens used: 4356
# Output tokens used: 409
# Processing element 1408/1541
# Input tokens used: 3074
# Output tokens used: 370
# Processing element 1409/1541
# Input tokens used: 7046
# Output tokens used: 578
# Classifications contains values that does not exist as category: ['Mixed-Methods Study']
# Probability distribution contains keys that are not available category: ['Mixed-Methods Study']
# Retrying 2/5...
# Input tokens used: 7082
# Output tokens used: 630
# Processing element 1410/1541
# Input tokens used: 4813
# Output tokens used: 458
# Processing element 1411/1541
# Input tokens used: 6738
# Output tokens used: 347
# Processing element 1412/1541
# Input tokens used: 7565
# Output tokens used: 579
# Processing element 1413/1541
# Input tokens used: 5087
# Output tokens used: 430
# Processing element 1414/1541
# Input tokens used: 2621
# Output tokens used: 547
# Processing element 1415/1541
# Input tokens used: 8075
# Output tokens used: 317
# Processing element 1416/1541
# Input tokens used: 2940
# Output tokens used: 415
# Processing element 1417/1541
# Input tokens used: 7346
# Output tokens used: 413
# Processing element 1418/1541
# Input tokens used: 5628
# Output tokens used: 305
# Processing element 1419/1541
# Input tokens used: 2868
# Output tokens used: 260
# Processing element 1420/1541
# Input tokens used: 3985
# Output tokens used: 452
# Processing element 1421/1541
# Input tokens used: 4366
# Output tokens used: 367
# Processing element 1422/1541
# Input tokens used: 2276
# Output tokens used: 430
# Processing element 1423/1541
# Input tokens used: 2920
# Output tokens used: 652
# Processing element 1424/1541
# Input tokens used: 4050
# Output tokens used: 129
# Processing element 1425/1541
# Input tokens used: 2973
# Output tokens used: 507
# Processing element 1426/1541
# Input tokens used: 2824
# Output tokens used: 406
# Processing element 1427/1541
# Input tokens used: 5075
# Output tokens used: 469
# Processing element 1428/1541
# Input tokens used: 5436
# Output tokens used: 598
# Processing element 1429/1541
# Input tokens used: 4095
# Output tokens used: 776
# Processing element 1430/1541
# Input tokens used: 3172
# Output tokens used: 458
# Processing element 1431/1541
# Input tokens used: 2883
# Output tokens used: 245
# Processing element 1432/1541
# Input tokens used: 3009
# Output tokens used: 307
# Processing element 1433/1541
# Input tokens used: 4221
# Output tokens used: 464
# Processing element 1434/1541
# Input tokens used: 3068
# Output tokens used: 548
# Processing element 1435/1541
# Input tokens used: 3487
# Output tokens used: 408
# Processing element 1436/1541
# Input tokens used: 5188
# Output tokens used: 411
# Processing element 1437/1541
# Input tokens used: 2898
# Output tokens used: 591
# Processing element 1438/1541
# Input tokens used: 2440
# Output tokens used: 258
# Processing element 1439/1541
# Input tokens used: 2609
# Output tokens used: 320
# Processing element 1440/1541
# Input tokens used: 3458
# Output tokens used: 329
# Processing element 1441/1541
# Input tokens used: 4988
# Output tokens used: 390
# Processing element 1442/1541
# Input tokens used: 3564
# Output tokens used: 307
# Processing element 1443/1541
# Input tokens used: 4661
# Output tokens used: 454
# Processing element 1444/1541
# Input tokens used: 8493
# Output tokens used: 613
# Processing element 1445/1541
# Input tokens used: 3202
# Output tokens used: 338
# Processing element 1446/1541
# Input tokens used: 5017
# Output tokens used: 357
# Processing element 1447/1541
# Input tokens used: 2569
# Output tokens used: 221
# Processing element 1448/1541
# Input tokens used: 7362
# Output tokens used: 331
# Processing element 1449/1541
# Input tokens used: 4772
# Output tokens used: 388
# Processing element 1450/1541
# Input tokens used: 5986
# Output tokens used: 616
# Processing element 1451/1541
# Input tokens used: 3454
# Output tokens used: 577
# Added new category: Thematic Analysis and Qualitative Coding
# Processing element 1452/1541
# Input tokens used: 2090
# Output tokens used: 158
# Processing element 1453/1541
# Input tokens used: 3795
# Output tokens used: 406
# Processing element 1454/1541
# Input tokens used: 4112
# Output tokens used: 406
# Processing element 1455/1541
# Input tokens used: 3337
# Output tokens used: 260
# Processing element 1456/1541
# Input tokens used: 4778
# Output tokens used: 165
# Processing element 1457/1541
# Input tokens used: 2600
# Output tokens used: 204
# Processing element 1458/1541
# Input tokens used: 5364
# Output tokens used: 373
# Processing element 1459/1541
# Input tokens used: 4780
# Output tokens used: 330
# Processing element 1460/1541
# Input tokens used: 2875
# Output tokens used: 317
# Processing element 1461/1541
# Input tokens used: 5262
# Output tokens used: 484
# Processing element 1462/1541
# Input tokens used: 2923
# Output tokens used: 151
# Classifications contains values that does not exist as category: ['Course Context Description']
# Probability distribution contains keys that are not available category: ['Course Context Description']
# Retrying 2/5...
# Input tokens used: 2957
# Output tokens used: 319
# Processing element 1463/1541
# Input tokens used: 3456
# Output tokens used: 369
# Processing element 1464/1541
# Input tokens used: 2653
# Output tokens used: 261
# Processing element 1465/1541
# Input tokens used: 4084
# Output tokens used: 450
# Processing element 1466/1541
# Input tokens used: 3581
# Output tokens used: 503
# Processing element 1467/1541
# Input tokens used: 2272
# Output tokens used: 268
# Processing element 1468/1541
# Input tokens used: 2966
# Output tokens used: 215
# Processing element 1469/1541
# Input tokens used: 5203
# Output tokens used: 659
# Added new category: Reasoning Chain Construction and Network Analysis in Physics Education
# Processing element 1470/1541
# Input tokens used: 4340
# Output tokens used: 421
# Processing element 1471/1541
# Input tokens used: 8217
# Output tokens used: 736
# Processing element 1472/1541
# Input tokens used: 5699
# Output tokens used: 502
# Processing element 1473/1541
# Input tokens used: 7323
# Output tokens used: 441
# Processing element 1474/1541
# Input tokens used: 4329
# Output tokens used: 676
# Processing element 1475/1541
# Input tokens used: 3322
# Output tokens used: 287
# Processing element 1476/1541
# Input tokens used: 5393
# Output tokens used: 289
# Processing element 1477/1541
# Input tokens used: 4748
# Output tokens used: 315
# Processing element 1478/1541
# Input tokens used: 7934
# Output tokens used: 491
# Processing element 1479/1541
# Input tokens used: 3303
# Output tokens used: 373
# Processing element 1480/1541
# Input tokens used: 2361
# Output tokens used: 321
# Processing element 1481/1541
# Input tokens used: 3223
# Output tokens used: 425
# Processing element 1482/1541
# Input tokens used: 6940
# Output tokens used: 781
# Processing element 1483/1541
# Input tokens used: 3638
# Output tokens used: 208
# Processing element 1484/1541
# Input tokens used: 3800
# Output tokens used: 348
# Processing element 1485/1541
# Input tokens used: 5187
# Output tokens used: 464
# Processing element 1486/1541
# Input tokens used: 5862
# Output tokens used: 582
# Processing element 1487/1541
# Input tokens used: 6081
# Output tokens used: 344
# Processing element 1488/1541
# Input tokens used: 2558
# Output tokens used: 317
# Processing element 1489/1541
# Input tokens used: 2937
# Output tokens used: 345
# Processing element 1490/1541
# Input tokens used: 4296
# Output tokens used: 377
# Processing element 1491/1541
# Input tokens used: 9969
# Output tokens used: 757
# Processing element 1492/1541
# Input tokens used: 3731
# Output tokens used: 556
# Processing element 1493/1541
# Input tokens used: 2741
# Output tokens used: 481
# Processing element 1494/1541
# Input tokens used: 6837
# Output tokens used: 509
# Processing element 1495/1541
# Input tokens used: 5746
# Output tokens used: 494
# Processing element 1496/1541
# Input tokens used: 3083
# Output tokens used: 465
# Processing element 1497/1541
# Input tokens used: 5953
# Output tokens used: 581
# Processing element 1498/1541
# Input tokens used: 2597
# Output tokens used: 370
# Processing element 1499/1541
# Input tokens used: 5142
# Output tokens used: 327
# Processing element 1500/1541
# Input tokens used: 2282
# Output tokens used: 226
# Processing element 1501/1541
# Input tokens used: 6413
# Output tokens used: 296
# Processing element 1502/1541
# Input tokens used: 6053
# Output tokens used: 437
# Processing element 1503/1541
# Input tokens used: 3879
# Output tokens used: 435
# Processing element 1504/1541
# Input tokens used: 5337
# Output tokens used: 510
# Processing element 1505/1541
# Input tokens used: 2681
# Output tokens used: 340
# Processing element 1506/1541
# Input tokens used: 4351
# Output tokens used: 506
# Processing element 1507/1541
# Input tokens used: 4377
# Output tokens used: 545
# Processing element 1508/1541
# Input tokens used: 6469
# Output tokens used: 432
# Processing element 1509/1541
# Input tokens used: 7519
# Output tokens used: 498
# Processing element 1510/1541
# Input tokens used: 6111
# Output tokens used: 485
# Processing element 1511/1541
# Input tokens used: 6428
# Output tokens used: 450
# Processing element 1512/1541
# Input tokens used: 12168
# Output tokens used: 556
# Processing element 1513/1541
# Input tokens used: 3412
# Output tokens used: 343
# Added new category: Simulation and Demonstration-Based Instructional Design
# Processing element 1514/1541
# Input tokens used: 5389
# Output tokens used: 515
# Processing element 1515/1541
# Input tokens used: 6312
# Output tokens used: 747
# Classifications contains values that does not exist as category: ['Mixed-Methods Study']
# Probability distribution contains keys that are not available category: ['Mixed-Methods Study']
# Retrying 2/5...
# Input tokens used: 6348
# Output tokens used: 116
# Processing element 1516/1541
# Input tokens used: 2799
# Output tokens used: 306
# Processing element 1517/1541
# Input tokens used: 4982
# Output tokens used: 334
# Processing element 1518/1541
# Input tokens used: 4682
# Output tokens used: 315
# Processing element 1519/1541
# Input tokens used: 4976
# Output tokens used: 567
# Processing element 1520/1541
# Input tokens used: 3139
# Output tokens used: 250
# Processing element 1521/1541
# Input tokens used: 5054
# Output tokens used: 307
# Processing element 1522/1541
# Input tokens used: 3880
# Output tokens used: 336
# Processing element 1523/1541
# Input tokens used: 4832
# Output tokens used: 421
# Processing element 1524/1541
# Input tokens used: 6575
# Output tokens used: 410
# Processing element 1525/1541
# Input tokens used: 4962
# Output tokens used: 345
# Processing element 1526/1541
# Input tokens used: 3855
# Output tokens used: 552
# Processing element 1527/1541
# Input tokens used: 4193
# Output tokens used: 368
# Processing element 1528/1541
# Input tokens used: 3807
# Output tokens used: 588
# Processing element 1529/1541
# Input tokens used: 3501
# Output tokens used: 482
# Processing element 1530/1541
# Input tokens used: 5776
# Output tokens used: 387
# Processing element 1531/1541
# Input tokens used: 4479
# Output tokens used: 584
# Processing element 1532/1541
# Input tokens used: 3804
# Output tokens used: 397
# Processing element 1533/1541
# Input tokens used: 7661
# Output tokens used: 469
# Processing element 1534/1541
# Input tokens used: 4934
# Output tokens used: 363
# Processing element 1535/1541
# Input tokens used: 3053
# Output tokens used: 399
# Processing element 1536/1541
# Input tokens used: 2865
# Output tokens used: 315
# Processing element 1537/1541
# Input tokens used: 5914
# Output tokens used: 428
# Processing element 1538/1541
# Input tokens used: 6615
# Output tokens used: 608
# Processing element 1539/1541
# Input tokens used: 5064
# Output tokens used: 549
# Processing element 1540/1541
# Input tokens used: 5745
# Output tokens used: 330
# Processing element 1541/1541
# Input tokens used: 4821
# Output tokens used: 786
# Batch processing complete. Total categories available: 44

# %% [markdown]
# Let us preview the results to make sure they make sense.

# %%
result_df
# Out:
#                                article_id  \
# 0           10.1103/PhysRevSTPER.2.010103
# 1           10.1103/PhysRevSTPER.2.010103
# 2           10.1103/PhysRevSTPER.2.010105
# 3           10.1103/PhysRevSTPER.2.020101
# 4           10.1103/PhysRevSTPER.2.020103
# ..                                    ...
# 584  10.1103/PhysRevPhysEducRes.20.020145
# 585  10.1103/PhysRevPhysEducRes.20.020146
# 586  10.1103/PhysRevPhysEducRes.20.020146
# 587  10.1103/PhysRevPhysEducRes.20.020147
# 588  10.1103/PhysRevPhysEducRes.20.020153
#
#                                          section_title  \
# 0              THEORETICAL FRAME: A MODEL OF COGNITION
# 1    STUDENT MODEL SPACE: A MATHEMATICAL REPRESENTA...
# 2                      BACKGROUND AND VALIDITY OF BEMA
# 3                                   THEORETICAL FRAMES
# 4                        DEFINING SCIENTIFIC ABILITIES
# ..                                                 ...
# 584                                         BACKGROUND
# 585                            THE COMMOGNITIVE THEORY
# 586  ANALYSIS OF SCIENTIFIC CONTENT: CONCEPTUALIZAT...
# 587                             THEORETICAL BACKGROUND
# 588               THEORETICAL FRAMEWORK AND LITERATURE
#
#                           classifications_gpt-4.1-mini  \
# 0    [Resource Framing, Knowledge Integration Frame...
# 1    [Mathematical Modeling Framework, Postpositivism]
# 2    [Measurement Theory Framework, Formative Asses...
# 3    [Modeling, Structure Mapping, and Conceptual B...
# 4    [Formative Assessment Framework (Assessment fo...
# ..                                                 ...
# 584  [Philosophy & History of Science Framework, Ep...
# 585                              [Commognitive Theory]
# 586  [Model of Educational Reconstruction (MER), Co...
# 587  [Johnson-Laird Mental Representation Framework...
# 588  [Sociocultural Identity and Gender Performativ...
#
#                             probabilities_gpt-4.1-mini  \
# 0    {'Resource Framing': 0.6, 'Knowledge Integrati...
# 1    {'Mathematical Modeling Framework': 0.85, 'Pos...
# 2    {'Measurement Theory Framework': 0.75, 'Format...
# 3    {'Modeling, Structure Mapping, and Conceptual ...
# 4    {'Formative Assessment Framework (Assessment f...
# ..                                                 ...
# 584  {'Philosophy & History of Science Framework': ...
# 585                       {'Commognitive Theory': 1.0}
# 586  {'Model of Educational Reconstruction (MER)': ...
# 587  {'Johnson-Laird Mental Representation Framewor...
# 588  {'Sociocultural Identity and Gender Performati...
#
#                              highest_prob_gpt-4.1-mini  \
# 0                                     Resource Framing
# 1                      Mathematical Modeling Framework
# 2                         Measurement Theory Framework
# 3    Modeling, Structure Mapping, and Conceptual Bl...
# 4    Formative Assessment Framework (Assessment for...
# ..                                                 ...
# 584          Philosophy & History of Science Framework
# 585                                Commognitive Theory
# 586          Model of Educational Reconstruction (MER)
# 587      Johnson-Laird Mental Representation Framework
# 588   Metacognitive Critical Affective (MCA) Framework
#
#                             text_excerpts_gpt-4.1-mini
# 0    {'Resource Framing': [{'excerpt': 'We are inte...
# 1    {'Mathematical Modeling Framework': [{'excerpt...
# 2    {'Measurement Theory Framework': [{'excerpt': ...
# 3    {'Modeling, Structure Mapping, and Conceptual ...
# 4    {'Formative Assessment Framework (Assessment f...
# ..                                                 ...
# 584  {'Philosophy & History of Science Framework': ...
# 585  {'Commognitive Theory': [{'excerpt': 'Rooted i...
# 586  {'Model of Educational Reconstruction (MER)': ...
# 587  {'Johnson-Laird Mental Representation Framewor...
# 588  {'Sociocultural Identity and Gender Performati...
#
# [589 rows x 6 columns]

# %% [markdown]
# The classificator also extracts some text exerpts from the classification data. Currently this is not used for anything. But it could be used e.g. for generating improved and more detailed descriptions of research methods by passing a bunch of exerpts for the same framework to a LLM.
#
# Here we print out a sample of them for a simple overview of what it extracts.

# %%
# Print out the text excerpts from 3 random rows using sample
sampled = result_df.sample(3, random_state=42)
for idx, row in sampled.iterrows():
    excerpts = row.get("text_excerpts_gpt-4.1-mini", [])
    # If excerpts is a string, try to parse as JSON
    if isinstance(excerpts, str):
        try:
            excerpts = json.loads(excerpts)
        except Exception:
            pass  # If it can't be parsed, leave as is
    if not excerpts or excerpts == "No excerpts found":
        print(f"\nRow {idx}: No excerpts found")
        continue
    print(f"\nRow {idx} excerpts by category:")
    for excerpt in excerpts:
        # If excerpt is a string, try to parse as JSON
        if isinstance(excerpt, str):
            try:
                excerpt = json.loads(excerpt)
            except Exception:
                excerpt = {}
        category = excerpt.get("category", "Unknown Category")
        text = excerpt.get("excerpt", "No excerpt text")
        print(f"  Category: {category}\n    Excerpt: {text}")
# Out:
# Row 1491 excerpts by category:
#   Category: Unknown Category
#     Excerpt: No excerpt text
#   Category: Unknown Category
#     Excerpt: No excerpt text
#   Category: Unknown Category
#     Excerpt: No excerpt text
#   Category: Unknown Category
#     Excerpt: No excerpt text
#
# Row 1155 excerpts by category:
#   Category: Unknown Category
#     Excerpt: No excerpt text
#   Category: Unknown Category
#     Excerpt: No excerpt text
#   Category: Unknown Category
#     Excerpt: No excerpt text
#
# Row 1252 excerpts by category:
#   Category: Unknown Category
#     Excerpt: No excerpt text
#   Category: Unknown Category
#     Excerpt: No excerpt text
#   Category: Unknown Category
#     Excerpt: No excerpt text

# %% [markdown]
# #### Classification and new category processing and saving

# %%
len(updated_categories)
# Out:
# 44

# %%
# Save updated categories if any new ones were discovered
if len(updated_categories) > len(methods):
    print(f"\nDiscovered {len(updated_categories) - len(methods)} new categories")
    save_categories_to_json(updated_categories, "./methods_data/reviewed_categories.json")
# Out:
# Discovered 19 new categories
# Categories saved to ./methods_data/reviewed_categories_20250807_190400.json

# %%
# Merge result_df columns into theory_df using 'article_id' and 'section_title' for alignment, prefixing with 'theory_'
merge_cols = [col for col in result_df.columns if col not in ['article_id', 'section_title']]
methods_df_merged = methods_df.merge(
    result_df.rename(columns={col: f"method_{col}" for col in merge_cols}),
    on=['article_id', 'section_title'],
    how='left'
)

# %%
import numpy as np

# Count the rows in theory_df_merged with a NaN value in 'theory_classification_gpt_4.1-mini'
nan_count = methods_df_merged['method_probabilities_gpt-4.1-mini'].isna().sum()
print(f"Number of rows with NaN in 'method_classification_gpt_4.1-mini': {nan_count}")
# Out:
# Number of rows with NaN in 'theory_classification_gpt_4.1-mini': 0

# %%
methods_df_merged
# Out:
#                                        article_abstract article_articleType  \
# 0     {'value': '<p>We report a detailed study of th...             article
# 1     {'value': '<p>We investigated the common diffi...             article
# 2     {'value': '<p>We investigated the common diffi...             article
# 3     {'value': '<p>This paper examines the effects ...             article
# 4     {'value': '<p>Student success in solving physi...             article
# ...                                                 ...                 ...
# 1536  {'value': '<p>We examine students’ challenges ...             article
# 1537  {'value': '<p>Undergraduate students on track ...             article
# 1538  {'value': '<p>One hallmark of expertise in phy...             article
# 1539  {'value': '<p>[This paper is part of the Focus...             article
# 1540  {'value': '<p>[This paper is part of the Focus...             article
#
#                                         article_authors  \
# 0     [{'type': 'Person', 'name': 'N. D. Finkelstein...
# 1     [{'type': 'Person', 'name': 'Lorenzo G. Rimold...
# 2     [{'type': 'Person', 'name': 'Lorenzo G. Rimold...
# 3     [{'type': 'Person', 'name': 'N. D. Finkelstein...
# 4     [{'type': 'Person', 'name': 'Patrick B. Kohl',...
# ...                                                 ...
# 1536  [{'type': 'Person', 'name': 'Christof Keebaugh...
# 1537  [{'type': 'Person', 'name': 'Madeline Harmer',...
# 1538  [{'type': 'Person', 'name': 'Emily Marshman', ...
# 1539  [{'type': 'Person', 'name': 'Nilüfer Didiş Kör...
# 1540  [{'type': 'Person', 'name': 'Angela M. Kelly',...
#
#                                    article_affiliations article_date  \
# 0     [{'name': 'Department of Physics, University o...   2005-09-08
# 1     [{'name': 'Department of Physics and Astronomy...   2005-10-04
# 2     [{'name': 'Department of Physics and Astronomy...   2005-10-04
# 3     [{'name': 'Department of Physics, University o...   2005-10-06
# 4     [{'name': 'Department of Physics, University o...   2005-10-19
# ...                                                 ...          ...
# 1536  [{'name': 'Department of Physics, Pennsylvania...   2024-12-05
# 1537  [{'name': 'Physics and Astronomy Department, <...   2024-12-13
# 1538  [{'name': 'Department of Physics and Natural S...   2024-12-23
# 1539  [{'name': 'Department of Mathematics and Scien...   2024-12-26
# 1540  [{'name': 'Department of Physics and Astronomy...   2024-12-31
#
#      article_type article_metadata_last_modified_at  article_last_modified_at  \
# 0         article          2006-03-02T15:40:18+0000 2014-08-22 11:32:05+00:00
# 1         article          2006-03-02T15:40:56+0000 2014-02-26 22:53:09+00:00
# 2         article          2006-03-02T15:40:56+0000 2014-02-26 22:53:09+00:00
# 3         article          2006-03-02T15:41:24+0000 2014-08-22 11:32:06+00:00
# 4         article          2006-03-02T15:41:57+0000 2014-02-26 22:53:09+00:00
# ...           ...                               ...                       ...
# 1536      article          2024-12-05T16:21:31+0000 2024-12-05 16:21:31+00:00
# 1537      article          2024-12-13T15:03:03+0000 2024-12-13 15:03:03+00:00
# 1538      article          2024-12-23T17:00:21+0000 2024-12-23 17:00:21+00:00
# 1539      article          2024-12-26T14:57:19+0000 2024-12-26 14:57:19+00:00
# 1540      article          2024-12-31T15:01:02+0000 2024-12-31 15:01:02+00:00
#
#                                 article_id  \
# 0            10.1103/PhysRevSTPER.1.010101
# 1            10.1103/PhysRevSTPER.1.010102
# 2            10.1103/PhysRevSTPER.1.010102
# 3            10.1103/PhysRevSTPER.1.010103
# 4            10.1103/PhysRevSTPER.1.010104
# ...                                    ...
# 1536  10.1103/PhysRevPhysEducRes.20.020149
# 1537  10.1103/PhysRevPhysEducRes.20.020150
# 1538  10.1103/PhysRevPhysEducRes.20.020152
# 1539  10.1103/PhysRevPhysEducRes.20.020153
# 1540  10.1103/PhysRevPhysEducRes.20.020154
#
#                                   article_identifiers  ...  \
# 0            {'doi': '10.1103/PhysRevSTPER.1.010101'}  ...
# 1            {'doi': '10.1103/PhysRevSTPER.1.010102'}  ...
# 2            {'doi': '10.1103/PhysRevSTPER.1.010102'}  ...
# 3            {'doi': '10.1103/PhysRevSTPER.1.010103'}  ...
# 4            {'doi': '10.1103/PhysRevSTPER.1.010104'}  ...
# ...                                               ...  ...
# 1536  {'doi': '10.1103/PhysRevPhysEducRes.20.020149'}  ...
# 1537  {'doi': '10.1103/PhysRevPhysEducRes.20.020150'}  ...
# 1538  {'doi': '10.1103/PhysRevPhysEducRes.20.020152'}  ...
# 1539  {'doi': '10.1103/PhysRevPhysEducRes.20.020153'}  ...
# 1540  {'doi': '10.1103/PhysRevPhysEducRes.20.020154'}  ...
#
#                                 section_title_embedding  \
# 0     [-0.014114919118583202, 0.06385361403226852, 0...
# 1     [-0.06506878137588501, 0.03131435438990593, 0....
# 2     [-0.021777695044875145, -0.006472709123045206,...
# 3     [-0.08216888457536697, -0.0027919262647628784,...
# 4     [-0.03895077481865883, 0.0529254786670208, 0.0...
# ...                                                 ...
# 1536  [-0.061682552099227905, -0.005451112519949675,...
# 1537  [-0.03920810669660568, 0.05327513813972473, 0....
# 1538  [-0.055263690650463104, 0.03912600874900818, 0...
# 1539  [-0.05474643036723137, 0.03916209936141968, 0....
# 1540  [-0.03901199251413345, 0.05327018350362778, 0....
#
#                               section_content_embedding  \
# 0     [-0.030135443434119225, 0.04174668341875076, -...
# 1     [-0.029744913801550865, 0.005188309587538242, ...
# 2     [-0.03321903944015503, -0.0014654365368187428,...
# 3     [-0.02911161445081234, -0.028258124366402626, ...
# 4     [-0.040330804884433746, 0.021954139694571495, ...
# ...                                                 ...
# 1536  [-0.07386224716901779, 0.015368035063147545, 0...
# 1537  [-0.08286938071250916, 0.034298013895750046, -...
# 1538  [-0.06580902636051178, -0.0011794535676017404,...
# 1539  [-0.06832382082939148, 0.029234101995825768, -...
# 1540  [-0.0803992822766304, 0.03932449594140053, -0....
#
#                           probability_dist_gpt-4.1-mini  \
# 0     {'Methods': 0.9, 'Introduction / Motivation': ...
# 1     {'Methods': 0.97, 'Introduction / Motivation':...
# 2     {'Methods': 0.9, 'Results': 0.05, 'Introductio...
# 3     {'Methods': 0.85, 'Introduction / Motivation':...
# 4     {'Introduction / Motivation': 0.05, 'Theoretic...
# ...                                                 ...
# 1536  {'Introduction / Motivation': 0.0, 'Theoretica...
# 1537  {'Methods': 0.85, 'Limitations': 0.12, 'Ethica...
# 1538  {'Methods': 0.95, 'Introduction / Motivation':...
# 1539  {'Methods': 0.95, 'Introduction / Motivation':...
# 1540  {'Methods': 0.98, 'Introduction / Motivation':...
#
#            classification_gpt-4.1-mini  \
# 0                            [Methods]
# 1                            [Methods]
# 2                            [Methods]
# 3                            [Methods]
# 4                            [Methods]
# ...                                ...
# 1536  [Methods, Theoretical Framework]
# 1537            [Methods, Limitations]
# 1538                         [Methods]
# 1539                         [Methods]
# 1540                         [Methods]
#
#      classification_highest_prob_gpt-4.1-mini failed_validation_gpt-4.1-mini  \
# 0                                     Methods                          False
# 1                                     Methods                          False
# 2                                     Methods                          False
# 3                                     Methods                          False
# 4                                     Methods                          False
# ...                                       ...                            ...
# 1536                                  Methods                          False
# 1537                                  Methods                          False
# 1538                                  Methods                          False
# 1539                                  Methods                          False
# 1540                                  Methods                          False
#
#                     theory_classifications_gpt-4.1-mini  \
# 0     [Tutorial Implementation, Course and Curriculu...
# 1     [Demonstration-Based Tasks, Multiple-Choice In...
# 2     [Demonstration-Based Tasks, Qualitative Interv...
# 3     [Experimental Design in Physics Education, Cou...
# 4     [Homework and Quiz Study Methods, Experimental...
# ...                                                 ...
# 1536  [Pedagogical Interventions and Tools, Assessme...
# 1537  [Laboratory Instruction and Student Activities...
# 1538  [Tutorial Implementation, Qualitative Intervie...
# 1539  [Case Study Analysis in Physics Education, Stu...
# 1540  [Professional Development in Physics Education...
#
#                       theory_probabilities_gpt-4.1-mini  \
# 0     {'Tutorial Implementation': 0.5, 'Course and C...
# 1     {'Demonstration-Based Tasks': 0.35, 'Multiple-...
# 2     {'Demonstration-Based Tasks': 0.75, 'Qualitati...
# 3     {'Experimental Design in Physics Education': 0...
# 4     {'Homework and Quiz Study Methods': 0.7, 'Expe...
# ...                                                 ...
# 1536  {'Pedagogical Interventions and Tools': 0.6, '...
# 1537  {'Laboratory Instruction and Student Activitie...
# 1538  {'Tutorial Implementation': 0.35, 'Qualitative...
# 1539  {'Case Study Analysis in Physics Education': 0...
# 1540  {'Professional Development in Physics Educatio...
#
#                        theory_highest_prob_gpt-4.1-mini  \
# 0                               Tutorial Implementation
# 1                             Demonstration-Based Tasks
# 2                             Demonstration-Based Tasks
# 3              Experimental Design in Physics Education
# 4                       Homework and Quiz Study Methods
# ...                                                 ...
# 1536                Pedagogical Interventions and Tools
# 1537  Laboratory Instruction and Student Activities ...
# 1538                            Tutorial Implementation
# 1539           Case Study Analysis in Physics Education
# 1540      Professional Development in Physics Education
#
#                       theory_text_excerpts_gpt-4.1-mini
# 0     {'Tutorial Implementation': [{'excerpt': 'Tuto...
# 1     {'Demonstration-Based Tasks': [{'excerpt': 'Th...
# 2     {'Demonstration-Based Tasks': [{'excerpt': 'Th...
# 3     {'Experimental Design in Physics Education': [...
# 4     {'Homework and Quiz Study Methods': [{'excerpt...
# ...                                                 ...
# 1536  {'Pedagogical Interventions and Tools': [{'exc...
# 1537  {'Laboratory Instruction and Student Activitie...
# 1538  {'Tutorial Implementation': [{'excerpt': 'The ...
# 1539  {'Case Study Analysis in Physics Education': [...
# 1540  {'Professional Development in Physics Educatio...
#
# [1541 rows x 42 columns]

# %%
helpers.save_processed_embeddings(methods_df_merged, "./methods_data/methods_classification_df")
# Out:
# Saved processed_embeddings to ./methods_data/methods_classification_df_20250807_141802.pkl
# './methods_data/methods_classification_df_20250807_141802.pkl'

# %% [markdown]
# ## Review categories

# %% [markdown]
# ### Load classified data (to avoid rerunning)

# %%
methods_df_merged = pd.read_pickle("./methods_data/methods_classification_df_20250807_141802.pkl")
updated_categories = load_categories_from_json("./methods_data/reviewed_categories_20250721_163329.json")
print(methods_df_merged.keys())
print(len(updated_categories))
# Out:
# Successfully loaded 135 categories from ./reviewed_categories_20250721_163329.json
# Index(['article_abstract', 'article_articleType', 'article_authors',
#        'article_affiliations', 'article_date', 'article_type',
#        'article_metadata_last_modified_at', 'article_last_modified_at',
#        'article_id', 'article_identifiers', 'article_issue',
#        'article_pageStart', 'article_hasArticleId', 'article_numPages',
#        'article_publisher', 'article_rights', 'article_journal',
#        'article_title', 'article_volume', 'article_notes',
#        'article_tocSection', 'article_fundings',
#        'article_classificationSchemes', 'article_doi', 'article_full_text_xml',
#        'article_full_text', 'article_year', 'section_relative_position',
#        'section_label', 'section_title', 'section_content', 'section_id',
#        'section_title_embedding', 'section_content_embedding',
#        'probability_dist_gpt-4.1-mini', 'classification_gpt-4.1-mini',
#        'classification_highest_prob_gpt-4.1-mini',
#        'failed_validation_gpt-4.1-mini', 'theory_classifications_gpt-4.1-mini',
#        'theory_probabilities_gpt-4.1-mini', 'theory_highest_prob_gpt-4.1-mini',
#        'theory_text_excerpts_gpt-4.1-mini'],
#       dtype='object')
# 135

# %% [markdown]
# ### Run Cleaning

# %%
reviewed_categories = classifier.review_and_clean_categories(updated_categories)
# Out:
# Category review using model: o3-mini
# Reviewing 44 categories
# Input tokens used: 2073
# Output tokens used: 3374
# Review summary:
#   - Original categories: 44
#   - Cleaned categories: 38
#   - Removed categories: 4
#   - Merge suggestions: 2
#   - Removed: Data Collection Methods in Physics Education, Educational Psychology Framework Application, Instructional Context Description, Positionality and Identity Reflection in Physics Education Research
#   - Suggested merges: Student Reasoning Analysis, Instructional Intervention Studies

# %%
from IPython.display import Markdown
issues = classifier._validate_review_result(reviewed_categories, updated_categories)
report = classifier.generate_validation_report(reviewed_categories, updated_categories, issues)
with open("review_report.md", "w") as f:
    f.write(report)
display(Markdown(report))
# Out:
# # Category Review Validation Report
#
# ## Summary
#
# - **Original categories**: 44
# - **Cleaned categories**: 38
# - **Removed categories**: 4
# - **Merge suggestions**: 2
#
# ## Category Differences
# This is based on the actual difference between the original categories and the cleaned categories.
# It does not take into account the merge suggestions.
# See the validation section for validation based on the return from the model.
#
# ### ✅ Added Categories
# - `Instructional Intervention Studies`
# - `Student Reasoning Analysis`
#
# ### ❌ Removed Categories
# - `Data Collection Methods in Physics Education`
# - `Educational Psychology Framework Application`
# - `Instructional Context Description`
# - `Instructional Study Methods in Physics Education`
# - `Pedagogical Interventions and Tools`
# - `Positionality and Identity Reflection in Physics Education Research`
# - `Student Learning and Reasoning Studies`
# - `Student Reasoning and Coding in Physics Education`
#
# ### ➡️ Unchanged Categories
# - `Analogical Scaffolding in Instruction`
# - `Animation-Based Assessment`
# - `Assessment Development and Validation`
# - `Case Study Analysis in Physics Education`
# - `Classroom Implementation and Instructional Strategies`
# - `Cluster Analysis and Student Conceptual Patterns`
# - `Content Analysis in Physics Education`
# - `Course Environment Analysis`
# - `Course and Curriculum Design`
# - `Cross-Sequential Longitudinal Study Design`
# - `Demonstration-Based Tasks`
# - `Design-Based Research Methodology in Physics Education`
# - `Ethnographic Observation and Field Notes Analysis`
# - `Experimental Apparatus and Materials`
# - `Experimental Design in Physics Education`
# - `Homework and Quiz Study Methods`
# - `Identity Survey Study`
# - `Instructional Practice Comparative Study`
# - `Instructor Interview Studies`
# - `Laboratory Instruction and Student Activities Analysis`
# - `Longitudinal Case Study`
# - `Mixed-Methods Study: Simulation and Qualitative Coding`
# - `Multiple-Choice Instrument Analysis`
# - `Professional Development in Physics Education`
# - `Qualitative Interview Methodology in Physics Education`
# - `Reasoning Chain Construction and Network Analysis in Physics Education`
# - `Secondary Data Analysis in Physics Education Research`
# - `Simulation and Demonstration-Based Instructional Design`
# - `Social Network Analysis in Physics Education`
# - `Statistical Analysis in Physics Education`
# - `Survey Methodology in Physics Education`
# - `Test Statistical Evaluation`
# - `Thematic Analysis and Qualitative Coding`
# - `Tutorial Implementation`
# - `Usability and Learning Technology Studies`
# - `Video Data Collection and Analysis`
#
# ## ✅ No Validation Issues
#
# All validation checks passed successfully.
#
# ## 🔄 Merge Suggestions
#
# **1. Student Reasoning Analysis**
# Combines: `Student Learning and Reasoning Studies`, `Student Reasoning and Coding in Physics Education`
# Reasoning: Both entries focus on analyzing how students think and solve physics problems. Merging them provides a unified category that captures the range of approaches (from broad investigations to detailed coding schemes) used to explore student reasoning.
#
# **2. Instructional Intervention Studies**
# Combines: `Pedagogical Interventions and Tools`, `Instructional Study Methods in Physics Education`
# Reasoning: Both methods center on the evaluation of teaching interventions and the impact of instructional designs on learning outcomes. Combining them streamlines classification and highlights common features in how educational innovations are studied in physics education research.
#
# ## 📋 Complete Category Listings
#
# ### Original Categories
#
# - **Analogical Scaffolding in Instruction**: Instructional design using analogies and multiple representations to scaffold student learning of complex physics concepts.
# - **Animation-Based Assessment**: Use of computer animation versions of conceptual tests to explore student understanding and assessment validity.
# - **Assessment Development and Validation**: Methods related to the creation, validation, and use of assessment instruments to measure student learning and understanding.
# - **Case Study Analysis in Physics Education**: Research methodology using case study approach to construct a holistic and in-depth understanding of a situation or phenomenon through triangulation of multiple data sources including surveys, interviews, and assessments.
# - **Classroom Implementation and Instructional Strategies**: Methods detailing the actual execution of instructional activities in classroom settings, including student group work, feedback, and instructor roles.
# - **Cluster Analysis and Student Conceptual Patterns**: Use of cluster analysis to identify patterns in student conceptual responses in physics.
# - **Content Analysis in Physics Education**: Use of content analysis methods to analyze qualitative data such as essays or interview transcripts to explore student or teacher perspectives and experiences in physics education.
# - **Course Environment Analysis**: Methods for analyzing lectures, exams, and assignments to characterize instructional environments.
# - **Course and Curriculum Design**: Methods involving the planning, structuring, and implementation of course content and activities, including curriculum transformation and instructional design.
# - **Cross-Sequential Longitudinal Study Design**: Research methodology involving a combination of longitudinal and cross-sectional designs to track multiple cohorts over time, allowing linkage of data across cohorts to study development along a temporal scale efficiently.
# - **Data Collection Methods in Physics Education**: This merged category covers procedures and tools for gathering research data, including combined descriptions of overall study design, specific data collection instruments, and protocols.
# - **Demonstration-Based Tasks**: Design and use of physical demonstration tasks to probe student conceptual models during interviews.
# - **Design-Based Research Methodology in Physics Education**: Research methodology involving iterative development and study of educational interventions in real classroom settings, integrating design and research to improve teaching and learning.
# - **Educational Psychology Framework Application**: Application of educational psychology theoretical frameworks, such as wise schooling and stereotype threat, to interpret classroom observation data and understand student learning outcomes.
# - **Ethnographic Observation and Field Notes Analysis**: Use of ethnographic methods including detailed field notes and classroom observations to analyze instructor practices and student interactions in physics education settings.
# - **Experimental Apparatus and Materials**: Description and use of physical devices or teaching materials developed or adapted for research or instructional purposes.
# - **Experimental Design in Physics Education**: A comprehensive category that addresses the design of controlled experiments, including participant selection, intervention procedures, pre-/post-testing, and comparative studies across domains.
# - **Homework and Quiz Study Methods**: Design and use of homework and quiz problems in various representational formats to study student understanding.
# - **Identity Survey Study**: Use of repeated identity survey instruments to measure constructs such as physics identity components (interest, competence, recognition) longitudinally.
# - **Instructional Context Description**: Description of the instructional context including course structure, content, student demographics, and instructional approach, used to situate the research study.
# - **Instructional Practice Comparative Study**: Comparative analysis of different instructors' teaching practices, including use of rubrics and coding of observational data, to relate instructional methods to student learning disparities.
# - **Instructional Study Methods in Physics Education**: A unified category that includes studies evaluating instructional interventions, course formats, and materials, covering both general instructional studies and content-specific interventions (e.g., Newton's third law materials).
# - **Instructor Interview Studies**: Semi-structured interviews with physics faculty to explore instructional conceptions and practices.
# - **Laboratory Instruction and Student Activities Analysis**: Comparative studies of design-based and traditional labs, including coding of student activities and interactions.
# - **Longitudinal Case Study**: Research methodology using longitudinal case study design involving tracking participants over time to study development and changes.
# - **Mixed-Methods Study: Simulation and Qualitative Coding**: Research methodology involving the use of mixed-reality simulation activities combined with qualitative coding of participant reflections and video data to study pedagogical skills and participant impressions.
# - **Multiple-Choice Instrument Analysis**: Development and use of model-based analysis of student responses to multiple-choice conceptual assessments.
# - **Pedagogical Interventions and Tools**: Design and evaluation of specific teaching methods or tools aimed at improving student learning and epistemic development.
# - **Positionality and Identity Reflection in Physics Education Research**: Research method category involving researchers' reflection on their own identities, experiences, and positionalities as they relate to the study of physics education, particularly focusing on how identity, recognition, and social resources impact participation and belonging in physics communities.
# - **Professional Development in Physics Education**: Research methods focusing specifically on the design, implementation, and evaluation of professional development programs for physics instructors, including workshops, training meetings, observations, coaching, and reflective practices to prepare instructors for teaching reform-based physics courses.
# - **Qualitative Interview Methodology in Physics Education**: This category encompasses qualitative approaches to interviewing, including think‐aloud protocols, demonstration-based and stimulated recall interviews, as well as structured protocols used with both experts and students.
# - **Reasoning Chain Construction and Network Analysis in Physics Education**: Research methodology involving the use of reasoning chain construction tasks where students select and order reasoning elements to build physics problem solutions, combined with network analysis techniques to quantitatively analyze associations between reasoning elements, including methods such as network sparsification, community detection, and centrality measures.
# - **Secondary Data Analysis in Physics Education Research**: Research methodology involving the reinterpretation and reanalysis of existing data sets collected by other researchers, including re-coding and re-categorization of student responses or difficulties using new theoretical frameworks.
# - **Simulation and Demonstration-Based Instructional Design**: Design and use of combined simulation and demonstration-based instructional activities, including development of worksheets and homework assignments that integrate simulation exploration with conceptual questions to enhance student understanding.
# - **Social Network Analysis in Physics Education**: Research methods involving the collection, construction, and analysis of social network data to study student interactions, integration, and influence within physics education contexts. This includes the use of centrality measures, network boundary definitions, weighted and directed ties, and longitudinal network data collection.
# - **Statistical Analysis in Physics Education**: Use of statistical tests and models such as Shapiro-Wilk test, Kruskal-Wallis rank sum test, chi-square test, logistic regression, likelihood ratio tests, and procedures to handle missing data, applied to analyze physics education research data.
# - **Student Learning and Reasoning Studies**: Studies examining student reasoning across and within domains using different representational and instructional treatments.
# - **Student Reasoning and Coding in Physics Education**: Methods for coding and analyzing student reasoning patterns and responses to conceptual physics questions.
# - **Survey Methodology in Physics Education**: A consolidated category covering the development, administration, scoring, analysis, validation, and reliability assessment of surveys (including instruments to assess student beliefs and attitudes).
# - **Test Statistical Evaluation**: Use of item difficulty, discrimination indices, reliability coefficients, and other statistics to evaluate assessment instruments.
# - **Thematic Analysis and Qualitative Coding**: Use of thematic analysis methods to qualitatively analyze qualitative data such as transcripts of peer discussions to identify themes related to learning strategies and cognitive processes.
# - **Tutorial Implementation**: Description of implementing tutorial-based instruction in physics courses, including course structure, staffing, and instructional methods.
# - **Usability and Learning Technology Studies**: Research methods focusing on the evaluation of educational technologies and their impact on student learning and engagement.
# - **Video Data Collection and Analysis**: Methodologies for collecting and analyzing video data of student interactions and TA-student engagement in tutorials.
#
# ### Cleaned Categories
#
# - **Analogical Scaffolding in Instruction**: Instructional design using analogies and multiple representations to scaffold student learning of complex physics concepts.
# - **Animation-Based Assessment**: Use of computer animation versions of conceptual tests to explore student understanding and assessment validity.
# - **Assessment Development and Validation**: Methods related to the creation, validation, and use of assessment instruments to measure student learning and understanding.
# - **Case Study Analysis in Physics Education**: Research methodology using case study approach to construct a holistic and in-depth understanding of a situation or phenomenon through triangulation of multiple data sources including surveys, interviews, and assessments.
# - **Classroom Implementation and Instructional Strategies**: Methods detailing the actual execution of instructional activities in classroom settings, including student group work, feedback, and instructor roles.
# - **Cluster Analysis and Student Conceptual Patterns**: Use of cluster analysis to identify patterns in student conceptual responses in physics.
# - **Content Analysis in Physics Education**: Use of content analysis methods to analyze qualitative data such as essays or interview transcripts to explore student or teacher perspectives and experiences in physics education.
# - **Course Environment Analysis**: Methods for analyzing lectures, exams, and assignments to characterize instructional environments.
# - **Course and Curriculum Design**: Methods involving the planning, structuring, and implementation of course content and activities, including curriculum transformation and instructional design.
# - **Cross-Sequential Longitudinal Study Design**: Research methodology involving a combination of longitudinal and cross-sectional designs to track multiple cohorts over time, allowing linkage of data across cohorts to study development along a temporal scale efficiently.
# - **Demonstration-Based Tasks**: Design and use of physical demonstration tasks to probe student conceptual models during interviews.
# - **Design-Based Research Methodology in Physics Education**: Research methodology involving iterative development and study of educational interventions in real classroom settings, integrating design and research to improve teaching and learning.
# - **Ethnographic Observation and Field Notes Analysis**: Use of ethnographic methods including detailed field notes and classroom observations to analyze instructor practices and student interactions in physics education settings.
# - **Experimental Apparatus and Materials**: Description and use of physical devices or teaching materials developed or adapted for research or instructional purposes.
# - **Experimental Design in Physics Education**: A comprehensive category that addresses the design of controlled experiments, including participant selection, intervention procedures, pre-/post-testing, and comparative studies across domains.
# - **Homework and Quiz Study Methods**: Design and use of homework and quiz problems in various representational formats to study student understanding.
# - **Identity Survey Study**: Use of repeated identity survey instruments to measure constructs such as physics identity components (interest, competence, recognition) longitudinally.
# - **Instructional Intervention Studies**: This category consolidates research methods that evaluate and compare instructional interventions, including both the design and evaluation of specific pedagogical tools and broader instructional studies. It merges entries such as 'Pedagogical Interventions and Tools' and 'Instructional Study Methods in Physics Education', which both address systematic evaluation of instructional practices and course innovations.
# - **Instructional Practice Comparative Study**: Comparative analysis of different instructors' teaching practices, including use of rubrics and coding of observational data, to relate instructional methods to student learning disparities.
# - **Instructor Interview Studies**: Semi-structured interviews with physics faculty to explore instructional conceptions and practices.
# - **Laboratory Instruction and Student Activities Analysis**: Comparative studies of design-based and traditional labs, including coding of student activities and interactions.
# - **Longitudinal Case Study**: Research methodology using longitudinal case study design involving tracking participants over time to study development and changes.
# - **Mixed-Methods Study: Simulation and Qualitative Coding**: Research methodology involving the use of mixed-reality simulation activities combined with qualitative coding of participant reflections and video data to study pedagogical skills and participant impressions.
# - **Multiple-Choice Instrument Analysis**: Development and use of model-based analysis of student responses to multiple-choice conceptual assessments.
# - **Professional Development in Physics Education**: Research methods focusing specifically on the design, implementation, and evaluation of professional development programs for physics instructors, including workshops, training meetings, observations, coaching, and reflective practices to prepare instructors for teaching reform-based physics courses.
# - **Qualitative Interview Methodology in Physics Education**: This category encompasses qualitative approaches to interviewing, including think‐aloud protocols, demonstration-based and stimulated recall interviews, as well as structured protocols used with both experts and students.
# - **Reasoning Chain Construction and Network Analysis in Physics Education**: Research methodology involving the use of reasoning chain construction tasks where students select and order reasoning elements to build physics problem solutions, combined with network analysis techniques to quantitatively analyze associations between reasoning elements, including methods such as network sparsification, community detection, and centrality measures.
# - **Secondary Data Analysis in Physics Education Research**: Research methodology involving the reinterpretation and reanalysis of existing data sets collected by other researchers, including re-coding and re-categorization of student responses or difficulties using new theoretical frameworks.
# - **Simulation and Demonstration-Based Instructional Design**: Design and use of combined simulation and demonstration-based instructional activities, including development of worksheets and homework assignments that integrate simulation exploration with conceptual questions to enhance student understanding.
# - **Social Network Analysis in Physics Education**: Research methods involving the collection, construction, and analysis of social network data to study student interactions, integration, and influence within physics education contexts. This includes the use of centrality measures, network boundary definitions, weighted and directed ties, and longitudinal network data collection.
# - **Statistical Analysis in Physics Education**: Use of statistical tests and models such as Shapiro-Wilk test, Kruskal-Wallis rank sum test, chi-square test, logistic regression, likelihood ratio tests, and procedures to handle missing data, applied to analyze physics education research data.
# - **Student Reasoning Analysis**: This merged category encompasses methods that investigate student reasoning and conceptual understanding through both qualitative coding and analysis of reasoning tasks. It includes approaches originally labeled as 'Student Learning and Reasoning Studies' and 'Student Reasoning and Coding in Physics Education', uniting studies examining reasoning processes with those involving systematic coding of student responses.
# - **Survey Methodology in Physics Education**: A consolidated category covering the development, administration, scoring, analysis, validation, and reliability assessment of surveys (including instruments to assess student beliefs and attitudes).
# - **Test Statistical Evaluation**: Use of item difficulty, discrimination indices, reliability coefficients, and other statistics to evaluate assessment instruments.
# - **Thematic Analysis and Qualitative Coding**: Use of thematic analysis methods to qualitatively analyze qualitative data such as transcripts of peer discussions to identify themes related to learning strategies and cognitive processes.
# - **Tutorial Implementation**: Description of implementing tutorial-based instruction in physics courses, including course structure, staffing, and instructional methods.
# - **Usability and Learning Technology Studies**: Research methods focusing on the evaluation of educational technologies and their impact on student learning and engagement.
# - **Video Data Collection and Analysis**: Methodologies for collecting and analyzing video data of student interactions and TA-student engagement in tutorials.
#
# ### Removed Categories
#
# - **Data Collection Methods in Physics Education**: This category attempted to cover overall study design, individual data collection instruments, and protocols in one umbrella, making it overly broad and insufficiently specific for classification. (Reason: The category is too broad and general, lacking the specificity needed to be useful for classification as a discrete research method.)
# - **Educational Psychology Framework Application**: This entry describes the application of educational psychology theoretical frameworks (e.g., wise schooling, stereotype threat) to interpret data rather than a concrete research method. (Reason: It is a theoretical framework application, not a research method per se. It does not describe a procedure or protocol for collecting or analyzing data.)
# - **Instructional Context Description**: This entry focuses on describing the instructional context (course structure, student demographics, etc.) used to situate research rather than outlining a systematic method. (Reason: It is a descriptive background element rather than a research method or approach for data collection or analysis.)
# - **Positionality and Identity Reflection in Physics Education Research**: This category involves researcher reflexivity and personal narrative on identity and positionality. (Reason: While critical for qualitative work, it is not a research method but rather a practice of reflective commentary that does not specify a systematic procedure for data collection or analysis.)
#
# ## 📄 JSON Format (Copy-Paste Ready)
#
# ### Original Categories (JSON)
# ```json
# [
#   {
#     "title": "Analogical Scaffolding in Instruction",
#     "description": "Instructional design using analogies and multiple representations to scaffold student learning of complex physics concepts."
#   },
#   {
#     "title": "Animation-Based Assessment",
#     "description": "Use of computer animation versions of conceptual tests to explore student understanding and assessment validity."
#   },
#   {
#     "title": "Assessment Development and Validation",
#     "description": "Methods related to the creation, validation, and use of assessment instruments to measure student learning and understanding."
#   },
#   {
#     "title": "Case Study Analysis in Physics Education",
#     "description": "Research methodology using case study approach to construct a holistic and in-depth understanding of a situation or phenomenon through triangulation of multiple data sources including surveys, interviews, and assessments."
#   },
#   {
#     "title": "Classroom Implementation and Instructional Strategies",
#     "description": "Methods detailing the actual execution of instructional activities in classroom settings, including student group work, feedback, and instructor roles."
#   },
#   {
#     "title": "Cluster Analysis and Student Conceptual Patterns",
#     "description": "Use of cluster analysis to identify patterns in student conceptual responses in physics."
#   },
#   {
#     "title": "Content Analysis in Physics Education",
#     "description": "Use of content analysis methods to analyze qualitative data such as essays or interview transcripts to explore student or teacher perspectives and experiences in physics education."
#   },
#   {
#     "title": "Course Environment Analysis",
#     "description": "Methods for analyzing lectures, exams, and assignments to characterize instructional environments."
#   },
#   {
#     "title": "Course and Curriculum Design",
#     "description": "Methods involving the planning, structuring, and implementation of course content and activities, including curriculum transformation and instructional design."
#   },
#   {
#     "title": "Cross-Sequential Longitudinal Study Design",
#     "description": "Research methodology involving a combination of longitudinal and cross-sectional designs to track multiple cohorts over time, allowing linkage of data across cohorts to study development along a temporal scale efficiently."
#   },
#   {
#     "title": "Data Collection Methods in Physics Education",
#     "description": "This merged category covers procedures and tools for gathering research data, including combined descriptions of overall study design, specific data collection instruments, and protocols."
#   },
#   {
#     "title": "Demonstration-Based Tasks",
#     "description": "Design and use of physical demonstration tasks to probe student conceptual models during interviews."
#   },
#   {
#     "title": "Design-Based Research Methodology in Physics Education",
#     "description": "Research methodology involving iterative development and study of educational interventions in real classroom settings, integrating design and research to improve teaching and learning."
#   },
#   {
#     "title": "Educational Psychology Framework Application",
#     "description": "Application of educational psychology theoretical frameworks, such as wise schooling and stereotype threat, to interpret classroom observation data and understand student learning outcomes."
#   },
#   {
#     "title": "Ethnographic Observation and Field Notes Analysis",
#     "description": "Use of ethnographic methods including detailed field notes and classroom observations to analyze instructor practices and student interactions in physics education settings."
#   },
#   {
#     "title": "Experimental Apparatus and Materials",
#     "description": "Description and use of physical devices or teaching materials developed or adapted for research or instructional purposes."
#   },
#   {
#     "title": "Experimental Design in Physics Education",
#     "description": "A comprehensive category that addresses the design of controlled experiments, including participant selection, intervention procedures, pre-/post-testing, and comparative studies across domains."
#   },
#   {
#     "title": "Homework and Quiz Study Methods",
#     "description": "Design and use of homework and quiz problems in various representational formats to study student understanding."
#   },
#   {
#     "title": "Identity Survey Study",
#     "description": "Use of repeated identity survey instruments to measure constructs such as physics identity components (interest, competence, recognition) longitudinally."
#   },
#   {
#     "title": "Instructional Context Description",
#     "description": "Description of the instructional context including course structure, content, student demographics, and instructional approach, used to situate the research study."
#   },
#   {
#     "title": "Instructional Practice Comparative Study",
#     "description": "Comparative analysis of different instructors' teaching practices, including use of rubrics and coding of observational data, to relate instructional methods to student learning disparities."
#   },
#   {
#     "title": "Instructional Study Methods in Physics Education",
#     "description": "A unified category that includes studies evaluating instructional interventions, course formats, and materials, covering both general instructional studies and content-specific interventions (e.g., Newton's third law materials)."
#   },
#   {
#     "title": "Instructor Interview Studies",
#     "description": "Semi-structured interviews with physics faculty to explore instructional conceptions and practices."
#   },
#   {
#     "title": "Laboratory Instruction and Student Activities Analysis",
#     "description": "Comparative studies of design-based and traditional labs, including coding of student activities and interactions."
#   },
#   {
#     "title": "Longitudinal Case Study",
#     "description": "Research methodology using longitudinal case study design involving tracking participants over time to study development and changes."
#   },
#   {
#     "title": "Mixed-Methods Study: Simulation and Qualitative Coding",
#     "description": "Research methodology involving the use of mixed-reality simulation activities combined with qualitative coding of participant reflections and video data to study pedagogical skills and participant impressions."
#   },
#   {
#     "title": "Multiple-Choice Instrument Analysis",
#     "description": "Development and use of model-based analysis of student responses to multiple-choice conceptual assessments."
#   },
#   {
#     "title": "Pedagogical Interventions and Tools",
#     "description": "Design and evaluation of specific teaching methods or tools aimed at improving student learning and epistemic development."
#   },
#   {
#     "title": "Positionality and Identity Reflection in Physics Education Research",
#     "description": "Research method category involving researchers' reflection on their own identities, experiences, and positionalities as they relate to the study of physics education, particularly focusing on how identity, recognition, and social resources impact participation and belonging in physics communities."
#   },
#   {
#     "title": "Professional Development in Physics Education",
#     "description": "Research methods focusing specifically on the design, implementation, and evaluation of professional development programs for physics instructors, including workshops, training meetings, observations, coaching, and reflective practices to prepare instructors for teaching reform-based physics courses."
#   },
#   {
#     "title": "Qualitative Interview Methodology in Physics Education",
#     "description": "This category encompasses qualitative approaches to interviewing, including think\u2010aloud protocols, demonstration-based and stimulated recall interviews, as well as structured protocols used with both experts and students."
#   },
#   {
#     "title": "Reasoning Chain Construction and Network Analysis in Physics Education",
#     "description": "Research methodology involving the use of reasoning chain construction tasks where students select and order reasoning elements to build physics problem solutions, combined with network analysis techniques to quantitatively analyze associations between reasoning elements, including methods such as network sparsification, community detection, and centrality measures."
#   },
#   {
#     "title": "Secondary Data Analysis in Physics Education Research",
#     "description": "Research methodology involving the reinterpretation and reanalysis of existing data sets collected by other researchers, including re-coding and re-categorization of student responses or difficulties using new theoretical frameworks."
#   },
#   {
#     "title": "Simulation and Demonstration-Based Instructional Design",
#     "description": "Design and use of combined simulation and demonstration-based instructional activities, including development of worksheets and homework assignments that integrate simulation exploration with conceptual questions to enhance student understanding."
#   },
#   {
#     "title": "Social Network Analysis in Physics Education",
#     "description": "Research methods involving the collection, construction, and analysis of social network data to study student interactions, integration, and influence within physics education contexts. This includes the use of centrality measures, network boundary definitions, weighted and directed ties, and longitudinal network data collection."
#   },
#   {
#     "title": "Statistical Analysis in Physics Education",
#     "description": "Use of statistical tests and models such as Shapiro-Wilk test, Kruskal-Wallis rank sum test, chi-square test, logistic regression, likelihood ratio tests, and procedures to handle missing data, applied to analyze physics education research data."
#   },
#   {
#     "title": "Student Learning and Reasoning Studies",
#     "description": "Studies examining student reasoning across and within domains using different representational and instructional treatments."
#   },
#   {
#     "title": "Student Reasoning and Coding in Physics Education",
#     "description": "Methods for coding and analyzing student reasoning patterns and responses to conceptual physics questions."
#   },
#   {
#     "title": "Survey Methodology in Physics Education",
#     "description": "A consolidated category covering the development, administration, scoring, analysis, validation, and reliability assessment of surveys (including instruments to assess student beliefs and attitudes)."
#   },
#   {
#     "title": "Test Statistical Evaluation",
#     "description": "Use of item difficulty, discrimination indices, reliability coefficients, and other statistics to evaluate assessment instruments."
#   },
#   {
#     "title": "Thematic Analysis and Qualitative Coding",
#     "description": "Use of thematic analysis methods to qualitatively analyze qualitative data such as transcripts of peer discussions to identify themes related to learning strategies and cognitive processes."
#   },
#   {
#     "title": "Tutorial Implementation",
#     "description": "Description of implementing tutorial-based instruction in physics courses, including course structure, staffing, and instructional methods."
#   },
#   {
#     "title": "Usability and Learning Technology Studies",
#     "description": "Research methods focusing on the evaluation of educational technologies and their impact on student learning and engagement."
#   },
#   {
#     "title": "Video Data Collection and Analysis",
#     "description": "Methodologies for collecting and analyzing video data of student interactions and TA-student engagement in tutorials."
#   }
# ]
# ```
#
# ### Cleaned Categories (JSON)
# ```json
# [
#   {
#     "title": "Analogical Scaffolding in Instruction",
#     "description": "Instructional design using analogies and multiple representations to scaffold student learning of complex physics concepts."
#   },
#   {
#     "title": "Animation-Based Assessment",
#     "description": "Use of computer animation versions of conceptual tests to explore student understanding and assessment validity."
#   },
#   {
#     "title": "Assessment Development and Validation",
#     "description": "Methods related to the creation, validation, and use of assessment instruments to measure student learning and understanding."
#   },
#   {
#     "title": "Case Study Analysis in Physics Education",
#     "description": "Research methodology using case study approach to construct a holistic and in-depth understanding of a situation or phenomenon through triangulation of multiple data sources including surveys, interviews, and assessments."
#   },
#   {
#     "title": "Classroom Implementation and Instructional Strategies",
#     "description": "Methods detailing the actual execution of instructional activities in classroom settings, including student group work, feedback, and instructor roles."
#   },
#   {
#     "title": "Cluster Analysis and Student Conceptual Patterns",
#     "description": "Use of cluster analysis to identify patterns in student conceptual responses in physics."
#   },
#   {
#     "title": "Content Analysis in Physics Education",
#     "description": "Use of content analysis methods to analyze qualitative data such as essays or interview transcripts to explore student or teacher perspectives and experiences in physics education."
#   },
#   {
#     "title": "Course Environment Analysis",
#     "description": "Methods for analyzing lectures, exams, and assignments to characterize instructional environments."
#   },
#   {
#     "title": "Course and Curriculum Design",
#     "description": "Methods involving the planning, structuring, and implementation of course content and activities, including curriculum transformation and instructional design."
#   },
#   {
#     "title": "Cross-Sequential Longitudinal Study Design",
#     "description": "Research methodology involving a combination of longitudinal and cross-sectional designs to track multiple cohorts over time, allowing linkage of data across cohorts to study development along a temporal scale efficiently."
#   },
#   {
#     "title": "Demonstration-Based Tasks",
#     "description": "Design and use of physical demonstration tasks to probe student conceptual models during interviews."
#   },
#   {
#     "title": "Design-Based Research Methodology in Physics Education",
#     "description": "Research methodology involving iterative development and study of educational interventions in real classroom settings, integrating design and research to improve teaching and learning."
#   },
#   {
#     "title": "Ethnographic Observation and Field Notes Analysis",
#     "description": "Use of ethnographic methods including detailed field notes and classroom observations to analyze instructor practices and student interactions in physics education settings."
#   },
#   {
#     "title": "Experimental Apparatus and Materials",
#     "description": "Description and use of physical devices or teaching materials developed or adapted for research or instructional purposes."
#   },
#   {
#     "title": "Experimental Design in Physics Education",
#     "description": "A comprehensive category that addresses the design of controlled experiments, including participant selection, intervention procedures, pre-/post-testing, and comparative studies across domains."
#   },
#   {
#     "title": "Homework and Quiz Study Methods",
#     "description": "Design and use of homework and quiz problems in various representational formats to study student understanding."
#   },
#   {
#     "title": "Identity Survey Study",
#     "description": "Use of repeated identity survey instruments to measure constructs such as physics identity components (interest, competence, recognition) longitudinally."
#   },
#   {
#     "title": "Instructional Intervention Studies",
#     "description": "This category consolidates research methods that evaluate and compare instructional interventions, including both the design and evaluation of specific pedagogical tools and broader instructional studies. It merges entries such as 'Pedagogical Interventions and Tools' and 'Instructional Study Methods in Physics Education', which both address systematic evaluation of instructional practices and course innovations."
#   },
#   {
#     "title": "Instructional Practice Comparative Study",
#     "description": "Comparative analysis of different instructors' teaching practices, including use of rubrics and coding of observational data, to relate instructional methods to student learning disparities."
#   },
#   {
#     "title": "Instructor Interview Studies",
#     "description": "Semi-structured interviews with physics faculty to explore instructional conceptions and practices."
#   },
#   {
#     "title": "Laboratory Instruction and Student Activities Analysis",
#     "description": "Comparative studies of design-based and traditional labs, including coding of student activities and interactions."
#   },
#   {
#     "title": "Longitudinal Case Study",
#     "description": "Research methodology using longitudinal case study design involving tracking participants over time to study development and changes."
#   },
#   {
#     "title": "Mixed-Methods Study: Simulation and Qualitative Coding",
#     "description": "Research methodology involving the use of mixed-reality simulation activities combined with qualitative coding of participant reflections and video data to study pedagogical skills and participant impressions."
#   },
#   {
#     "title": "Multiple-Choice Instrument Analysis",
#     "description": "Development and use of model-based analysis of student responses to multiple-choice conceptual assessments."
#   },
#   {
#     "title": "Professional Development in Physics Education",
#     "description": "Research methods focusing specifically on the design, implementation, and evaluation of professional development programs for physics instructors, including workshops, training meetings, observations, coaching, and reflective practices to prepare instructors for teaching reform-based physics courses."
#   },
#   {
#     "title": "Qualitative Interview Methodology in Physics Education",
#     "description": "This category encompasses qualitative approaches to interviewing, including think\u2010aloud protocols, demonstration-based and stimulated recall interviews, as well as structured protocols used with both experts and students."
#   },
#   {
#     "title": "Reasoning Chain Construction and Network Analysis in Physics Education",
#     "description": "Research methodology involving the use of reasoning chain construction tasks where students select and order reasoning elements to build physics problem solutions, combined with network analysis techniques to quantitatively analyze associations between reasoning elements, including methods such as network sparsification, community detection, and centrality measures."
#   },
#   {
#     "title": "Secondary Data Analysis in Physics Education Research",
#     "description": "Research methodology involving the reinterpretation and reanalysis of existing data sets collected by other researchers, including re-coding and re-categorization of student responses or difficulties using new theoretical frameworks."
#   },
#   {
#     "title": "Simulation and Demonstration-Based Instructional Design",
#     "description": "Design and use of combined simulation and demonstration-based instructional activities, including development of worksheets and homework assignments that integrate simulation exploration with conceptual questions to enhance student understanding."
#   },
#   {
#     "title": "Social Network Analysis in Physics Education",
#     "description": "Research methods involving the collection, construction, and analysis of social network data to study student interactions, integration, and influence within physics education contexts. This includes the use of centrality measures, network boundary definitions, weighted and directed ties, and longitudinal network data collection."
#   },
#   {
#     "title": "Statistical Analysis in Physics Education",
#     "description": "Use of statistical tests and models such as Shapiro-Wilk test, Kruskal-Wallis rank sum test, chi-square test, logistic regression, likelihood ratio tests, and procedures to handle missing data, applied to analyze physics education research data."
#   },
#   {
#     "title": "Student Reasoning Analysis",
#     "description": "This merged category encompasses methods that investigate student reasoning and conceptual understanding through both qualitative coding and analysis of reasoning tasks. It includes approaches originally labeled as 'Student Learning and Reasoning Studies' and 'Student Reasoning and Coding in Physics Education', uniting studies examining reasoning processes with those involving systematic coding of student responses."
#   },
#   {
#     "title": "Survey Methodology in Physics Education",
#     "description": "A consolidated category covering the development, administration, scoring, analysis, validation, and reliability assessment of surveys (including instruments to assess student beliefs and attitudes)."
#   },
#   {
#     "title": "Test Statistical Evaluation",
#     "description": "Use of item difficulty, discrimination indices, reliability coefficients, and other statistics to evaluate assessment instruments."
#   },
#   {
#     "title": "Thematic Analysis and Qualitative Coding",
#     "description": "Use of thematic analysis methods to qualitatively analyze qualitative data such as transcripts of peer discussions to identify themes related to learning strategies and cognitive processes."
#   },
#   {
#     "title": "Tutorial Implementation",
#     "description": "Description of implementing tutorial-based instruction in physics courses, including course structure, staffing, and instructional methods."
#   },
#   {
#     "title": "Usability and Learning Technology Studies",
#     "description": "Research methods focusing on the evaluation of educational technologies and their impact on student learning and engagement."
#   },
#   {
#     "title": "Video Data Collection and Analysis",
#     "description": "Methodologies for collecting and analyzing video data of student interactions and TA-student engagement in tutorials."
#   }
# ]
# ```
#
# ### Removed Categories (JSON)
# ```json
# [
#   {
#     "title": "Data Collection Methods in Physics Education",
#     "description": "This category attempted to cover overall study design, individual data collection instruments, and protocols in one umbrella, making it overly broad and insufficiently specific for classification.",
#     "reason": "The category is too broad and general, lacking the specificity needed to be useful for classification as a discrete research method."
#   },
#   {
#     "title": "Educational Psychology Framework Application",
#     "description": "This entry describes the application of educational psychology theoretical frameworks (e.g., wise schooling, stereotype threat) to interpret data rather than a concrete research method.",
#     "reason": "It is a theoretical framework application, not a research method per se. It does not describe a procedure or protocol for collecting or analyzing data."
#   },
#   {
#     "title": "Instructional Context Description",
#     "description": "This entry focuses on describing the instructional context (course structure, student demographics, etc.) used to situate research rather than outlining a systematic method.",
#     "reason": "It is a descriptive background element rather than a research method or approach for data collection or analysis."
#   },
#   {
#     "title": "Positionality and Identity Reflection in Physics Education Research",
#     "description": "This category involves researcher reflexivity and personal narrative on identity and positionality.",
#     "reason": "While critical for qualitative work, it is not a research method but rather a practice of reflective commentary that does not specify a systematic procedure for data collection or analysis."
#   }
# ]
# ```
#
# ### Merges (JSON)
# ```json
# [
#   {
#     "merged_title": "Instructional Intervention Studies",
#     "frameworks_to_merge": [
#       "Pedagogical Interventions and Tools",
#       "Instructional Study Methods in Physics Education"
#     ],
#     "reasoning": "Both methods center on the evaluation of teaching interventions and the impact of instructional designs on learning outcomes. Combining them streamlines classification and highlights common features in how educational innovations are studied in physics education research."
#   },
#   {
#     "merged_title": "Student Reasoning Analysis",
#     "frameworks_to_merge": [
#       "Student Learning and Reasoning Studies",
#       "Student Reasoning and Coding in Physics Education"
#     ],
#     "reasoning": "Both entries focus on analyzing how students think and solve physics problems. Merging them provides a unified category that captures the range of approaches (from broad investigations to detailed coding schemes) used to explore student reasoning."
#   }
# ]
# ```
#
# ## 💭 Review Reasoning
#
# Each method was reviewed considering its status as a genuine research practice in physics education, its specificity, and its conceptual distinctiveness. Categories that were overly broad, duplicated under different names, or pertained more to theoretical frameworks than to applied research procedures were either merged with overlapping categories or removed entirely. The resulting cleaned list now includes categories that are both sufficiently detailed and distinct for useful classification in physics education research.

# %%
save_categories_to_json(reviewed_categories.cleaned_categories, "./methods_data/reviewed_categories.json")
# Out:
# Categories saved to ./methods_data/reviewed_categories_20250807_190755.json

# %% [markdown]
# ## Create Meta-Categories

# %%
from methods_classifiers import ResearchMethodsClassifier


classifier = ResearchMethodsClassifier(api_key=api_key, temperature=0.5,
                                max_tokens=1000, general_model="gpt-4.1", reasoning_model="o3-mini")
                                # OBS! We are using gpt-4.1 here because of the low token length

# %%
research_methods = load_categories_from_json("./methods_data/reviewed_categories_20250807_141801.json")
# Out:
# Successfully loaded 44 categories from ./methods_data/reviewed_categories_20250807_141801.json

# %% [markdown]
# #### Discover/load initial categories
#
# The classifier can pass the raw data, in this case the framework titles and descriptions, to a LLM to discover a initial set of categories.

# %%
preped_discovery_data = [f"{cat.title}: {cat.description}" for cat in research_methods]
discovered_meta_categories = classifier.discover_categories(preped_discovery_data)
# Out:
# Category discovery using model: gpt-4.1
# Input tokens used: 2026
# Output tokens used: 361

# %%
for x in discovered_meta_categories:
    print(x.title)
    print(x.description)
    print("-"*100)
# Out:
# Instructional Design and Implementation Methods
# Methods focused on the planning, structuring, and execution of instructional activities, including curriculum development, classroom interventions, and use of specific pedagogical tools.
# ----------------------------------------------------------------------------------------------------
# Assessment and Evaluation Methods
# Methods related to the creation, validation, statistical evaluation, and analysis of assessment instruments such as tests, surveys, and quizzes to measure student learning and conceptual understanding.
# ----------------------------------------------------------------------------------------------------
# Qualitative Research Methods
# Approaches involving the collection and analysis of qualitative data, such as interviews, thematic analysis, content analysis, and ethnographic observation, to explore perspectives, reasoning, and experiences.
# ----------------------------------------------------------------------------------------------------
# Quantitative and Statistical Methods
# Methods utilizing quantitative data collection and statistical analysis, including experimental design, cluster analysis, social network analysis, and use of statistical tests to analyze research data.
# ----------------------------------------------------------------------------------------------------
# Mixed-Methods Research
# Research methodologies that combine qualitative and quantitative approaches, such as mixed-methods studies involving simulations, coding, and statistical analysis.
# ----------------------------------------------------------------------------------------------------
# Longitudinal and Case Study Methods
# Research designs that involve tracking participants or cohorts over extended periods to study development, change, and identity formation, including longitudinal case studies and cross-sequential designs.
# ----------------------------------------------------------------------------------------------------
# Professional Development and Instructor-Focused Methods
# Methods centered on the design, implementation, and evaluation of professional development programs and studies of instructor practices and beliefs.
# ----------------------------------------------------------------------------------------------------
# Technology and Tool Evaluation Methods
# Approaches to studying the design, implementation, and impact of educational technologies, simulations, and instructional materials on student learning.
# ----------------------------------------------------------------------------------------------------
# Secondary Data Analysis and Theoretical Framework Application
# Methods involving the reanalysis of existing data sets and the application of educational psychology or other theoretical frameworks to interpret research findings.
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Review and clean the initial categories
#
# The classifier can also review and clean up the categories. Since the amount of tokens used for this process is negligible in the case of meta-categorization, we can run it on the initial categories just for the sake of it.

# %%
review_response = classifier.review_and_clean_categories(discovered_meta_categories)
reviewed_meta_categories = review_response.cleaned_categories
# Out:
# Category review using model: o3-mini
# Reviewing 9 categories
# Input tokens used: 906
# Output tokens used: 1379
# Review summary:
#   - Original categories: 9
#   - Cleaned categories: 8
#   - Removed categories: 1
#   - Merge suggestions: 0
#   - Removed: Secondary Data Analysis and Theoretical Framework Application

# %% [markdown]
# We can also save these if we'd like.

# %%
save_categories_to_json(reviewed_meta_categories, "./methods_data/reviewed_meta_categories.json")
# Out:
# Categories saved to ./methods_data/reviewed_meta_categories_20250807_191155.json

# %% [markdown]
# ### Run meta-categorization
#
# We can now run the classification on the frameworks using this set of meta-categories.
#
# #### Cost estimate
#
# Let us first estimate the cost of running our classifier with the selected models.

# %%
cost_classifier = CostEstimationWrapper(classifier)

estimates = cost_classifier.estimate_full_workflow(research_methods, reviewed_meta_categories, preped_discovery_data)
display(Markdown(cost_classifier.generate_cost_report(estimates)))
# Out:
# # Cost Estimation Report
# Generated: 2025-08-06 23:35:44
#
# ## Category Discovery
#
# - **Cost**: $0.0219
# - **Model**: gpt-4.1
# - **Input Tokens**: 7,619
# - **Output Tokens**: 830
#
# ## Category Review
#
# - **Cost**: $0.0004
# - **Model**: o3-mini
# - **Input Tokens**: 525
# - **Output Tokens**: 470
#
# ## Batch Classification
#
# - **Total Cost**: $0.2255
# - **Items Processed**: 135
# - **Average Cost per Item**: $0.0017
# - **Total Input Tokens**: 69,546
# - **Total Output Tokens**: 10,800
#
# ## Summary
#
# - **Total Estimated Cost**: $0.2477
# - **Total Input Tokens**: 77,690
# - **Total Output Tokens**: 12,100
#
# *Note: These are estimates based on current pricing and may vary.*

# %% [markdown]
# #### Classifying

# %%
classification_response = classifier.batch_classify(research_methods, reviewed_meta_categories, "balanced")
# Out:
# Processing element 1/44
# Input tokens used: 691
# Output tokens used: 63
# Processing element 2/44
# Input tokens used: 689
# Output tokens used: 63
# Processing element 3/44
# Input tokens used: 692
# Output tokens used: 102
# Processing element 4/44
# Input tokens used: 686
# Output tokens used: 65
# Processing element 5/44
# Input tokens used: 690
# Output tokens used: 90
# Processing element 6/44
# Input tokens used: 688
# Output tokens used: 61
# Processing element 7/44
# Input tokens used: 691
# Output tokens used: 90
# Processing element 8/44
# Input tokens used: 691
# Output tokens used: 133
# Processing element 9/44
# Input tokens used: 694
# Output tokens used: 89
# Processing element 10/44
# Input tokens used: 693
# Output tokens used: 70
# Processing element 11/44
# Input tokens used: 687
# Output tokens used: 57
# Processing element 12/44
# Input tokens used: 692
# Output tokens used: 59
# Processing element 13/44
# Input tokens used: 693
# Output tokens used: 65
# Processing element 14/44
# Input tokens used: 690
# Output tokens used: 57
# Processing element 15/44
# Input tokens used: 696
# Output tokens used: 63
# Processing element 16/44
# Input tokens used: 699
# Output tokens used: 98
# Processing element 17/44
# Input tokens used: 692
# Output tokens used: 67
# Processing element 18/44
# Input tokens used: 693
# Output tokens used: 65
# Processing element 19/44
# Input tokens used: 695
# Output tokens used: 75
# Processing element 20/44
# Input tokens used: 693
# Output tokens used: 57
# Processing element 21/44
# Input tokens used: 705
# Output tokens used: 55
# Processing element 22/44
# Input tokens used: 703
# Output tokens used: 73
# Processing element 23/44
# Input tokens used: 711
# Output tokens used: 40
# Processing element 24/44
# Input tokens used: 711
# Output tokens used: 95
# Processing element 25/44
# Input tokens used: 703
# Output tokens used: 111
# Added new category: Data Collection Methods
# Processing element 26/44
# Input tokens used: 732
# Output tokens used: 57
# Processing element 27/44
# Input tokens used: 730
# Output tokens used: 59
# Processing element 28/44
# Input tokens used: 734
# Output tokens used: 86
# Processing element 29/44
# Input tokens used: 732
# Output tokens used: 54
# Processing element 30/44
# Input tokens used: 730
# Output tokens used: 59
# Processing element 31/44
# Input tokens used: 740
# Output tokens used: 80
# Processing element 32/44
# Input tokens used: 741
# Output tokens used: 64
# Processing element 33/44
# Input tokens used: 758
# Output tokens used: 70
# Processing element 34/44
# Input tokens used: 755
# Output tokens used: 57
# Processing element 35/44
# Input tokens used: 723
# Output tokens used: 49
# Processing element 36/44
# Input tokens used: 727
# Output tokens used: 65
# Processing element 37/44
# Input tokens used: 756
# Output tokens used: 130
# Added new category: Positionality and Identity Reflexivity Methods
# Processing element 38/44
# Input tokens used: 784
# Output tokens used: 74
# Processing element 39/44
# Input tokens used: 795
# Output tokens used: 74
# Processing element 40/44
# Input tokens used: 791
# Output tokens used: 68
# Processing element 41/44
# Input tokens used: 799
# Output tokens used: 74
# Processing element 42/44
# Input tokens used: 786
# Output tokens used: 67
# Processing element 43/44
# Input tokens used: 814
# Output tokens used: 116
# Processing element 44/44
# Input tokens used: 790
# Output tokens used: 67

# %%
classification = classification_response[0]
extended_categories = classification_response[1]

len(extended_categories)
categories_diff = len(extended_categories) - len(discovered_meta_categories)
print(f"{categories_diff} new meta-categories generated during classification!")
# Out:
# 1 new meta-categories generated during classification!

# %% [markdown]
# ### Analyzing
#
# With these classifications of the frameworks, we can now see if we can find any patterns using these meta-categories.
#
# Let us first add a new column to our dataframe. For this, we need a mapping from frameworks to meta-categories.

# %%
category_mapping = {}

for cat in classification:
    cat_title = cat[0].title
    cat_prob = cat[1].probabilities  # This is a list of ProbabilityScore objects
    # Find the ProbabilityScore object with the highest probability
    max_prob_obj = max(cat_prob, key=lambda p: p.probability)
    category_mapping[cat_title] = max_prob_obj.category

methods_df_merged['classification_meta_framework_category'] = methods_df_merged['method_highest_prob_gpt-4.1-mini'].map(lambda el: [el])

# Use a set in order to make it only unique values.
# methods_df_merged['classification_meta_framework_category'] = methods_df_merged['method_classifications_gpt-4.1-mini'].map(lambda r: set([category_mapping.get(el) for el in r]))

# %%
for el in methods_df_merged["classification_meta_framework_category"]:
    print(el)
# Out:
# ['Tutorial Implementation']
# ['Demonstration-Based Tasks']
# ['Demonstration-Based Tasks']
# ['Experimental Design in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Video Data Collection and Analysis']
# ['Experimental Apparatus and Materials']
# ['Experimental Apparatus and Materials']
# ['Experimental Apparatus and Materials']
# ['Experimental Apparatus and Materials']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Homework and Quiz Study Methods']
# ['Course Environment Analysis']
# ['Multiple-Choice Instrument Analysis']
# ['Animation-Based Assessment']
# ['Test Statistical Evaluation']
# ['Homework and Quiz Study Methods']
# ['Tutorial Implementation']
# ['Analogical Scaffolding in Instruction']
# ['Multiple-Choice Instrument Analysis']
# ['Test Statistical Evaluation']
# ['Assessment Development and Validation']
# ['Assessment Development and Validation']
# ['Course and Curriculum Design']
# ['Tutorial Implementation']
# ['Instructional Study Methods in Physics Education']
# ['Demonstration-Based Tasks']
# ['Tutorial Implementation']
# ['Video Data Collection and Analysis']
# ['Video Data Collection and Analysis']
# ['Course Environment Analysis']
# ['Homework and Quiz Study Methods']
# ['Assessment Development and Validation']
# ['Experimental Design in Physics Education']
# ['Student Learning and Reasoning Studies']
# ['Tutorial Implementation']
# ['Homework and Quiz Study Methods']
# ['Analogical Scaffolding in Instruction']
# ['Video Data Collection and Analysis']
# ['Instructor Interview Studies']
# ['Instructor Interview Studies']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Tutorial Implementation']
# ['Tutorial Implementation']
# ['Student Reasoning and Coding in Physics Education']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Student Reasoning and Coding in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Cluster Analysis and Student Conceptual Patterns']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Video Data Collection and Analysis']
# ['Student Learning and Reasoning Studies']
# ['Test Statistical Evaluation']
# ['Experimental Design in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Homework and Quiz Study Methods']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Tutorial Implementation']
# ['Qualitative Interview Methodology in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Video Data Collection and Analysis']
# ['Student Reasoning and Coding in Physics Education']
# ['Course Environment Analysis']
# ['Student Reasoning and Coding in Physics Education']
# ['Course and Curriculum Design']
# ['Student Learning and Reasoning Studies']
# ['Survey Methodology in Physics Education']
# ['Tutorial Implementation']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Course Environment Analysis']
# ['Analogical Scaffolding in Instruction']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Multiple-Choice Instrument Analysis']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Tutorial Implementation']
# ['Course and Curriculum Design']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Course and Curriculum Design']
# ['Survey Methodology in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Course Environment Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Tutorial Implementation']
# ['Survey Methodology in Physics Education']
# ['Course Environment Analysis']
# ['Student Reasoning and Coding in Physics Education']
# ['Tutorial Implementation']
# ['Video Data Collection and Analysis']
# ['Survey Methodology in Physics Education']
# ['Tutorial Implementation']
# ['Video Data Collection and Analysis']
# ['Video Data Collection and Analysis']
# ['Course Environment Analysis']
# ['Multiple-Choice Instrument Analysis']
# ['Course and Curriculum Design']
# ['Course Environment Analysis']
# ['Instructor Interview Studies']
# ['Survey Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Homework and Quiz Study Methods']
# ['Survey Methodology in Physics Education']
# ['Video Data Collection and Analysis']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Course and Curriculum Design']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructional Study Methods in Physics Education']
# ['Pedagogical Interventions and Tools']
# ['Assessment Development and Validation']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Course and Curriculum Design']
# ['Course and Curriculum Design']
# ['Course and Curriculum Design']
# ['Instructional Study Methods in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Tutorial Implementation']
# ['Qualitative Interview Methodology in Physics Education']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Assessment Development and Validation']
# ['Experimental Design in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Experimental Design in Physics Education']
# ['Tutorial Implementation']
# ['Homework and Quiz Study Methods']
# ['Course Environment Analysis']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Tutorial Implementation']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Course and Curriculum Design']
# ['Tutorial Implementation']
# ['Course and Curriculum Design']
# ['Assessment Development and Validation']
# ['Tutorial Implementation']
# ['Tutorial Implementation']
# ['Multiple-Choice Instrument Analysis']
# ['Course Environment Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Multiple-Choice Instrument Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Tutorial Implementation']
# ['Experimental Design in Physics Education']
# ['Course and Curriculum Design']
# ['Course and Curriculum Design']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Experimental Design in Physics Education']
# ['Assessment Development and Validation']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Student Learning and Reasoning Studies']
# ['Homework and Quiz Study Methods']
# ['Student Reasoning and Coding in Physics Education']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Tutorial Implementation']
# ['Survey Methodology in Physics Education']
# ['Pedagogical Interventions and Tools']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Video Data Collection and Analysis']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Survey Methodology in Physics Education']
# ['Cluster Analysis and Student Conceptual Patterns']
# ['Tutorial Implementation']
# ['Survey Methodology in Physics Education']
# ['Course and Curriculum Design']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Survey Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Multiple-Choice Instrument Analysis']
# ['Pedagogical Interventions and Tools']
# ['Assessment Development and Validation']
# ['Ethnographic Observation and Field Notes Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructional Study Methods in Physics Education']
# ['Demonstration-Based Tasks']
# ['Video Data Collection and Analysis']
# ['Experimental Design in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Survey Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Homework and Quiz Study Methods']
# ['Course and Curriculum Design']
# ['Instructional Study Methods in Physics Education']
# ['Assessment Development and Validation']
# ['Experimental Design in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Experimental Design in Physics Education']
# ['Assessment Development and Validation']
# ['Qualitative Interview Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Cluster Analysis and Student Conceptual Patterns']
# ['Cluster Analysis and Student Conceptual Patterns']
# ['Experimental Design in Physics Education']
# ['Cluster Analysis and Student Conceptual Patterns']
# ['Homework and Quiz Study Methods']
# ['Experimental Design in Physics Education']
# ['Course Environment Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Pedagogical Interventions and Tools']
# ['Student Reasoning and Coding in Physics Education']
# ['Content Analysis in Physics Education']
# ['Assessment Development and Validation']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Tutorial Implementation']
# ['Qualitative Interview Methodology in Physics Education']
# ['Tutorial Implementation']
# ['Video Data Collection and Analysis']
# ['Survey Methodology in Physics Education']
# ['Video Data Collection and Analysis']
# ['Course Environment Analysis']
# ['Multiple-Choice Instrument Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructor Interview Studies']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Experimental Design in Physics Education']
# ['Test Statistical Evaluation']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructor Interview Studies']
# ['Instructional Study Methods in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Student Learning and Reasoning Studies']
# ['Homework and Quiz Study Methods']
# ['Experimental Design in Physics Education']
# ['Demonstration-Based Tasks']
# ['Pedagogical Interventions and Tools']
# ['Video Data Collection and Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Tutorial Implementation']
# ['Tutorial Implementation']
# ['Student Learning and Reasoning Studies']
# ['Demonstration-Based Tasks']
# ['Tutorial Implementation']
# ['Instructional Practice Comparative Study']
# ['Homework and Quiz Study Methods']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Student Learning and Reasoning Studies']
# ['Survey Methodology in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Course Environment Analysis']
# ['Assessment Development and Validation']
# ['Assessment Development and Validation']
# ['Course Environment Analysis']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Assessment Development and Validation']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Course Environment Analysis']
# ['Ethnographic Observation and Field Notes Analysis']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Course Environment Analysis']
# ['Ethnographic Observation and Field Notes Analysis']
# ['Assessment Development and Validation']
# ['Tutorial Implementation']
# ['Course and Curriculum Design']
# ['Multiple-Choice Instrument Analysis']
# ['Experimental Design in Physics Education']
# ['Assessment Development and Validation']
# ['Multiple-Choice Instrument Analysis']
# ['Survey Methodology in Physics Education']
# ['Course Environment Analysis']
# ['Assessment Development and Validation']
# ['Course and Curriculum Design']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Video Data Collection and Analysis']
# ['Student Learning and Reasoning Studies']
# ['Experimental Design in Physics Education']
# ['Video Data Collection and Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Test Statistical Evaluation']
# ['Multiple-Choice Instrument Analysis']
# ['Survey Methodology in Physics Education']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Data Collection Methods in Physics Education']
# ['Student Learning and Reasoning Studies']
# ['Course and Curriculum Design']
# ['Assessment Development and Validation']
# ['Experimental Design in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Course and Curriculum Design']
# ['Assessment Development and Validation']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Video Data Collection and Analysis']
# ['Homework and Quiz Study Methods']
# ['Tutorial Implementation']
# ['Test Statistical Evaluation']
# ['Experimental Design in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Experimental Design in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Course Environment Analysis']
# ['Experimental Design in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Student Reasoning and Coding in Physics Education']
# ['Ethnographic Observation and Field Notes Analysis']
# ['Video Data Collection and Analysis']
# ['Assessment Development and Validation']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Ethnographic Observation and Field Notes Analysis']
# ['Content Analysis in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Pedagogical Interventions and Tools']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Qualitative Interview Methodology in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Tutorial Implementation']
# ['Qualitative Interview Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Course and Curriculum Design']
# ['Classroom Implementation and Instructional Strategies']
# ['Experimental Apparatus and Materials']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructional Context Description']
# ['Course and Curriculum Design']
# ['Instructional Context Description']
# ['Qualitative Interview Methodology in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Tutorial Implementation']
# ['Instructional Context Description']
# ['Course and Curriculum Design']
# ['Assessment Development and Validation']
# ['Course and Curriculum Design']
# ['Course and Curriculum Design']
# ['Instructional Context Description']
# ['Tutorial Implementation']
# ['Student Reasoning and Coding in Physics Education']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Student Reasoning and Coding in Physics Education']
# ['Experimental Design in Physics Education']
# ['Assessment Development and Validation']
# ['Student Reasoning and Coding in Physics Education']
# ['Student Learning and Reasoning Studies']
# ['Student Reasoning and Coding in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Test Statistical Evaluation']
# ['Instructional Context Description']
# ['Tutorial Implementation']
# ['Pedagogical Interventions and Tools']
# ['Experimental Design in Physics Education']
# ['Assessment Development and Validation']
# ['Qualitative Interview Methodology in Physics Education']
# ['Course and Curriculum Design']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructional Context Description']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructor Interview Studies']
# ['Usability and Learning Technology Studies']
# ['Homework and Quiz Study Methods']
# ['Experimental Design in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Multiple-Choice Instrument Analysis']
# ['Multiple-Choice Instrument Analysis']
# ['Multiple-Choice Instrument Analysis']
# ['Assessment Development and Validation']
# ['Video Data Collection and Analysis']
# ['Instructor Interview Studies']
# ['Instructional Context Description']
# ['Video Data Collection and Analysis']
# ['Instructional Context Description']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructional Context Description']
# ['Instructor Interview Studies']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Content Analysis in Physics Education']
# ['Experimental Design in Physics Education']
# ['Assessment Development and Validation']
# ['Pedagogical Interventions and Tools']
# ['Assessment Development and Validation']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Course Environment Analysis']
# ['Student Reasoning and Coding in Physics Education']
# ['Instructional Context Description']
# ['Instructional Study Methods in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Course and Curriculum Design']
# ['Assessment Development and Validation']
# ['Student Learning and Reasoning Studies']
# ['Student Learning and Reasoning Studies']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Instructional Study Methods in Physics Education']
# ['Assessment Development and Validation']
# ['Instructional Context Description']
# ['Demonstration-Based Tasks']
# ['Ethnographic Observation and Field Notes Analysis']
# ['Course Environment Analysis']
# ['Experimental Design in Physics Education']
# ['Assessment Development and Validation']
# ['Instructional Context Description']
# ['Survey Methodology in Physics Education']
# ['Student Learning and Reasoning Studies']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructional Context Description']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Multiple-Choice Instrument Analysis']
# ['Survey Methodology in Physics Education']
# ['Test Statistical Evaluation']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructional Context Description']
# ['Survey Methodology in Physics Education']
# ['Course Environment Analysis']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Assessment Development and Validation']
# ['Instructor Interview Studies']
# ['Student Reasoning and Coding in Physics Education']
# ['Instructional Context Description']
# ['Survey Methodology in Physics Education']
# ['Course Environment Analysis']
# ['Instructional Practice Comparative Study']
# ['Instructor Interview Studies']
# ['Tutorial Implementation']
# ['Assessment Development and Validation']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Test Statistical Evaluation']
# ['Multiple-Choice Instrument Analysis']
# ['Survey Methodology in Physics Education']
# ['Instructional Study Methods in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Pedagogical Interventions and Tools']
# ['Instructor Interview Studies']
# ['Survey Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Assessment Development and Validation']
# ['Instructional Context Description']
# ['Course and Curriculum Design']
# ['Video Data Collection and Analysis']
# ['Instructional Context Description']
# ['Assessment Development and Validation']
# ['Demonstration-Based Tasks']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructional Study Methods in Physics Education']
# ['Instructional Context Description']
# ['Instructor Interview Studies']
# ['Multiple-Choice Instrument Analysis']
# ['Experimental Design in Physics Education']
# ['Video Data Collection and Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Ethnographic Observation and Field Notes Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Course and Curriculum Design']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Demonstration-Based Tasks']
# ['Survey Methodology in Physics Education']
# ['Instructional Context Description']
# ['Assessment Development and Validation']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Student Reasoning and Coding in Physics Education']
# ['Pedagogical Interventions and Tools']
# ['Assessment Development and Validation']
# ['Assessment Development and Validation']
# ['Assessment Development and Validation']
# ['Data Collection Methods in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Homework and Quiz Study Methods']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructional Context Description']
# ['Course and Curriculum Design']
# ['Student Reasoning and Coding in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Tutorial Implementation']
# ['Homework and Quiz Study Methods']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Instructional Context Description']
# ['Homework and Quiz Study Methods']
# ['Assessment Development and Validation']
# ['Assessment Development and Validation']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructional Study Methods in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Pedagogical Interventions and Tools']
# ['Video Data Collection and Analysis']
# ['Instructional Context Description']
# ['Video Data Collection and Analysis']
# ['Experimental Design in Physics Education']
# ['Video Data Collection and Analysis']
# ['Video Data Collection and Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Test Statistical Evaluation']
# ['Multiple-Choice Instrument Analysis']
# ['Assessment Development and Validation']
# ['Assessment Development and Validation']
# ['Assessment Development and Validation']
# ['Test Statistical Evaluation']
# ['Course Environment Analysis']
# ['Survey Methodology in Physics Education']
# ['Instructional Study Methods in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructional Context Description']
# ['Test Statistical Evaluation']
# ['Assessment Development and Validation']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Instructional Context Description']
# ['Video Data Collection and Analysis']
# ['Assessment Development and Validation']
# ['Assessment Development and Validation']
# ['Experimental Design in Physics Education']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Test Statistical Evaluation']
# ['Course and Curriculum Design']
# ['Student Reasoning and Coding in Physics Education']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Course and Curriculum Design']
# ['Homework and Quiz Study Methods']
# ['Qualitative Interview Methodology in Physics Education']
# ['Animation-Based Assessment']
# ['Student Reasoning and Coding in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Instructor Interview Studies']
# ['Instructor Interview Studies']
# ['Multiple-Choice Instrument Analysis']
# ['Experimental Design in Physics Education']
# ['Course and Curriculum Design']
# ['Data Collection Methods in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Course and Curriculum Design']
# ['Data Collection Methods in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Video Data Collection and Analysis']
# ['Video Data Collection and Analysis']
# ['Test Statistical Evaluation']
# ['Assessment Development and Validation']
# ['Student Reasoning and Coding in Physics Education']
# ['Pedagogical Interventions and Tools']
# ['Experimental Design in Physics Education']
# ['Test Statistical Evaluation']
# ['Cluster Analysis and Student Conceptual Patterns']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Course and Curriculum Design']
# ['Experimental Design in Physics Education']
# ['Course and Curriculum Design']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Tutorial Implementation']
# ['Student Learning and Reasoning Studies']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Test Statistical Evaluation']
# ['Instructional Context Description']
# ['Survey Methodology in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Multiple-Choice Instrument Analysis']
# ['Multiple-Choice Instrument Analysis']
# ['Instructional Context Description']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Instructional Context Description']
# ['Homework and Quiz Study Methods']
# ['Homework and Quiz Study Methods']
# ['Classroom Implementation and Instructional Strategies']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Assessment Development and Validation']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Course and Curriculum Design']
# ['Qualitative Interview Methodology in Physics Education']
# ['Ethnographic Observation and Field Notes Analysis']
# ['Instructional Context Description']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructional Context Description']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Test Statistical Evaluation']
# ['Course and Curriculum Design']
# ['Instructional Context Description']
# ['Mixed-Methods Study: Simulation and Qualitative Coding']
# ['Qualitative Interview Methodology in Physics Education']
# ['Course and Curriculum Design']
# ['Instructional Context Description']
# ['Survey Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Test Statistical Evaluation']
# ['Assessment Development and Validation']
# ['Survey Methodology in Physics Education']
# [None]
# ['Data Collection Methods in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Assessment Development and Validation']
# ['Longitudinal Case Study']
# ['Course Environment Analysis']
# ['Social Network Analysis in Physics Education']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Experimental Design in Physics Education']
# ['Tutorial Implementation']
# ['Student Reasoning and Coding in Physics Education']
# ['Assessment Development and Validation']
# ['Statistical Analysis in Physics Education']
# ['Instructor Interview Studies']
# ['Homework and Quiz Study Methods']
# ['Survey Methodology in Physics Education']
# ['Instructional Context Description']
# ['Qualitative Interview Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Survey Methodology in Physics Education']
# ['Ethnographic Observation and Field Notes Analysis']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Student Reasoning and Coding in Physics Education']
# ['Data Collection Methods in Physics Education']
# ['Tutorial Implementation']
# ['Course and Curriculum Design']
# ['Survey Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Assessment Development and Validation']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Test Statistical Evaluation']
# ['Survey Methodology in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Instructional Context Description']
# ['Survey Methodology in Physics Education']
# ['Content Analysis in Physics Education']
# ['Instructional Study Methods in Physics Education']
# ['Demonstration-Based Tasks']
# ['Demonstration-Based Tasks']
# ['Student Reasoning and Coding in Physics Education']
# ['Assessment Development and Validation']
# ['Statistical Analysis in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Assessment Development and Validation']
# ['Tutorial Implementation']
# ['Tutorial Implementation']
# ['Survey Methodology in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Multiple-Choice Instrument Analysis']
# ['Instructional Context Description']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Multiple-Choice Instrument Analysis']
# ['Multiple-Choice Instrument Analysis']
# ['Student Reasoning and Coding in Physics Education']
# ['Course and Curriculum Design']
# ['Qualitative Interview Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Course Environment Analysis']
# ['Statistical Analysis in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Assessment Development and Validation']
# ['Course and Curriculum Design']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Qualitative Interview Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Homework and Quiz Study Methods']
# ['Content Analysis in Physics Education']
# ['Assessment Development and Validation']
# ['Demonstration-Based Tasks']
# ['Student Reasoning and Coding in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Demonstration-Based Tasks']
# ['Instructional Context Description']
# ['Experimental Design in Physics Education']
# ['Pedagogical Interventions and Tools']
# ['Content Analysis in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Social Network Analysis in Physics Education']
# ['Experimental Design in Physics Education']
# ['Course Environment Analysis']
# ['Statistical Analysis in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Assessment Development and Validation']
# ['Student Reasoning and Coding in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Cluster Analysis and Student Conceptual Patterns']
# ['Cluster Analysis and Student Conceptual Patterns']
# ['Cluster Analysis and Student Conceptual Patterns']
# ['Cluster Analysis and Student Conceptual Patterns']
# ['Statistical Analysis in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Positionality and Identity Reflection in Physics Education Research']
# ['Qualitative Interview Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Test Statistical Evaluation']
# ['Assessment Development and Validation']
# ['Survey Methodology in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Design-Based Research Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructional Context Description']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructional Context Description']
# ['Course and Curriculum Design']
# ['Student Reasoning and Coding in Physics Education']
# ['Assessment Development and Validation']
# ['Multiple-Choice Instrument Analysis']
# ['Content Analysis in Physics Education']
# ['Tutorial Implementation']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Test Statistical Evaluation']
# ['Test Statistical Evaluation']
# ['Survey Methodology in Physics Education']
# ['Student Learning and Reasoning Studies']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Instructional Context Description']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Qualitative Interview Methodology in Physics Education']
# ['Mixed-Methods Study: Simulation and Qualitative Coding']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Course and Curriculum Design']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Social Network Analysis in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Multiple-Choice Instrument Analysis']
# ['Experimental Design in Physics Education']
# ['Demonstration-Based Tasks']
# ['Assessment Development and Validation']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Course and Curriculum Design']
# ['Secondary Data Analysis in Physics Education Research']
# ['Multiple-Choice Instrument Analysis']
# ['Experimental Design in Physics Education']
# ['Secondary Data Analysis in Physics Education Research']
# ['Multiple-Choice Instrument Analysis']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Experimental Design in Physics Education']
# ['Instructional Context Description']
# ['Qualitative Interview Methodology in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Instructor Interview Studies']
# ['Assessment Development and Validation']
# ['Assessment Development and Validation']
# ['Assessment Development and Validation']
# ['Statistical Analysis in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Experimental Design in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Qualitative Interview Methodology in Physics Education']
# ['Tutorial Implementation']
# ['Pedagogical Interventions and Tools']
# ['Instructor Interview Studies']
# ['Qualitative Interview Methodology in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Assessment Development and Validation']
# ['Data Collection Methods in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Survey Methodology in Physics Education']
# ['Demonstration-Based Tasks']
# ['Assessment Development and Validation']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Statistical Analysis in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructional Context Description']
# ['Qualitative Interview Methodology in Physics Education']
# ['Course Environment Analysis']
# ['Experimental Design in Physics Education']
# ['Assessment Development and Validation']
# ['Statistical Analysis in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Secondary Data Analysis in Physics Education Research']
# ['Qualitative Interview Methodology in Physics Education']
# ['Course and Curriculum Design']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Survey Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Instructor Interview Studies']
# ['Assessment Development and Validation']
# ['Tutorial Implementation']
# ['Assessment Development and Validation']
# ['Assessment Development and Validation']
# ['Assessment Development and Validation']
# ['Instructional Study Methods in Physics Education']
# ['Experimental Design in Physics Education']
# ['Tutorial Implementation']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Course Environment Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Instructional Context Description']
# ['Qualitative Interview Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Test Statistical Evaluation']
# ['Test Statistical Evaluation']
# ['Survey Methodology in Physics Education']
# ['Animation-Based Assessment']
# ['Survey Methodology in Physics Education']
# ['Secondary Data Analysis in Physics Education Research']
# ['Pedagogical Interventions and Tools']
# ['Tutorial Implementation']
# ['Survey Methodology in Physics Education']
# ['Social Network Analysis in Physics Education']
# ['Secondary Data Analysis in Physics Education Research']
# ['Qualitative Interview Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Assessment Development and Validation']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Assessment Development and Validation']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructional Context Description']
# ['Course and Curriculum Design']
# ['Instructional Context Description']
# ['Course and Curriculum Design']
# ['Course and Curriculum Design']
# ['Design-Based Research Methodology in Physics Education']
# ['Design-Based Research Methodology in Physics Education']
# ['Design-Based Research Methodology in Physics Education']
# ['Course and Curriculum Design']
# ['Instructional Context Description']
# ['Course and Curriculum Design']
# ['Positionality and Identity Reflection in Physics Education Research']
# ['Course and Curriculum Design']
# ['Instructional Context Description']
# ['Instructional Context Description']
# ['Course and Curriculum Design']
# ['Instructional Study Methods in Physics Education']
# ['Course and Curriculum Design']
# ['Multiple-Choice Instrument Analysis']
# ['Instructional Context Description']
# ['Instructional Context Description']
# ['Instructional Study Methods in Physics Education']
# ['Course and Curriculum Design']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Student Learning and Reasoning Studies']
# ['Pedagogical Interventions and Tools']
# ['Course and Curriculum Design']
# ['Qualitative Interview Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructional Context Description']
# ['Student Reasoning and Coding in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Instructional Context Description']
# ['Survey Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Ethnographic Observation and Field Notes Analysis']
# ['Assessment Development and Validation']
# ['Assessment Development and Validation']
# ['Statistical Analysis in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Course and Curriculum Design']
# ['Statistical Analysis in Physics Education']
# ['Experimental Design in Physics Education']
# ['Course and Curriculum Design']
# ['Experimental Design in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Statistical Analysis in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Instructor Interview Studies']
# ['Qualitative Interview Methodology in Physics Education']
# ['Content Analysis in Physics Education']
# ['Test Statistical Evaluation']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Experimental Design in Physics Education']
# ['Cluster Analysis and Student Conceptual Patterns']
# ['Statistical Analysis in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Student Reasoning and Coding in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Instructional Study Methods in Physics Education']
# ['Experimental Design in Physics Education']
# ['Demonstration-Based Tasks']
# ['Course Environment Analysis']
# ['Multiple-Choice Instrument Analysis']
# ['Homework and Quiz Study Methods']
# ['Test Statistical Evaluation']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Assessment Development and Validation']
# ['Instructor Interview Studies']
# ['Course Environment Analysis']
# ['Instructional Context Description']
# ['Homework and Quiz Study Methods']
# ['Qualitative Interview Methodology in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Student Reasoning and Coding in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Survey Methodology in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Secondary Data Analysis in Physics Education Research']
# ['Mixed-Methods Study: Simulation and Qualitative Coding']
# ['Instructional Context Description']
# ['Video Data Collection and Analysis']
# ['Homework and Quiz Study Methods']
# ['Multiple-Choice Instrument Analysis']
# ['Survey Methodology in Physics Education']
# [None]
# ['Statistical Analysis in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Secondary Data Analysis in Physics Education Research']
# ['Statistical Analysis in Physics Education']
# ['Experimental Design in Physics Education']
# ['Instructional Study Methods in Physics Education']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Course and Curriculum Design']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Instructional Context Description']
# ['Course and Curriculum Design']
# ['Laboratory Instruction and Student Activities Analysis']
# ...
# ['Qualitative Interview Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Experimental Design in Physics Education']
# ['Case Study Analysis in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Student Learning and Reasoning Studies']
# ['Tutorial Implementation']
# ['Tutorial Implementation']
# ['Assessment Development and Validation']
# ['Survey Methodology in Physics Education']
# ['Social Network Analysis in Physics Education']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Assessment Development and Validation']
# ['Statistical Analysis in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Content Analysis in Physics Education']
# ['Case Study Analysis in Physics Education']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Assessment Development and Validation']
# ['Instructional Context Description']
# ['Qualitative Interview Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Assessment Development and Validation']
# ['Assessment Development and Validation']
# ['Statistical Analysis in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Demonstration-Based Tasks']
# ['Demonstration-Based Tasks']
# ['Qualitative Interview Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Course and Curriculum Design']
# ['Course and Curriculum Design']
# ['Positionality and Identity Reflection in Physics Education Research']
# ['Experimental Design in Physics Education']
# ['Course Environment Analysis']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Instructional Context Description']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Qualitative Interview Methodology in Physics Education']
# ['Secondary Data Analysis in Physics Education Research']
# ['Qualitative Interview Methodology in Physics Education']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Student Learning and Reasoning Studies']
# ['Student Reasoning and Coding in Physics Education']
# ['Course and Curriculum Design']
# ['Course and Curriculum Design']
# ['Qualitative Interview Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Content Analysis in Physics Education']
# ['Instructional Context Description']
# ['Survey Methodology in Physics Education']
# ['Social Network Analysis in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Data Collection Methods in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Course and Curriculum Design']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Instructor Interview Studies']
# ['Social Network Analysis in Physics Education']
# ['Social Network Analysis in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Video Data Collection and Analysis']
# ['Assessment Development and Validation']
# ['Survey Methodology in Physics Education']
# ['Instructor Interview Studies']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Course and Curriculum Design']
# ['Course and Curriculum Design']
# ['Course and Curriculum Design']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Design-Based Research Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Homework and Quiz Study Methods']
# ['Student Reasoning and Coding in Physics Education']
# ['Instructional Context Description']
# ['Instructional Context Description']
# ['Experimental Design in Physics Education']
# ['Pedagogical Interventions and Tools']
# ['Instructional Context Description']
# ['Homework and Quiz Study Methods']
# ['Instructional Context Description']
# ['Homework and Quiz Study Methods']
# ['Qualitative Interview Methodology in Physics Education']
# ['Secondary Data Analysis in Physics Education Research']
# ['Student Reasoning and Coding in Physics Education']
# ['Course Environment Analysis']
# ['Instructional Context Description']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Statistical Analysis in Physics Education']
# ['Case Study Analysis in Physics Education']
# ['Content Analysis in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Design-Based Research Methodology in Physics Education']
# ['Mixed-Methods Study: Simulation and Qualitative Coding']
# ['Test Statistical Evaluation']
# ['Secondary Data Analysis in Physics Education Research']
# ['Course and Curriculum Design']
# ['Tutorial Implementation']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Positionality and Identity Reflection in Physics Education Research']
# ['Qualitative Interview Methodology in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Case Study Analysis in Physics Education']
# ['Experimental Design in Physics Education']
# ['Assessment Development and Validation']
# ['Secondary Data Analysis in Physics Education Research']
# ['Multiple-Choice Instrument Analysis']
# ['Instructor Interview Studies']
# ['Tutorial Implementation']
# ['Assessment Development and Validation']
# ['Tutorial Implementation']
# ['Video Data Collection and Analysis']
# ['Homework and Quiz Study Methods']
# ['Demonstration-Based Tasks']
# ['Multiple-Choice Instrument Analysis']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Course Environment Analysis']
# ['Assessment Development and Validation']
# ['Survey Methodology in Physics Education']
# ['Cross-Sequential Longitudinal Study Design']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Assessment Development and Validation']
# ['Student Reasoning and Coding in Physics Education']
# ['Instructional Context Description']
# ['Video Data Collection and Analysis']
# ['Demonstration-Based Tasks']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Course and Curriculum Design']
# ['Homework and Quiz Study Methods']
# ['Survey Methodology in Physics Education']
# ['Instructional Context Description']
# ['Survey Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Instructional Context Description']
# ['Instructional Study Methods in Physics Education']
# ['Ethnographic Observation and Field Notes Analysis']
# ['Survey Methodology in Physics Education']
# ['Social Network Analysis in Physics Education']
# ['Course and Curriculum Design']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Statistical Analysis in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Course and Curriculum Design']
# ['Usability and Learning Technology Studies']
# ['Assessment Development and Validation']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Cross-Sequential Longitudinal Study Design']
# ['Mixed-Methods Study: Simulation and Qualitative Coding']
# ['Instructional Context Description']
# ['Design-Based Research Methodology in Physics Education']
# ['Design-Based Research Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Secondary Data Analysis in Physics Education Research']
# ['Multiple-Choice Instrument Analysis']
# ['Multiple-Choice Instrument Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Longitudinal Case Study']
# ['Multiple-Choice Instrument Analysis']
# ['Survey Methodology in Physics Education']
# ['Positionality and Identity Reflection in Physics Education Research']
# ['Qualitative Interview Methodology in Physics Education']
# ['Content Analysis in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Student Reasoning and Coding in Physics Education']
# ['Design-Based Research Methodology in Physics Education']
# ['Instructional Context Description']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Assessment Development and Validation']
# ['Instructional Context Description']
# ['Pedagogical Interventions and Tools']
# ['Survey Methodology in Physics Education']
# ['Course Environment Analysis']
# ['Professional Development in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Content Analysis in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Student Reasoning and Coding in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Secondary Data Analysis in Physics Education Research']
# ['Secondary Data Analysis in Physics Education Research']
# ['Case Study Analysis in Physics Education']
# ['Instructional Context Description']
# ['Instructional Context Description']
# ['Content Analysis in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Instructor Interview Studies']
# ['Experimental Design in Physics Education']
# ['Pedagogical Interventions and Tools']
# ['Experimental Design in Physics Education']
# ['Course and Curriculum Design']
# ['Qualitative Interview Methodology in Physics Education']
# ['Content Analysis in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Social Network Analysis in Physics Education']
# ['Instructional Context Description']
# ['Survey Methodology in Physics Education']
# ['Reasoning Chain Construction and Network Analysis in Physics Education']
# ['Assessment Development and Validation']
# ['Statistical Analysis in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Homework and Quiz Study Methods']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Test Statistical Evaluation']
# ['Qualitative Interview Methodology in Physics Education']
# ['Video Data Collection and Analysis']
# ['Survey Methodology in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Design-Based Research Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Experimental Design in Physics Education']
# ['Tutorial Implementation']
# ['Professional Development in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Instructional Context Description']
# ['Experimental Design in Physics Education']
# ['Instructional Context Description']
# ['Experimental Design in Physics Education']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Positionality and Identity Reflection in Physics Education Research']
# ['Survey Methodology in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Mixed-Methods Study: Simulation and Qualitative Coding']
# ['Assessment Development and Validation']
# ['Mixed-Methods Study: Simulation and Qualitative Coding']
# ['Survey Methodology in Physics Education']
# ['Homework and Quiz Study Methods']
# ['Experimental Design in Physics Education']
# ['Assessment Development and Validation']
# ['Homework and Quiz Study Methods']
# ['Simulation and Demonstration-Based Instructional Design']
# ['Social Network Analysis in Physics Education']
# ['Student Reasoning and Coding in Physics Education']
# ['Demonstration-Based Tasks']
# ['Assessment Development and Validation']
# ['Assessment Development and Validation']
# ['Survey Methodology in Physics Education']
# ['Assessment Development and Validation']
# ['Video Data Collection and Analysis']
# ['Experimental Design in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Multiple-Choice Instrument Analysis']
# ['Qualitative Interview Methodology in Physics Education']
# ['Course and Curriculum Design']
# ['Instructional Context Description']
# ['Experimental Design in Physics Education']
# ['Survey Methodology in Physics Education']
# ['Professional Development in Physics Education']
# ['Case Study Analysis in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Qualitative Interview Methodology in Physics Education']
# ['Pedagogical Interventions and Tools']
# ['Laboratory Instruction and Student Activities Analysis']
# ['Tutorial Implementation']
# ['Case Study Analysis in Physics Education']
# ['Professional Development in Physics Education']

# %%
reversed_map = {}

for key,val in category_mapping.items():
    reversed_map.setdefault(val, []).append(key)

# with open(create_timestamped_path("./methods_data/research_methods_meta_map.json"), "w") as fp:
#     json.dump(reversed_map, fp)


# pd.DataFrame({"Meta Category":reversed_map.keys(), "Frameworks": reversed_map.values()})

# %% [markdown]
# Using this, we can now plot the development over time.

# %%
import plotly.express as px
from LLM_classifier.utils import create_timestamped_path
import pandas as pd # It's good practice to import pandas

# Ensure the relevant columns exist
category_col = "classification_meta_framework_category"
year_col = 'article_year'

# 1. Start with the original DataFrame and drop rows with NaN values
plot_df = methods_df_merged.dropna(subset=[category_col, year_col]).copy()

# 2. Filter out rows where the category_col list is empty.
#    The condition is changed to > 0 to KEEP rows with non-empty lists.
is_not_empty_mask = plot_df[category_col].str.len() > 0
plot_df = plot_df[is_not_empty_mask].copy()

print(f"Number of sections: {len(plot_df)}")

# 3. THE KEY STEP: Explode the DataFrame.
#    This creates a new row for each category in the list, repeating the year.
plot_df = plot_df.explode(category_col)

print(f"Number of exploded entries: {len(plot_df)}")

# 4. Convert year to integer
plot_df[year_col] = plot_df[year_col].astype(int)

# 5. Get category counts. This groupby now works correctly on the exploded data.
category_counts = (
    plot_df.groupby([year_col, category_col])
    .size()
    .reset_index(name='count')
)

# 6. Create interactive plot (This part remains the same)
fig = px.line(
    category_counts,
    x=year_col,
    y='count',
    color=category_col,
    markers=True,
    labels={
        year_col: 'Year',
        'count': 'Number of Sections',
        category_col: 'Methods Category'
    },
    title='Methods Category Counts by Year (Exploded Data)'
)

fig.update_layout(
    legend_title_text='Methods Category',
    legend=dict(
        orientation="v",
        yanchor="top",
        y=1,
        xanchor="left",
        x=1.01
    ),
    width=1000,
    height=500
)

# output_path = create_timestamped_path("plotly_method_year_exploded.html")
# fig.write_html(output_path)
# print(f"Plot saved to: {output_path}")
fig.show()
# Out:
# Number of sections: 1541
# Number of exploded entries: 1541
