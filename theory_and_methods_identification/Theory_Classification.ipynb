# %% [markdown]
# # Theory Framework Classification Using Section Classifier Framework
#
# This notebook demonstrates the use of the new section classifier framework for analyzing theoretical frameworks in physics education research articles.

# %% [markdown]
# ## Initial Setup

# %%
import pandas as pd

# Add parent directory to path to import local modules
# sys.path.insert(0, r"C:/Users/sfgar/programing/INTED-article-splitting/__computational_essays/python_code")

from LLM_classifier import (
    load_categories_from_json,
    save_categories_to_json,
    create_timestamped_path,
    CostEstimationWrapper
)
from theory_classifiers import FrameworkClassifier

import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from python_code import helpers

from IPython.display import Markdown

# %%
api_key = helpers.safe_load_env_variable("OPENAI_API_KEY", "../.env.secret")
# Initialize the classifier with loaded frameworks
classifier = FrameworkClassifier(
    api_key = api_key,
    temperature=0.6,
    max_tokens=15000,
    general_model="gpt-4.1-mini",
    reasoning_model="o3-mini"
)

# %% [markdown]
# ## Data loading

# %%
# Load the data
df = pd.read_pickle("../section_type_classification/data/classified_sections_light_gpt-4.1-mini_20250716_122412.pkl")

# Load existing theory categories
frameworks = load_categories_from_json("./theory_data/reviewed_categories_20250721_163329.json")
# Out:
# Successfully loaded 135 categories from ./reviewed_categories_20250721_163329.json

# %% [markdown]
# ## Filter Theoretical Framework Sections

# %%
# Helper function to filter DataFrame by category
def filter_df_by_category(
    df,
    value: str,
    column: str = "classification_highest_prob_gpt-4.1-mini"
):
    """
    Returns a DataFrame filtered to only rows where the specified column matches the given value.
    """
    mask = df[column] == value
    return df[mask].copy()

# Filter for theoretical framework sections
theory_df = filter_df_by_category(df, "Theoretical Framework")
print(f"Found {len(theory_df)} theoretical framework sections")
# Out:
# Found 589 theoretical framework sections

# %% [markdown]
# ## Batch Classify Sections

# %% [markdown]
# #### Estimate costs

# %%
cost_estimator = CostEstimationWrapper(classifier)

data = classifier._df_to_sections(theory_df)

est = cost_estimator.estimate_full_workflow(data, frameworks)

display(Markdown(cost_estimator.generate_cost_report(est)))
# Out:
# # Cost Estimation Report
# Generated: 2025-08-06 00:21:54
#
# ## Category Review
#
# - **Cost**: $0.0029
# - **Model**: o3-mini
# - **Input Tokens**: 6,589
# - **Output Tokens**: 3,170
#
# ## Batch Classification
#
# - **Total Cost**: $1.3243
# - **Items Processed**: 589
# - **Average Cost per Item**: $0.0022
# - **Total Input Tokens**: 5,108,903
# - **Total Output Tokens**: 47,120
#
# ## Summary
#
# - **Total Estimated Cost**: $1.3272
# - **Total Input Tokens**: 5,115,492
# - **Total Output Tokens**: 50,290
#
# *Note: These are estimates based on current pricing and may vary.*

# %% [markdown]
# #### Do the actual classification

# %% [markdown]
# Run the classification. the `category_creation_temperature` parampeter decides how aggressive the model is in creating new categories.

# %%
# Prepare the DataFrame for batch classification
# theory_batch_df = theory_df[['article_id', 'section_title', 'section_content']].copy()

# Process a subset of sections for testing
# test_size = 2
# print(f"\nProcessing {test_size} sections as a test...")

# Run batch classification
result_df, updated_categories = classifier.batch_classify_sections_df(theory_df, frameworks, category_creation_temperature="locked")
# Out:
# Processing element 1/589
# Input tokens used: 10897
# Output tokens used: 312
# Processing element 2/589
# Input tokens used: 8171
# Output tokens used: 298
# Processing element 3/589
# Input tokens used: 7453
# Output tokens used: 307
# Processing element 4/589
# Input tokens used: 8160
# Output tokens used: 149
# Processing element 5/589
# Input tokens used: 7584
# Output tokens used: 141
# Processing element 6/589
# Input tokens used: 8749
# Output tokens used: 272
# Classifications contains values that does not exist as category: ['Conceptual Change Theory']
# Probability distribution contains keys that are not available category: ['Conceptual Change Theory']
# Retrying 2/5...
# Input tokens used: 8785
# Output tokens used: 329
# Classifications contains values that does not exist as category: ['Conceptual Change Theory']
# Probability distribution contains keys that are not available category: ['Conceptual Change Theory']
# Retrying 3/5...
# Input tokens used: 8821
# Output tokens used: 283
# Classifications contains values that does not exist as category: ['Conceptual Change Theory']
# Probability distribution contains keys that are not available category: ['Conceptual Change Theory']
# Retrying 4/5...
# Input tokens used: 8857
# Output tokens used: 337
# Processing element 7/589
# Input tokens used: 9173
# Output tokens used: 188
# Processing element 8/589
# Input tokens used: 7777
# Output tokens used: 358
# Processing element 9/589
# Input tokens used: 8219
# Output tokens used: 149
# Processing element 10/589
# Input tokens used: 7213
# Output tokens used: 221
# Processing element 11/589
# Input tokens used: 10457
# Output tokens used: 254
# Processing element 12/589
# Input tokens used: 12332
# Output tokens used: 297
# Processing element 13/589
# Input tokens used: 8256
# Output tokens used: 357
# Processing element 14/589
# Input tokens used: 11476
# Output tokens used: 463
# Processing element 15/589
# Input tokens used: 9798
# Output tokens used: 327
# Processing element 16/589
# Input tokens used: 10948
# Output tokens used: 393
# Processing element 17/589
# Input tokens used: 7501
# Output tokens used: 452
# Processing element 18/589
# Input tokens used: 7048
# Output tokens used: 144
# Processing element 19/589
# Input tokens used: 7693
# Output tokens used: 404
# Processing element 20/589
# Input tokens used: 7587
# Output tokens used: 235
# Processing element 21/589
# Input tokens used: 7604
# Output tokens used: 341
# Classifications contains values that does not exist as category: ['Item Response Theory (IRT) Modeling']
# Probability distribution contains keys that are not available category: ['Item Response Theory (IRT) Modeling']
# Retrying 2/5...
# Input tokens used: 7646
# Output tokens used: 297
# Processing element 22/589
# Input tokens used: 9236
# Output tokens used: 288
# Processing element 23/589
# Input tokens used: 10171
# Output tokens used: 514
# Processing element 24/589
# Input tokens used: 8496
# Output tokens used: 84
# Processing element 25/589
# Input tokens used: 8576
# Output tokens used: 146
# Processing element 26/589
# Input tokens used: 7534
# Output tokens used: 155
# Processing element 27/589
# Input tokens used: 7368
# Output tokens used: 191
# Processing element 28/589
# Input tokens used: 7845
# Output tokens used: 392
# Processing element 29/589
# Input tokens used: 12101
# Output tokens used: 322
# Classifications contains values that does not exist as category: ['Resource Theory']
# Probability distribution contains keys that are not available category: ['Resource Theory']
# Retrying 2/5...
# Input tokens used: 12133
# Output tokens used: 129
# Processing element 30/589
# Input tokens used: 8470
# Output tokens used: 536
# Processing element 31/589
# Input tokens used: 7220
# Output tokens used: 107
# Processing element 32/589
# Input tokens used: 8881
# Output tokens used: 267
# Processing element 33/589
# Input tokens used: 8519
# Output tokens used: 517
# Classifications contains values that does not exist as category: ['Action Research']
# Probability distribution contains keys that are not available category: ['Action Research']
# Retrying 2/5...
# Input tokens used: 8551
# Output tokens used: 318
# Classifications contains values that does not exist as category: ['Action Research Framework']
# Probability distribution contains keys that are not available category: ['Action Research Framework']
# Retrying 3/5...
# Input tokens used: 8585
# Output tokens used: 411
# Classifications contains values that does not exist as category: ['Action Research Framework']
# Probability distribution contains keys that are not available category: ['Action Research Framework']
# Retrying 4/5...
# Input tokens used: 8619
# Output tokens used: 376
# Classifications contains values that does not exist as category: ['Action research']
# Probability distribution contains keys that are not available category: ['Action research']
# Retrying 5/5...
# Couldn't make a valid classification, returning empty!
# Processing element 34/589
# Input tokens used: 9102
# Output tokens used: 1259
# Processing element 35/589
# Input tokens used: 9864
# Output tokens used: 265
# Processing element 36/589
# Input tokens used: 8226
# Output tokens used: 523
# Processing element 37/589
# Input tokens used: 8631
# Output tokens used: 116
# Processing element 38/589
# Input tokens used: 10756
# Output tokens used: 153
# Processing element 39/589
# Input tokens used: 9148
# Output tokens used: 337
# Processing element 40/589
# Input tokens used: 9128
# Output tokens used: 183
# Processing element 41/589
# Input tokens used: 8455
# Output tokens used: 275
# Processing element 42/589
# Input tokens used: 6967
# Output tokens used: 402
# Processing element 43/589
# Input tokens used: 7001
# Output tokens used: 191
# Processing element 44/589
# Input tokens used: 7731
# Output tokens used: 223
# Processing element 45/589
# Input tokens used: 11271
# Output tokens used: 383
# Processing element 46/589
# Input tokens used: 10577
# Output tokens used: 413
# Processing element 47/589
# Input tokens used: 7890
# Output tokens used: 171
# Processing element 48/589
# Input tokens used: 10059
# Output tokens used: 255
# Processing element 49/589
# Input tokens used: 7579
# Output tokens used: 121
# Processing element 50/589
# Input tokens used: 6987
# Output tokens used: 223
# Processing element 51/589
# Input tokens used: 8003
# Output tokens used: 261
# Processing element 52/589
# Input tokens used: 8212
# Output tokens used: 172
# Processing element 53/589
# Input tokens used: 7542
# Output tokens used: 282
# Processing element 54/589
# Input tokens used: 7675
# Output tokens used: 340
# Processing element 55/589
# Input tokens used: 13339
# Output tokens used: 297
# Processing element 56/589
# Input tokens used: 7074
# Output tokens used: 201
# Processing element 57/589
# Input tokens used: 8986
# Output tokens used: 506
# Processing element 58/589
# Input tokens used: 8238
# Output tokens used: 328
# Processing element 59/589
# Input tokens used: 7732
# Output tokens used: 147
# Processing element 60/589
# Input tokens used: 9121
# Output tokens used: 643
# Classifications contains values that does not exist as category: ['Pedagogical Content Knowledge (PCK) Framework']
# Probability distribution contains keys that are not available category: ['Pedagogical Content Knowledge (PCK) Framework']
# Retrying 2/5...
# Input tokens used: 9169
# Output tokens used: 742
# Classifications contains values that does not exist as category: ['Pedagogical Content Knowledge (PCK) Framework']
# Probability distribution contains keys that are not available category: ['Pedagogical Content Knowledge (PCK) Framework']
# Retrying 3/5...
# Input tokens used: 9217
# Output tokens used: 535
# Processing element 61/589
# Input tokens used: 6992
# Output tokens used: 121
# Processing element 62/589
# Input tokens used: 7530
# Output tokens used: 795
# Processing element 63/589
# Input tokens used: 7421
# Output tokens used: 445
# Processing element 64/589
# Input tokens used: 9302
# Output tokens used: 351
# Classifications contains values that does not exist as category: ['Conceptual Change Theory']
# Retrying 2/5...
# Input tokens used: 9333
# Output tokens used: 143
# Processing element 65/589
# Input tokens used: 7177
# Output tokens used: 242
# Processing element 66/589
# Input tokens used: 8750
# Output tokens used: 255
# Processing element 67/589
# Input tokens used: 7190
# Output tokens used: 241
# Processing element 68/589
# Input tokens used: 8165
# Output tokens used: 326
# Processing element 69/589
# Input tokens used: 8207
# Output tokens used: 473
# Processing element 70/589
# Input tokens used: 9646
# Output tokens used: 449
# Classifications contains values that does not exist as category: ['Motivation and Emotions Framework (Self-Determination Theory)']
# Probability distribution contains keys that are not available category: ['Motivation and Emotions Framework (Self-Determination Theory)']
# Retrying 2/5...
# Input tokens used: 9696
# Output tokens used: 416
# Classifications contains values that does not exist as category: ['Motivation and Emotions Framework']
# Probability distribution contains keys that are not available category: ['Motivation and Emotions Framework']
# Retrying 3/5...
# Input tokens used: 9734
# Output tokens used: 491
# Processing element 71/589
# Input tokens used: 6932
# Output tokens used: 237
# Processing element 72/589
# Input tokens used: 8226
# Output tokens used: 499
# Processing element 73/589
# Input tokens used: 7778
# Output tokens used: 347
# Classifications contains values that does not exist as category: ['Cognitive Psychology Framework', 'Behaviorist Learning Theory Framework']
# Probability distribution contains keys that are not available category: ['Cognitive Psychology Framework', 'Behaviorist Learning Theory Framework']
# Retrying 2/5...
# Input tokens used: 7824
# Output tokens used: 285
# Classifications contains values that does not exist as category: ['Cognitive Psychology Framework', 'Behaviorist Learning Theory Framework']
# Probability distribution contains keys that are not available category: ['Cognitive Psychology Framework', 'Behaviorist Learning Theory Framework']
# Retrying 3/5...
# Input tokens used: 7870
# Output tokens used: 342
# Classifications contains values that does not exist as category: ['Cognitive Psychology Framework']
# Probability distribution contains keys that are not available category: ['Cognitive Psychology Framework']
# Retrying 4/5...
# Input tokens used: 7904
# Output tokens used: 209
# Processing element 74/589
# Input tokens used: 10487
# Output tokens used: 347
# Processing element 75/589
# Input tokens used: 7781
# Output tokens used: 372
# Processing element 76/589
# Input tokens used: 9048
# Output tokens used: 365
# Processing element 77/589
# Input tokens used: 7748
# Output tokens used: 318
# Processing element 78/589
# Input tokens used: 8398
# Output tokens used: 364
# Classifications contains values that does not exist as category: ['Graph Theory and Network Analysis (implied within Mathematical Modeling Framework)']
# Probability distribution contains keys that are not available category: ['Graph Theory and Network Analysis (implied within Mathematical Modeling Framework)']
# Retrying 2/5...
# Input tokens used: 8450
# Output tokens used: 265
# Processing element 79/589
# Input tokens used: 10304
# Output tokens used: 310
# Classifications contains values that does not exist as category: ["Sfard's Process-Object Duality (part of Constructivism Framework)", 'Representations and Mental Models in Physics Education']
# Retrying 2/5...
# Input tokens used: 10355
# Output tokens used: 299
# Processing element 80/589
# Input tokens used: 7562
# Output tokens used: 131
# Processing element 81/589
# Input tokens used: 7944
# Output tokens used: 372
# Processing element 82/589
# Input tokens used: 8589
# Output tokens used: 138
# Processing element 83/589
# Input tokens used: 9098
# Output tokens used: 442
# Processing element 84/589
# Input tokens used: 12192
# Output tokens used: 430
# Processing element 85/589
# Input tokens used: 10121
# Output tokens used: 375
# Processing element 86/589
# Input tokens used: 9733
# Output tokens used: 270
# Processing element 87/589
# Input tokens used: 9121
# Output tokens used: 275
# Processing element 88/589
# Input tokens used: 8764
# Output tokens used: 280
# Classifications contains values that does not exist as category: ['Data Visualization in Science Education']
# Probability distribution contains keys that are not available category: ['Data Visualization in Science Education']
# Retrying 2/5...
# Input tokens used: 8802
# Output tokens used: 181
# Classifications contains values that does not exist as category: ['Statistical Data Analysis Framework']
# Probability distribution contains keys that are not available category: ['Statistical Data Analysis Framework']
# Retrying 3/5...
# Input tokens used: 8838
# Output tokens used: 205
# Processing element 89/589
# Input tokens used: 9846
# Output tokens used: 94
# Classifications contains values that does not exist as category: ['Quantum Mechanics Conceptual Framework']
# Probability distribution contains keys that are not available category: ['Quantum Mechanics Conceptual Framework']
# Retrying 2/5...
# Input tokens used: 9884
# Output tokens used: 140
# Processing element 90/589
# Input tokens used: 10483
# Output tokens used: 189
# Processing element 91/589
# Input tokens used: 7170
# Output tokens used: 242
# Processing element 92/589
# Input tokens used: 7882
# Output tokens used: 316
# Processing element 93/589
# Input tokens used: 10669
# Output tokens used: 278
# Processing element 94/589
# Input tokens used: 8432
# Output tokens used: 303
# Classifications contains values that does not exist as category: ['Expectancy Violation Framework (communication research)']
# Probability distribution contains keys that are not available category: ['Expectancy Violation Framework (communication research)']
# Retrying 2/5...
# Input tokens used: 8476
# Output tokens used: 532
# Processing element 95/589
# Input tokens used: 8082
# Output tokens used: 237
# Processing element 96/589
# Input tokens used: 10239
# Output tokens used: 598
# Processing element 97/589
# Input tokens used: 7925
# Output tokens used: 557
# Classifications contains values that does not exist as category: ['Mental Models Framework']
# Probability distribution contains keys that are not available category: ['Mental Models Framework']
# Retrying 2/5...
# Input tokens used: 7959
# Output tokens used: 328
# Processing element 98/589
# Input tokens used: 7180
# Output tokens used: 379
# Processing element 99/589
# Input tokens used: 7983
# Output tokens used: 145
# Processing element 100/589
# Input tokens used: 7375
# Output tokens used: 185
# Processing element 101/589
# Input tokens used: 8676
# Output tokens used: 374
# Processing element 102/589
# Input tokens used: 8697
# Output tokens used: 339
# Processing element 103/589
# Input tokens used: 7092
# Output tokens used: 221
# Processing element 104/589
# Input tokens used: 8394
# Output tokens used: 326
# Classifications contains values that does not exist as category: ['Actor-Network Theory']
# Probability distribution contains keys that are not available category: ['Actor-Network Theory']
# Retrying 2/5...
# Input tokens used: 8430
# Output tokens used: 388
# Processing element 105/589
# Input tokens used: 8275
# Output tokens used: 247
# Processing element 106/589
# Input tokens used: 7123
# Output tokens used: 129
# Processing element 107/589
# Input tokens used: 7501
# Output tokens used: 219
# Processing element 108/589
# Input tokens used: 7884
# Output tokens used: 654
# Processing element 109/589
# Input tokens used: 8136
# Output tokens used: 474
# Processing element 110/589
# Input tokens used: 11153
# Output tokens used: 110
# Processing element 111/589
# Input tokens used: 8490
# Output tokens used: 372
# Classifications contains values that does not exist as category: ['Cognitive Task Analysis']
# Probability distribution contains keys that are not available category: ['Cognitive Task Analysis']
# Retrying 2/5...
# Input tokens used: 8524
# Output tokens used: 130
# Processing element 112/589
# Input tokens used: 7217
# Output tokens used: 249
# Classifications contains values that does not exist as category: ['Peer Instruction Framework']
# Probability distribution contains keys that are not available category: ['Peer Instruction Framework']
# Retrying 2/5...
# Input tokens used: 7251
# Output tokens used: 239
# Processing element 113/589
# Input tokens used: 9194
# Output tokens used: 353
# Processing element 114/589
# Input tokens used: 11459
# Output tokens used: 451
# Processing element 115/589
# Input tokens used: 8254
# Output tokens used: 370
# Processing element 116/589
# Input tokens used: 8645
# Output tokens used: 271
# Processing element 117/589
# Input tokens used: 10276
# Output tokens used: 127
# Processing element 118/589
# Input tokens used: 8543
# Output tokens used: 339
# Processing element 119/589
# Input tokens used: 8424
# Output tokens used: 166
# Processing element 120/589
# Input tokens used: 14142
# Output tokens used: 501
# Processing element 121/589
# Input tokens used: 7852
# Output tokens used: 235
# Processing element 122/589
# Input tokens used: 7587
# Output tokens used: 337
# Processing element 123/589
# Input tokens used: 8190
# Output tokens used: 631
# Classifications contains values that does not exist as category: ['Conceptual Change Theory', 'Sociocultural Identity and Learning Framework (represented by Sociocultural Theory)', 'Dialogic Learning Framework (Bakhtinian Dialogism)', 'Dynamic Contextual Learning Framework (combining Cognitivist and Sociocultural)']
# Probability distribution contains keys that are not available category: ['Conceptual Change Theory', 'Sociocultural Identity and Learning Framework (represented by Sociocultural Theory)', 'Dialogic Learning Framework (Bakhtinian Dialogism)', 'Dynamic Contextual Learning Framework (combining Cognitivist and Sociocultural)']
# Retrying 2/5...
# Input tokens used: 8310
# Output tokens used: 929
# Processing element 124/589
# Input tokens used: 8323
# Output tokens used: 287
# Processing element 125/589
# Input tokens used: 8695
# Output tokens used: 476
# Processing element 126/589
# Input tokens used: 8939
# Output tokens used: 444
# Processing element 127/589
# Input tokens used: 7879
# Output tokens used: 169
# Processing element 128/589
# Input tokens used: 7468
# Output tokens used: 276
# Classifications contains values that does not exist as category: ['Semiotics and Multimedia Learning Theory']
# Retrying 2/5...
# Input tokens used: 7501
# Output tokens used: 288
# Classifications contains values that does not exist as category: ['Cognitive Psychology Framework', 'Semiotics Framework']
# Probability distribution contains keys that are not available category: ['Semiotics and Multimodality']
# Retrying 3/5...
# Input tokens used: 7543
# Output tokens used: 304
# Processing element 129/589
# Input tokens used: 8435
# Output tokens used: 406
# Processing element 130/589
# Input tokens used: 7845
# Output tokens used: 280
# Classifications contains values that does not exist as category: ['Conceptual Blending Theory']
# Probability distribution contains keys that are not available category: ['Conceptual Blending Theory']
# Retrying 2/5...
# Input tokens used: 7883
# Output tokens used: 224
# Processing element 131/589
# Input tokens used: 7632
# Output tokens used: 192
# Processing element 132/589
# Input tokens used: 9930
# Output tokens used: 323
# Processing element 133/589
# Input tokens used: 7412
# Output tokens used: 354
# Processing element 134/589
# Input tokens used: 11500
# Output tokens used: 397
# Processing element 135/589
# Input tokens used: 9679
# Output tokens used: 315
# Classifications contains values that does not exist as category: ['Social Network Theory']
# Probability distribution contains keys that are not available category: ['Social Network Theory']
# Retrying 2/5...
# Input tokens used: 9713
# Output tokens used: 195
# Processing element 136/589
# Input tokens used: 10698
# Output tokens used: 368
# Processing element 137/589
# Input tokens used: 7885
# Output tokens used: 220
# Processing element 138/589
# Input tokens used: 7753
# Output tokens used: 142
# Processing element 139/589
# Input tokens used: 7903
# Output tokens used: 245
# Processing element 140/589
# Input tokens used: 8777
# Output tokens used: 343
# Processing element 141/589
# Input tokens used: 8221
# Output tokens used: 286
# Processing element 142/589
# Input tokens used: 7591
# Output tokens used: 296
# Processing element 143/589
# Input tokens used: 7161
# Output tokens used: 281
# Classifications contains values that does not exist as category: ['Moderate Constructivism Framework']
# Probability distribution contains keys that are not available category: ['Moderate Constructivism Framework']
# Retrying 2/5...
# Input tokens used: 7199
# Output tokens used: 100
# Processing element 144/589
# Input tokens used: 9123
# Output tokens used: 339
# Processing element 145/589
# Input tokens used: 8050
# Output tokens used: 262
# Processing element 146/589
# Input tokens used: 7370
# Output tokens used: 280
# Classifications contains values that does not exist as category: ['Moderate Constructivism Framework', 'Science Learning and Teaching Framework (implied)']
# Probability distribution contains keys that are not available category: ['Moderate Constructivism Framework', 'Science Learning and Teaching Framework (implied)']
# Retrying 2/5...
# Input tokens used: 7426
# Output tokens used: 349
# Classifications contains values that does not exist as category: ['Conceptual Change Theory']
# Probability distribution contains keys that are not available category: ['Conceptual Change Theory']
# Retrying 3/5...
# Input tokens used: 7462
# Output tokens used: 117
# Classifications contains values that does not exist as category: ['Moderate Constructivism Framework']
# Probability distribution contains keys that are not available category: ['Moderate Constructivism Framework']
# Retrying 4/5...
# Input tokens used: 7500
# Output tokens used: 118
# Processing element 147/589
# Input tokens used: 8283
# Output tokens used: 277
# Processing element 148/589
# Input tokens used: 9518
# Output tokens used: 545
# Classifications contains values that does not exist as category: ['Cognitive Abilities Framework']
# Probability distribution contains keys that are not available category: ['Cognitive Abilities Framework']
# Retrying 2/5...
# Input tokens used: 9554
# Output tokens used: 202
# Processing element 149/589
# Input tokens used: 9054
# Output tokens used: 235
# Processing element 150/589
# Input tokens used: 10403
# Output tokens used: 369
# Processing element 151/589
# Input tokens used: 7314
# Output tokens used: 273
# Processing element 152/589
# Input tokens used: 7444
# Output tokens used: 342
# Processing element 153/589
# Input tokens used: 7847
# Output tokens used: 191
# Processing element 154/589
# Input tokens used: 7820
# Output tokens used: 427
# Processing element 155/589
# Input tokens used: 10288
# Output tokens used: 334
# Processing element 156/589
# Input tokens used: 7693
# Output tokens used: 230
# Processing element 157/589
# Input tokens used: 10875
# Output tokens used: 376
# Processing element 158/589
# Input tokens used: 7587
# Output tokens used: 370
# Processing element 159/589
# Input tokens used: 7468
# Output tokens used: 262
# Processing element 160/589
# Input tokens used: 8478
# Output tokens used: 236
# Processing element 161/589
# Input tokens used: 7889
# Output tokens used: 305
# Processing element 162/589
# Input tokens used: 7419
# Output tokens used: 389
# Classifications contains values that does not exist as category: ['Analogical Reasoning Framework (implied within Cognitive Frameworks)']
# Probability distribution contains keys that are not available category: ['Analogical Reasoning Framework (implied within Cognitive Frameworks)']
# Retrying 2/5...
# Input tokens used: 7471
# Output tokens used: 306
# Classifications contains values that does not exist as category: ['Cognitive Framework']
# Probability distribution contains keys that are not available category: ['Cognitive Framework']
# Retrying 3/5...
# Input tokens used: 7503
# Output tokens used: 221
# Processing element 163/589
# Input tokens used: 9742
# Output tokens used: 275
# Processing element 164/589
# Input tokens used: 10219
# Output tokens used: 362
# Processing element 165/589
# Input tokens used: 8429
# Output tokens used: 363
# Processing element 166/589
# Input tokens used: 10174
# Output tokens used: 333
# Processing element 167/589
# Input tokens used: 7482
# Output tokens used: 377
# Processing element 168/589
# Input tokens used: 8668
# Output tokens used: 305
# Classifications contains values that does not exist as category: ['Pedagogical Content Knowledge (PCK) Framework']
# Probability distribution contains keys that are not available category: ['Pedagogical Content Knowledge (PCK) Framework']
# Retrying 2/5...
# Input tokens used: 8716
# Output tokens used: 433
# Processing element 169/589
# Input tokens used: 8411
# Output tokens used: 396
# Processing element 170/589
# Input tokens used: 7683
# Output tokens used: 186
# Processing element 171/589
# Input tokens used: 8934
# Output tokens used: 232
# Processing element 172/589
# Input tokens used: 7316
# Output tokens used: 241
# Processing element 173/589
# Input tokens used: 7871
# Output tokens used: 407
# Processing element 174/589
# Input tokens used: 11203
# Output tokens used: 181
# Processing element 175/589
# Input tokens used: 9594
# Output tokens used: 333
# Processing element 176/589
# Input tokens used: 6982
# Output tokens used: 220
# Processing element 177/589
# Input tokens used: 8056
# Output tokens used: 263
# Processing element 178/589
# Input tokens used: 10497
# Output tokens used: 175
# Classifications contains values that does not exist as category: ['Cognitive Task Analysis', 'Modeling Framework']
# Probability distribution contains keys that are not available category: ['Cognitive Task Analysis', 'Modeling Framework']
# Retrying 2/5...
# Input tokens used: 10537
# Output tokens used: 308
# Processing element 179/589
# Input tokens used: 8515
# Output tokens used: 296
# Processing element 180/589
# Input tokens used: 8778
# Output tokens used: 253
# Processing element 181/589
# Input tokens used: 8008
# Output tokens used: 219
# Processing element 182/589
# Input tokens used: 7488
# Output tokens used: 170
# Processing element 183/589
# Input tokens used: 7343
# Output tokens used: 290
# Processing element 184/589
# Input tokens used: 9645
# Output tokens used: 168
# Processing element 185/589
# Input tokens used: 7193
# Output tokens used: 213
# Processing element 186/589
# Input tokens used: 7293
# Output tokens used: 293
# Processing element 187/589
# Input tokens used: 7441
# Output tokens used: 395
# Processing element 188/589
# Input tokens used: 11019
# Output tokens used: 392
# Processing element 189/589
# Input tokens used: 9106
# Output tokens used: 500
# Processing element 190/589
# Input tokens used: 8285
# Output tokens used: 506
# Processing element 191/589
# Input tokens used: 9124
# Output tokens used: 336
# Processing element 192/589
# Input tokens used: 7419
# Output tokens used: 339
# Processing element 193/589
# Input tokens used: 9283
# Output tokens used: 598
# Classifications contains values that does not exist as category: ['Social Cognitive Career Theory (SCCT) for Learning and Motivation']
# Probability distribution contains keys that are not available category: ['Social Cognitive Career Theory (SCCT) for Learning and Motivation']
# Retrying 2/5...
# Input tokens used: 9335
# Output tokens used: 128
# Classifications contains values that does not exist as category: ['Social Cognitive Career Theory (SCCT) for Learning and Motivation']
# Probability distribution contains keys that are not available category: ['Social Cognitive Career Theory (SCCT) for Learning and Motivation']
# Retrying 3/5...
# Input tokens used: 9387
# Output tokens used: 130
# Processing element 194/589
# Input tokens used: 9447
# Output tokens used: 425
# Processing element 195/589
# Input tokens used: 7699
# Output tokens used: 187
# Processing element 196/589
# Input tokens used: 8751
# Output tokens used: 347
# Classifications contains values that does not exist as category: ['Expectancy Violations Theory']
# Probability distribution contains keys that are not available category: ['Expectancy Violations Theory']
# Retrying 2/5...
# Input tokens used: 8789
# Output tokens used: 117
# Processing element 197/589
# Input tokens used: 8426
# Output tokens used: 225
# Processing element 198/589
# Input tokens used: 9288
# Output tokens used: 754
# Classifications contains values that does not exist as category: ['Pedagogical Content Knowledge (CKT) Framework']
# Probability distribution contains keys that are not available category: ['Pedagogical Content Knowledge (CKT) Framework']
# Retrying 2/5...
# Input tokens used: 9336
# Output tokens used: 605
# Classifications contains values that does not exist as category: ['Interactive Engagement Pedagogies', 'Peer Instruction']
# Probability distribution contains keys that are not available category: ['Interactive Engagement Pedagogies', 'Peer Instruction']
# Retrying 3/5...
# Input tokens used: 9380
# Output tokens used: 546
# Processing element 199/589
# Input tokens used: 8432
# Output tokens used: 647
# Processing element 200/589
# Input tokens used: 7265
# Output tokens used: 161
# Processing element 201/589
# Input tokens used: 8337
# Output tokens used: 537
# Processing element 202/589
# Input tokens used: 7760
# Output tokens used: 301
# Processing element 203/589
# Input tokens used: 7264
# Output tokens used: 239
# Processing element 204/589
# Input tokens used: 8025
# Output tokens used: 185
# Processing element 205/589
# Input tokens used: 8868
# Output tokens used: 369
# Processing element 206/589
# Input tokens used: 7933
# Output tokens used: 436
# Processing element 207/589
# Input tokens used: 7704
# Output tokens used: 182
# Processing element 208/589
# Input tokens used: 7637
# Output tokens used: 887
# Processing element 209/589
# Input tokens used: 8172
# Output tokens used: 359
# Processing element 210/589
# Input tokens used: 7609
# Output tokens used: 278
# Classifications contains values that does not exist as category: ['Peer Instruction Framework']
# Retrying 2/5...
# Input tokens used: 7639
# Output tokens used: 210
# Classifications contains values that does not exist as category: ['Peer Instruction Approach']
# Retrying 3/5...
# Input tokens used: 7669
# Output tokens used: 380
# Classifications contains values that does not exist as category: ['Peer Instruction (PI) is described as an active, peer-led discussion method to engage students in conceptual understanding and learning from each other, aligning with epistemological development in physics education.', 'The description emphasizes learning through peer interaction and engagement in a community of learners, characteristic of participationist perspectives.', 'Focus on reasoning through knowledge bases and conceptual understanding aligns with scientific reasoning aspects.']
# Retrying 4/5...
# Input tokens used: 7767
# Output tokens used: 355
# Processing element 211/589
# Input tokens used: 8313
# Output tokens used: 130
# Processing element 212/589
# Input tokens used: 9228
# Output tokens used: 327
# Processing element 213/589
# Input tokens used: 11357
# Output tokens used: 391
# Processing element 214/589
# Input tokens used: 7562
# Output tokens used: 595
# Processing element 215/589
# Input tokens used: 8067
# Output tokens used: 428
# Classifications contains values that does not exist as category: ['Knowledge in Pieces Framework', 'Mental Models Framework']
# Probability distribution contains keys that are not available category: ['Knowledge in Pieces Framework', 'Mental Models Framework']
# Retrying 2/5...
# Input tokens used: 8111
# Output tokens used: 209
# Processing element 216/589
# Input tokens used: 7870
# Output tokens used: 341
# Processing element 217/589
# Input tokens used: 7848
# Output tokens used: 301
# Processing element 218/589
# Input tokens used: 8007
# Output tokens used: 115
# Classifications contains values that does not exist as category: ['Quantum Mechanics Conceptual Framework']
# Probability distribution contains keys that are not available category: ['Quantum Mechanics Conceptual Framework']
# Retrying 2/5...
# Input tokens used: 8045
# Output tokens used: 155
# Processing element 219/589
# Input tokens used: 7481
# Output tokens used: 473
# Classifications contains values that does not exist as category: ["Zone of Proximal Development (ZPD) and Vygotsky's Sociocultural Theory"]
# Probability distribution contains keys that are not available category: ["Zone of Proximal Development (ZPD) and Vygotsky's Sociocultural Theory"]
# Retrying 2/5...
# Input tokens used: 7549
# Output tokens used: 343
# Processing element 220/589
# Input tokens used: 7205
# Output tokens used: 231
# Processing element 221/589
# Input tokens used: 7306
# Output tokens used: 302
# Processing element 222/589
# Input tokens used: 8629
# Output tokens used: 472
# Processing element 223/589
# Input tokens used: 7996
# Output tokens used: 349
# Processing element 224/589
# Input tokens used: 7847
# Output tokens used: 353
# Processing element 225/589
# Input tokens used: 8145
# Output tokens used: 501
# Classifications contains values that does not exist as category: ['Dynamic Systems Model of Role Identity']
# Probability distribution contains keys that are not available category: ['Dynamic Systems Model of Role Identity']
# Retrying 2/5...
# Input tokens used: 8185
# Output tokens used: 214
# Processing element 226/589
# Input tokens used: 9440
# Output tokens used: 160
# Processing element 227/589
# Input tokens used: 8523
# Output tokens used: 253
# Processing element 228/589
# Input tokens used: 9298
# Output tokens used: 151
# Processing element 229/589
# Input tokens used: 7871
# Output tokens used: 213
# Processing element 230/589
# Input tokens used: 8643
# Output tokens used: 441
# Processing element 231/589
# Input tokens used: 9563
# Output tokens used: 337
# Processing element 232/589
# Input tokens used: 8254
# Output tokens used: 199
# Processing element 233/589
# Input tokens used: 7772
# Output tokens used: 384
# Processing element 234/589
# Input tokens used: 8095
# Output tokens used: 317
# Processing element 235/589
# Input tokens used: 8509
# Output tokens used: 157
# Processing element 236/589
# Input tokens used: 7327
# Output tokens used: 151
# Processing element 237/589
# Input tokens used: 9354
# Output tokens used: 249
# Classifications contains values that does not exist as category: ['Cognitive Task Analysis of Troubleshooting']
# Probability distribution contains keys that are not available category: ['Cognitive Task Analysis of Troubleshooting']
# Retrying 2/5...
# Input tokens used: 9394
# Output tokens used: 237
# Processing element 238/589
# Input tokens used: 8074
# Output tokens used: 299
# Processing element 239/589
# Input tokens used: 9415
# Output tokens used: 280
# Processing element 240/589
# Input tokens used: 7713
# Output tokens used: 345
# Processing element 241/589
# Input tokens used: 7680
# Output tokens used: 191
# Processing element 242/589
# Input tokens used: 8905
# Output tokens used: 402
# Processing element 243/589
# Input tokens used: 9121
# Output tokens used: 212
# Processing element 244/589
# Input tokens used: 9783
# Output tokens used: 273
# Processing element 245/589
# Input tokens used: 8144
# Output tokens used: 363
# Processing element 246/589
# Input tokens used: 10474
# Output tokens used: 235
# Processing element 247/589
# Input tokens used: 7759
# Output tokens used: 527
# Classifications contains values that does not exist as category: ['Critical Thinking Framework']
# Probability distribution contains keys that are not available category: ['Critical Thinking Framework']
# Retrying 2/5...
# Input tokens used: 7793
# Output tokens used: 313
# Processing element 248/589
# Input tokens used: 8554
# Output tokens used: 483
# Processing element 249/589
# Input tokens used: 10083
# Output tokens used: 436
# Classifications contains values that does not exist as category: ['Conceptual Blending Framework']
# Probability distribution contains keys that are not available category: ['Conceptual Blending Framework']
# Retrying 2/5...
# Input tokens used: 10121
# Output tokens used: 284
# Processing element 250/589
# Input tokens used: 7719
# Output tokens used: 148
# Processing element 251/589
# Input tokens used: 7723
# Output tokens used: 288
# Processing element 252/589
# Input tokens used: 7770
# Output tokens used: 235
# Processing element 253/589
# Input tokens used: 10297
# Output tokens used: 449
# Classifications contains values that does not exist as category: ['Pedagogical Content Knowledge (PCK) Framework']
# Probability distribution contains keys that are not available category: ['Pedagogical Content Knowledge (PCK) Framework']
# Retrying 2/5...
# Input tokens used: 10345
# Output tokens used: 218
# Processing element 254/589
# Input tokens used: 7946
# Output tokens used: 324
# Classifications contains values that does not exist as category: ['Design-Based Research (DBR)']
# Probability distribution contains keys that are not available category: ['Design-Based Research (DBR)']
# Retrying 2/5...
# Input tokens used: 7986
# Output tokens used: 211
# Classifications contains values that does not exist as category: ['Design-Based Research (DBR)']
# Probability distribution contains keys that are not available category: ['Design-Based Research (DBR)']
# Retrying 3/5...
# Input tokens used: 8026
# Output tokens used: 181
# Processing element 255/589
# Input tokens used: 10715
# Output tokens used: 254
# Classifications contains values that does not exist as category: ['Design-Based Research (DBR) Framework']
# Probability distribution contains keys that are not available category: ['Design-Based Research (DBR) Framework']
# Retrying 2/5...
# Input tokens used: 10759
# Output tokens used: 173
# Processing element 256/589
# Input tokens used: 9147
# Output tokens used: 367
# Processing element 257/589
# Input tokens used: 8421
# Output tokens used: 335
# Processing element 258/589
# Input tokens used: 9068
# Output tokens used: 309
# Classifications contains values that does not exist as category: ['Moderate Constructivism Framework']
# Probability distribution contains keys that are not available category: ['Moderate Constructivism Framework']
# Retrying 2/5...
# Input tokens used: 9106
# Output tokens used: 346
# Processing element 259/589
# Input tokens used: 8828
# Output tokens used: 520
# Processing element 260/589
# Input tokens used: 8009
# Output tokens used: 222
# Processing element 261/589
# Input tokens used: 7341
# Output tokens used: 255
# Processing element 262/589
# Input tokens used: 7861
# Output tokens used: 410
# Processing element 263/589
# Input tokens used: 8565
# Output tokens used: 554
# Processing element 264/589
# Input tokens used: 7348
# Output tokens used: 262
# Processing element 265/589
# Input tokens used: 8295
# Output tokens used: 202
# Processing element 266/589
# Input tokens used: 9129
# Output tokens used: 154
# Processing element 267/589
# Input tokens used: 9077
# Output tokens used: 346
# Processing element 268/589
# Input tokens used: 8179
# Output tokens used: 472
# Processing element 269/589
# Input tokens used: 7285
# Output tokens used: 435
# Processing element 270/589
# Input tokens used: 7177
# Output tokens used: 194
# Processing element 271/589
# Input tokens used: 7721
# Output tokens used: 173
# Processing element 272/589
# Input tokens used: 7226
# Output tokens used: 99
# Processing element 273/589
# Input tokens used: 7548
# Output tokens used: 110
# Processing element 274/589
# Input tokens used: 7417
# Output tokens used: 169
# Processing element 275/589
# Input tokens used: 8721
# Output tokens used: 114
# Classifications contains values that does not exist as category: ['Modeling Framework']
# Probability distribution contains keys that are not available category: ['Modeling Framework']
# Retrying 2/5...
# Input tokens used: 8753
# Output tokens used: 155
# Processing element 276/589
# Input tokens used: 9345
# Output tokens used: 374
# Classifications contains values that does not exist as category: ['Legitimate Peripheral Participation', 'Disciplinary Practice Framework']
# Probability distribution contains keys that are not available category: ['Legitimate Peripheral Participation', 'Disciplinary Practice Framework']
# Retrying 2/5...
# Input tokens used: 9393
# Output tokens used: 303
# Processing element 277/589
# Input tokens used: 7547
# Output tokens used: 268
# Processing element 278/589
# Input tokens used: 7421
# Output tokens used: 135
# Processing element 279/589
# Input tokens used: 7574
# Output tokens used: 350
# Processing element 280/589
# Input tokens used: 8026
# Output tokens used: 185
# Classifications contains values that does not exist as category: ['Conceptual Change and Knowledge in Pieces Frameworks']
# Probability distribution contains keys that are not available category: ['Conceptual Change and Knowledge in Pieces Frameworks']
# Retrying 2/5...
# Input tokens used: 8072
# Output tokens used: 171
# Classifications contains values that does not exist as category: ['Conceptual Change and Knowledge in Pieces Frameworks']
# Probability distribution contains keys that are not available category: ['Conceptual Change and Knowledge in Pieces Frameworks']
# Retrying 3/5...
# Input tokens used: 8118
# Output tokens used: 355
# Classifications contains values that does not exist as category: ['Conceptual Change and Knowledge in Pieces Framework']
# Retrying 4/5...
# Input tokens used: 8153
# Output tokens used: 280
# Classifications contains values that does not exist as category: ['Conceptual Change and Knowledge in Pieces Framework', 'Conceptual Change and Knowledge in Pieces Framework']
# Retrying 5/5...
# Couldn't make a valid classification, returning empty!
# Processing element 281/589
# Input tokens used: 9930
# Output tokens used: 300
# Processing element 282/589
# Input tokens used: 8907
# Output tokens used: 352
# Processing element 283/589
# Input tokens used: 7509
# Output tokens used: 129
# Processing element 284/589
# Input tokens used: 8220
# Output tokens used: 227
# Processing element 285/589
# Input tokens used: 8656
# Output tokens used: 264
# Processing element 286/589
# Input tokens used: 9949
# Output tokens used: 312
# Processing element 287/589
# Input tokens used: 7710
# Output tokens used: 99
# Processing element 288/589
# Input tokens used: 8776
# Output tokens used: 178
# Processing element 289/589
# Input tokens used: 8400
# Output tokens used: 438
# Processing element 290/589
# Input tokens used: 8924
# Output tokens used: 453
# Classifications contains values that does not exist as category: ['Psychology Frameworks related to Identity and Motivation']
# Probability distribution contains keys that are not available category: ['Psychology Frameworks related to Identity and Motivation']
# Retrying 2/5...
# Input tokens used: 8968
# Output tokens used: 253
# Processing element 291/589
# Input tokens used: 8401
# Output tokens used: 292
# Processing element 292/589
# Input tokens used: 8421
# Output tokens used: 333
# Processing element 293/589
# Input tokens used: 9736
# Output tokens used: 676
# Processing element 294/589
# Input tokens used: 8920
# Output tokens used: 439
# Processing element 295/589
# Input tokens used: 7742
# Output tokens used: 242
# Classifications contains values that does not exist as category: ['Phenomenographic Learning Theory']
# Probability distribution contains keys that are not available category: ['Phenomenographic Learning Theory']
# Retrying 2/5...
# Input tokens used: 7780
# Output tokens used: 250
# Processing element 296/589
# Input tokens used: 14994
# Output tokens used: 888
# Classifications contains values that does not exist as category: ['Conceptual Change Theory']
# Probability distribution contains keys that are not available category: ['Conceptual Change Theory']
# Retrying 2/5...
# Input tokens used: 15030
# Output tokens used: 696
# Classifications contains values that does not exist as category: ['Conceptual Change Framework']
# Probability distribution contains keys that are not available category: ['Conceptual Change Framework']
# Retrying 3/5...
# Input tokens used: 15066
# Output tokens used: 473
# Classifications contains values that does not exist as category: ['Conceptual Change Theory']
# Probability distribution contains keys that are not available category: ['Conceptual Change Theory']
# Retrying 4/5...
# Input tokens used: 15102
# Output tokens used: 618
# Classifications contains values that does not exist as category: ['Conceptual Change Theory']
# Probability distribution contains keys that are not available category: ['Conceptual Change Theory']
# Retrying 5/5...
# Couldn't make a valid classification, returning empty!
# Processing element 297/589
# Input tokens used: 8297
# Output tokens used: 344
# Processing element 298/589
# Input tokens used: 8803
# Output tokens used: 179
# Processing element 299/589
# Input tokens used: 7941
# Output tokens used: 344
# Processing element 300/589
# Input tokens used: 8022
# Output tokens used: 249
# Processing element 301/589
# Input tokens used: 19891
# Output tokens used: 258
# Processing element 302/589
# Input tokens used: 12791
# Output tokens used: 552
# Classifications contains values that does not exist as category: ["Ainsworth's Design, Functions, and Tasks (DeFT) Framework"]
# Probability distribution contains keys that are not available category: ["Ainsworth's Design, Functions, and Tasks (DeFT) Framework"]
# Retrying 2/5...
# Input tokens used: 12849
# Output tokens used: 475
# Classifications contains values that does not exist as category: ["Ainsworth's Design, Functions, and Tasks (DeFT) Framework"]
# Probability distribution contains keys that are not available category: ["Ainsworth's Design, Functions, and Tasks (DeFT) Framework"]
# Retrying 3/5...
# Input tokens used: 12907
# Output tokens used: 346
# Processing element 303/589
# Input tokens used: 8222
# Output tokens used: 168
# Processing element 304/589
# Input tokens used: 7775
# Output tokens used: 376
# Processing element 305/589
# Input tokens used: 7753
# Output tokens used: 199
# Processing element 306/589
# Input tokens used: 11079
# Output tokens used: 414
# Classifications contains values that does not exist as category: ['Statistical Data Analysis Framework']
# Probability distribution contains keys that are not available category: ['Statistical Data Analysis Framework']
# Retrying 2/5...
# Input tokens used: 11115
# Output tokens used: 118
# Processing element 307/589
# Input tokens used: 13496
# Output tokens used: 115
# Processing element 308/589
# Input tokens used: 7806
# Output tokens used: 185
# Processing element 309/589
# Input tokens used: 7640
# Output tokens used: 276
# Processing element 310/589
# Input tokens used: 8392
# Output tokens used: 198
# Processing element 311/589
# Input tokens used: 12087
# Output tokens used: 363
# Processing element 312/589
# Input tokens used: 9000
# Output tokens used: 366
# Classifications contains values that does not exist as category: ['Longitudinal Data Analysis Framework']
# Probability distribution contains keys that are not available category: ['Longitudinal Data Analysis Framework']
# Retrying 2/5...
# Input tokens used: 9040
# Output tokens used: 269
# Processing element 313/589
# Input tokens used: 8640
# Output tokens used: 194
# Processing element 314/589
# Input tokens used: 8441
# Output tokens used: 550
# Processing element 315/589
# Input tokens used: 8138
# Output tokens used: 183
# Processing element 316/589
# Input tokens used: 7963
# Output tokens used: 152
# Processing element 317/589
# Input tokens used: 9383
# Output tokens used: 147
# Processing element 318/589
# Input tokens used: 10258
# Output tokens used: 141
# Processing element 319/589
# Input tokens used: 7784
# Output tokens used: 321
# Classifications contains values that does not exist as category: ['Critical Physics Identity (CDPI) Framework']
# Probability distribution contains keys that are not available category: ['Critical Physics Identity (CDPI) Framework']
# Retrying 2/5...
# Input tokens used: 7828
# Output tokens used: 336
# Processing element 320/589
# Input tokens used: 9261
# Output tokens used: 318
# Processing element 321/589
# Input tokens used: 8348
# Output tokens used: 125
# Processing element 322/589
# Input tokens used: 8100
# Output tokens used: 98
# Processing element 323/589
# Input tokens used: 9258
# Output tokens used: 362
# Processing element 324/589
# Input tokens used: 7443
# Output tokens used: 164
# Processing element 325/589
# Input tokens used: 8671
# Output tokens used: 366
# Processing element 326/589
# Input tokens used: 11076
# Output tokens used: 336
# Classifications contains values that does not exist as category: ['Conceptual Change Theory']
# Probability distribution contains keys that are not available category: ['Conceptual Change Theory']
# Retrying 2/5...
# Input tokens used: 11112
# Output tokens used: 163
# Processing element 327/589
# Input tokens used: 7788
# Output tokens used: 138
# Processing element 328/589
# Input tokens used: 10651
# Output tokens used: 647
# Processing element 329/589
# Input tokens used: 8199
# Output tokens used: 283
# Processing element 330/589
# Input tokens used: 8689
# Output tokens used: 413
# Processing element 331/589
# Input tokens used: 8810
# Output tokens used: 336
# Classifications contains values that does not exist as category: ['Difficulties Framework']
# Probability distribution contains keys that are not available category: ['Difficulties Framework']
# Retrying 2/5...
# Input tokens used: 8844
# Output tokens used: 210
# ...
# Output tokens used: 203
# Processing element 489/589
# Input tokens used: 7380
# Output tokens used: 171
# Classifications contains values that does not exist as category: ['Statistical Reasoning Framework']
# Probability distribution contains keys that are not available category: ['Statistical Reasoning Framework']
# Retrying 2/5...
# Input tokens used: 7416
# Output tokens used: 128
# Processing element 490/589
# Input tokens used: 7718
# Output tokens used: 113
# Processing element 491/589
# Input tokens used: 9154
# Output tokens used: 389
# Processing element 492/589
# Input tokens used: 9535
# Output tokens used: 454
# Processing element 493/589
# Input tokens used: 8767
# Output tokens used: 464
# Processing element 494/589
# Input tokens used: 9447
# Output tokens used: 363
# Processing element 495/589
# Input tokens used: 10186
# Output tokens used: 403
# Processing element 496/589
# Input tokens used: 10121
# Output tokens used: 400
# Processing element 497/589
# Input tokens used: 8763
# Output tokens used: 139
# Processing element 498/589
# Input tokens used: 9387
# Output tokens used: 394
# Classifications contains values that does not exist as category: ['Conceptual Change Theory']
# Probability distribution contains keys that are not available category: ['Conceptual Change Theory']
# Retrying 2/5...
# Input tokens used: 9423
# Output tokens used: 283
# Processing element 499/589
# Input tokens used: 7907
# Output tokens used: 484
# Processing element 500/589
# Input tokens used: 9211
# Output tokens used: 412
# Classifications contains values that does not exist as category: ['History and Philosophy of Science Framework', 'Mental Models Framework', 'Mathematization in Physics Education Framework']
# Probability distribution contains keys that are not available category: ['History and Philosophy of Science Framework', 'Mental Models Framework', 'Mathematization in Physics Education Framework']
# Retrying 2/5...
# Input tokens used: 9273
# Output tokens used: 355
# Classifications contains values that does not exist as category: ['History and Philosophy of Science Framework']
# Probability distribution contains keys that are not available category: ['History and Philosophy of Science Framework']
# Retrying 3/5...
# Input tokens used: 9313
# Output tokens used: 352
# Processing element 501/589
# Input tokens used: 10460
# Output tokens used: 208
# Processing element 502/589
# Input tokens used: 9713
# Output tokens used: 211
# Classifications contains values that does not exist as category: ['Conceptual Framework Model']
# Probability distribution contains keys that are not available category: ['Conceptual Framework Model']
# Retrying 2/5...
# Input tokens used: 9749
# Output tokens used: 213
# Processing element 503/589
# Input tokens used: 8257
# Output tokens used: 171
# Processing element 504/589
# Input tokens used: 9228
# Output tokens used: 198
# Processing element 505/589
# Input tokens used: 7513
# Output tokens used: 775
# Processing element 506/589
# Input tokens used: 8595
# Output tokens used: 281
# Processing element 507/589
# Input tokens used: 7624
# Output tokens used: 184
# Processing element 508/589
# Input tokens used: 10974
# Output tokens used: 275
# Classifications contains values that does not exist as category: ['Discourse Analysis Framework (Bakhtinian Discourse Analysis Framework)']
# Retrying 2/5...
# Input tokens used: 11013
# Output tokens used: 153
# Processing element 509/589
# Input tokens used: 14468
# Output tokens used: 192
# Processing element 510/589
# Input tokens used: 9186
# Output tokens used: 145
# Processing element 511/589
# Input tokens used: 7153
# Output tokens used: 176
# Processing element 512/589
# Input tokens used: 8420
# Output tokens used: 433
# Processing element 513/589
# Input tokens used: 8075
# Output tokens used: 511
# Classifications contains values that does not exist as category: ['Status Theory in Organizational Sociology']
# Probability distribution contains keys that are not available category: ['Status Theory in Organizational Sociology']
# Retrying 2/5...
# Input tokens used: 8113
# Output tokens used: 310
# Processing element 514/589
# Input tokens used: 7539
# Output tokens used: 334
# Processing element 515/589
# Input tokens used: 9313
# Output tokens used: 303
# Processing element 516/589
# Input tokens used: 8371
# Output tokens used: 273
# Classifications contains values that does not exist as category: ['Cognitive Load Theory']
# Probability distribution contains keys that are not available category: ['Cognitive Load Theory']
# Retrying 2/5...
# Input tokens used: 8405
# Output tokens used: 317
# Processing element 517/589
# Input tokens used: 7560
# Output tokens used: 426
# Processing element 518/589
# Input tokens used: 7584
# Output tokens used: 230
# Processing element 519/589
# Input tokens used: 8680
# Output tokens used: 155
# Processing element 520/589
# Input tokens used: 8960
# Output tokens used: 130
# Processing element 521/589
# Input tokens used: 9698
# Output tokens used: 226
# Classifications contains values that does not exist as category: ['Conceptual Change Theory']
# Probability distribution contains keys that are not available category: ['Conceptual Change Theory']
# Retrying 2/5...
# Input tokens used: 9734
# Output tokens used: 202
# Processing element 522/589
# Input tokens used: 7908
# Output tokens used: 271
# Processing element 523/589
# Input tokens used: 9437
# Output tokens used: 518
# Classifications contains values that does not exist as category: ['Pedagogical Content Knowledge (PCK) Framework']
# Probability distribution contains keys that are not available category: ['Pedagogical Content Knowledge (PCK) Framework']
# Retrying 2/5...
# Input tokens used: 9485
# Output tokens used: 487
# Classifications contains values that does not exist as category: ['Task Design and Assessment Framework (implicit)']
# Probability distribution contains keys that are not available category: ['Pedagogical Content Knowledge (PCK) Framework']
# Retrying 3/5...
# Input tokens used: 9530
# Output tokens used: 344
# Processing element 524/589
# Input tokens used: 7262
# Output tokens used: 251
# Processing element 525/589
# Input tokens used: 7492
# Output tokens used: 385
# Processing element 526/589
# Input tokens used: 7570
# Output tokens used: 330
# Processing element 527/589
# Input tokens used: 8506
# Output tokens used: 239
# Processing element 528/589
# Input tokens used: 8712
# Output tokens used: 407
# Processing element 529/589
# Input tokens used: 8848
# Output tokens used: 272
# Processing element 530/589
# Input tokens used: 9893
# Output tokens used: 372
# Processing element 531/589
# Input tokens used: 15173
# Output tokens used: 477
# Classifications contains values that does not exist as category: ['Conceptual Blending Framework']
# Probability distribution contains keys that are not available category: ['Conceptual Blending Framework']
# Retrying 2/5...
# Input tokens used: 15211
# Output tokens used: 272
# Classifications contains values that does not exist as category: ['Conceptual Blending Framework']
# Probability distribution contains keys that are not available category: ['Conceptual Blending Framework']
# Retrying 3/5...
# Input tokens used: 15249
# Output tokens used: 284
# Classifications contains values that does not exist as category: ['Conceptual Blending Framework']
# Probability distribution contains keys that are not available category: ['Conceptual Blending Framework']
# Retrying 4/5...
# Input tokens used: 15287
# Output tokens used: 266
# Classifications contains values that does not exist as category: ['Conceptual Blending Framework']
# Probability distribution contains keys that are not available category: ['Conceptual Blending Framework']
# Retrying 5/5...
# Couldn't make a valid classification, returning empty!
# Processing element 532/589
# Input tokens used: 16836
# Output tokens used: 429
# Processing element 533/589
# Input tokens used: 9629
# Output tokens used: 288
# Processing element 534/589
# Input tokens used: 9946
# Output tokens used: 391
# Processing element 535/589
# Input tokens used: 8254
# Output tokens used: 156
# Processing element 536/589
# Input tokens used: 7932
# Output tokens used: 244
# Processing element 537/589
# Input tokens used: 9169
# Output tokens used: 143
# Processing element 538/589
# Input tokens used: 7553
# Output tokens used: 218
# Processing element 539/589
# Input tokens used: 8027
# Output tokens used: 149
# Processing element 540/589
# Input tokens used: 9261
# Output tokens used: 345
# Classifications contains values that does not exist as category: ['Action Research Framework']
# Probability distribution contains keys that are not available category: ['Action Research Framework']
# Retrying 2/5...
# Input tokens used: 9295
# Output tokens used: 321
# Processing element 541/589
# Input tokens used: 8595
# Output tokens used: 606
# Processing element 542/589
# Input tokens used: 8491
# Output tokens used: 493
# Classifications contains values that does not exist as category: ['Procedural and Conceptual Knowledge in Science (PACKS)']
# Retrying 2/5...
# Input tokens used: 8529
# Output tokens used: 376
# Classifications contains values that does not exist as category: ['Procedural and Conceptual Knowledge in Science (PACKS)']
# Probability distribution contains keys that are not available category: ['Procedural and Conceptual Knowledge in Science (PACKS)']
# Retrying 3/5...
# Input tokens used: 8579
# Output tokens used: 251
# Processing element 543/589
# Input tokens used: 7872
# Output tokens used: 291
# Processing element 544/589
# Input tokens used: 8840
# Output tokens used: 329
# Processing element 545/589
# Input tokens used: 10484
# Output tokens used: 361
# Classifications contains values that does not exist as category: ['Phenomenography']
# Probability distribution contains keys that are not available category: ['Phenomenography']
# Retrying 2/5...
# Input tokens used: 10518
# Output tokens used: 293
# Processing element 546/589
# Input tokens used: 8810
# Output tokens used: 2086
# Processing element 547/589
# Input tokens used: 8048
# Output tokens used: 235
# Processing element 548/589
# Input tokens used: 13082
# Output tokens used: 377
# Processing element 549/589
# Input tokens used: 9636
# Output tokens used: 631
# Processing element 550/589
# Input tokens used: 8190
# Output tokens used: 143
# Processing element 551/589
# Input tokens used: 7713
# Output tokens used: 157
# Processing element 552/589
# Input tokens used: 10466
# Output tokens used: 277
# Processing element 553/589
# Input tokens used: 8440
# Output tokens used: 656
# Processing element 554/589
# Input tokens used: 7212
# Output tokens used: 209
# Processing element 555/589
# Input tokens used: 10782
# Output tokens used: 445
# Classifications contains values that does not exist as category: ['Metacognition Framework']
# Probability distribution contains keys that are not available category: ['Metacognition Framework']
# Retrying 2/5...
# Input tokens used: 10818
# Output tokens used: 406
# Processing element 556/589
# Input tokens used: 7629
# Output tokens used: 169
# Processing element 557/589
# Input tokens used: 8108
# Output tokens used: 324
# Processing element 558/589
# Input tokens used: 7717
# Output tokens used: 195
# Processing element 559/589
# Input tokens used: 9033
# Output tokens used: 313
# Processing element 560/589
# Input tokens used: 8992
# Output tokens used: 438
# Processing element 561/589
# Input tokens used: 9373
# Output tokens used: 456
# Classifications contains values that does not exist as category: ['Symbolic Blending Framework', 'Mathematical Sensemaking Framework']
# Probability distribution contains keys that are not available category: ['Symbolic Blending Framework', 'Mathematical Sensemaking Framework']
# Retrying 2/5...
# Input tokens used: 9421
# Output tokens used: 252
# Processing element 562/589
# Input tokens used: 7817
# Output tokens used: 396
# Processing element 563/589
# Input tokens used: 8988
# Output tokens used: 195
# Processing element 564/589
# Input tokens used: 8464
# Output tokens used: 626
# Classifications contains values that does not exist as category: ['Design-Based Research (DBR) Framework']
# Probability distribution contains keys that are not available category: ['Design-Based Research (DBR) Framework']
# Retrying 2/5...
# Input tokens used: 8508
# Output tokens used: 390
# Processing element 565/589
# Input tokens used: 8474
# Output tokens used: 304
# Processing element 566/589
# Input tokens used: 7658
# Output tokens used: 235
# Processing element 567/589
# Input tokens used: 8783
# Output tokens used: 221
# Processing element 568/589
# Input tokens used: 8552
# Output tokens used: 390
# Processing element 569/589
# Input tokens used: 8028
# Output tokens used: 278
# Processing element 570/589
# Input tokens used: 8467
# Output tokens used: 293
# Processing element 571/589
# Input tokens used: 7657
# Output tokens used: 394
# Processing element 572/589
# Input tokens used: 11543
# Output tokens used: 405
# Classifications contains values that does not exist as category: ['Pedagogical Content Knowledge (PCK) Framework']
# Probability distribution contains keys that are not available category: ['Pedagogical Content Knowledge (PCK) Framework']
# Retrying 2/5...
# Input tokens used: 11591
# Output tokens used: 276
# Classifications contains values that does not exist as category: ['Pedagogical Content Knowledge (PCK) Framework']
# Probability distribution contains keys that are not available category: ['Pedagogical Content Knowledge (PCK) Framework']
# Retrying 3/5...
# Input tokens used: 11639
# Output tokens used: 297
# Processing element 573/589
# Input tokens used: 7455
# Output tokens used: 333
# Processing element 574/589
# Input tokens used: 8481
# Output tokens used: 330
# Processing element 575/589
# Input tokens used: 8896
# Output tokens used: 788
# Classifications contains values that does not exist as category: ['Conceptual Change Theory']
# Probability distribution contains keys that are not available category: ['Conceptual Change Theory']
# Retrying 2/5...
# Input tokens used: 8932
# Output tokens used: 306
# Classifications contains values that does not exist as category: ['Conceptual Change Theory']
# Probability distribution contains keys that are not available category: ['Conceptual Change Theory']
# Retrying 3/5...
# Input tokens used: 8968
# Output tokens used: 372
# Classifications contains values that does not exist as category: ['Conceptual Change Theory']
# Probability distribution contains keys that are not available category: ['Conceptual Change Theory']
# Retrying 4/5...
# Input tokens used: 9004
# Output tokens used: 458
# Classifications contains values that does not exist as category: ['Conceptual Change Framework']
# Probability distribution contains keys that are not available category: ['Conceptual Change Framework']
# Retrying 5/5...
# Couldn't make a valid classification, returning empty!
# Processing element 576/589
# Input tokens used: 7091
# Output tokens used: 326
# Processing element 577/589
# Input tokens used: 8709
# Output tokens used: 454
# Processing element 578/589
# Input tokens used: 9638
# Output tokens used: 239
# Processing element 579/589
# Input tokens used: 8909
# Output tokens used: 605
# Processing element 580/589
# Input tokens used: 9610
# Output tokens used: 232
# Processing element 581/589
# Input tokens used: 9816
# Output tokens used: 347
# Processing element 582/589
# Input tokens used: 8415
# Output tokens used: 238
# Processing element 583/589
# Input tokens used: 8010
# Output tokens used: 392
# Processing element 584/589
# Input tokens used: 7550
# Output tokens used: 269
# Processing element 585/589
# Input tokens used: 10418
# Output tokens used: 750
# Processing element 586/589
# Input tokens used: 7993
# Output tokens used: 251
# Processing element 587/589
# Input tokens used: 8119
# Output tokens used: 504
# Processing element 588/589
# Input tokens used: 10888
# Output tokens used: 315
# Classifications contains values that does not exist as category: ['Mental Models Framework']
# Probability distribution contains keys that are not available category: ['Mental Models Framework']
# Retrying 2/5...
# Input tokens used: 10922
# Output tokens used: 155
# Classifications contains values that does not exist as category: ['Mental Models Framework']
# Probability distribution contains keys that are not available category: ['Mental Models Framework']
# Retrying 3/5...
# Input tokens used: 10956
# Output tokens used: 276
# Processing element 589/589
# Input tokens used: 9419
# Output tokens used: 444
# Batch processing complete. Total categories available: 135

# %% [markdown]
# Let us preview the results to make sure they make sense.

# %%
result_df
# Out:
#                                article_id  \
# 0           10.1103/PhysRevSTPER.2.010103
# 1           10.1103/PhysRevSTPER.2.010103
# 2           10.1103/PhysRevSTPER.2.010105
# 3           10.1103/PhysRevSTPER.2.020101
# 4           10.1103/PhysRevSTPER.2.020103
# ..                                    ...
# 584  10.1103/PhysRevPhysEducRes.20.020145
# 585  10.1103/PhysRevPhysEducRes.20.020146
# 586  10.1103/PhysRevPhysEducRes.20.020146
# 587  10.1103/PhysRevPhysEducRes.20.020147
# 588  10.1103/PhysRevPhysEducRes.20.020153
#
#                                          section_title  \
# 0              THEORETICAL FRAME: A MODEL OF COGNITION
# 1    STUDENT MODEL SPACE: A MATHEMATICAL REPRESENTA...
# 2                      BACKGROUND AND VALIDITY OF BEMA
# 3                                   THEORETICAL FRAMES
# 4                        DEFINING SCIENTIFIC ABILITIES
# ..                                                 ...
# 584                                         BACKGROUND
# 585                            THE COMMOGNITIVE THEORY
# 586  ANALYSIS OF SCIENTIFIC CONTENT: CONCEPTUALIZAT...
# 587                             THEORETICAL BACKGROUND
# 588               THEORETICAL FRAMEWORK AND LITERATURE
#
#                           classifications_gpt-4.1-mini  \
# 0    [Resource Framing, Knowledge Integration Frame...
# 1    [Mathematical Modeling Framework, Postpositivism]
# 2    [Measurement Theory Framework, Formative Asses...
# 3    [Modeling, Structure Mapping, and Conceptual B...
# 4    [Formative Assessment Framework (Assessment fo...
# ..                                                 ...
# 584  [Philosophy & History of Science Framework, Ep...
# 585                              [Commognitive Theory]
# 586  [Model of Educational Reconstruction (MER), Co...
# 587  [Johnson-Laird Mental Representation Framework...
# 588  [Sociocultural Identity and Gender Performativ...
#
#                             probabilities_gpt-4.1-mini  \
# 0    {'Resource Framing': 0.6, 'Knowledge Integrati...
# 1    {'Mathematical Modeling Framework': 0.85, 'Pos...
# 2    {'Measurement Theory Framework': 0.75, 'Format...
# 3    {'Modeling, Structure Mapping, and Conceptual ...
# 4    {'Formative Assessment Framework (Assessment f...
# ..                                                 ...
# 584  {'Philosophy & History of Science Framework': ...
# 585                       {'Commognitive Theory': 1.0}
# 586  {'Model of Educational Reconstruction (MER)': ...
# 587  {'Johnson-Laird Mental Representation Framewor...
# 588  {'Sociocultural Identity and Gender Performati...
#
#                              highest_prob_gpt-4.1-mini  \
# 0                                     Resource Framing
# 1                      Mathematical Modeling Framework
# 2                         Measurement Theory Framework
# 3    Modeling, Structure Mapping, and Conceptual Bl...
# 4    Formative Assessment Framework (Assessment for...
# ..                                                 ...
# 584          Philosophy & History of Science Framework
# 585                                Commognitive Theory
# 586          Model of Educational Reconstruction (MER)
# 587      Johnson-Laird Mental Representation Framework
# 588   Metacognitive Critical Affective (MCA) Framework
#
#                             text_excerpts_gpt-4.1-mini
# 0    {'Resource Framing': [{'excerpt': 'We are inte...
# 1    {'Mathematical Modeling Framework': [{'excerpt...
# 2    {'Measurement Theory Framework': [{'excerpt': ...
# 3    {'Modeling, Structure Mapping, and Conceptual ...
# 4    {'Formative Assessment Framework (Assessment f...
# ..                                                 ...
# 584  {'Philosophy & History of Science Framework': ...
# 585  {'Commognitive Theory': [{'excerpt': 'Rooted i...
# 586  {'Model of Educational Reconstruction (MER)': ...
# 587  {'Johnson-Laird Mental Representation Framewor...
# 588  {'Sociocultural Identity and Gender Performati...
#
# [589 rows x 6 columns]

# %% [markdown]
# The classificator also extracts some text exerpts from the classification data. Currently this is not used for anything. But it could be used e.g. for generating improved and more detailed descriptions of theoretical frameworks by passing a bunch of exerpts for the same framework to a LLM.
#
# Here we print out a sample of them for a simple overview of what it extracts.

# %%
import json

# Print out the text excerpts from 3 random rows using sample
sampled = result_df.sample(3, random_state=42)
for idx, row in sampled.iterrows():
    excerpts = row.get("text_excerpts_gpt-4.1-mini", [])
    # If excerpts is a string, try to parse as JSON
    if isinstance(excerpts, str):
        try:
            excerpts = json.loads(excerpts)
        except Exception:
            pass  # If it can't be parsed, leave as is
    if not excerpts or excerpts == "No excerpts found":
        print(f"\nRow {idx}: No excerpts found")
        continue
    print(f"\nRow {idx} excerpts by category:")
    for excerpt in excerpts:
        # If excerpt is a string, try to parse as JSON
        if isinstance(excerpt, str):
            try:
                excerpt = json.loads(excerpt)
            except Exception:
                excerpt = {}
        category = excerpt.get("category", "Unknown Category")
        text = excerpt.get("excerpt", "No excerpt text")
        print(f"  Category: {category}\n    Excerpt: {text}")
# Out:
# Row 521 excerpts by category:
#   Category: Unknown Category
#     Excerpt: No excerpt text
#
# Row 284 excerpts by category:
#   Category: Unknown Category
#     Excerpt: No excerpt text
#   Category: Unknown Category
#     Excerpt: No excerpt text
#   Category: Unknown Category
#     Excerpt: No excerpt text
#
# Row 513 excerpts by category:
#   Category: Unknown Category
#     Excerpt: No excerpt text
#   Category: Unknown Category
#     Excerpt: No excerpt text

# %% [markdown]
# #### Classification and new category processing and saving

# %%
len(updated_categories)
# Out:
# 135

# %%
# Save updated categories if any new ones were discovered
if len(updated_categories) > len(frameworks):
    print(f"\nDiscovered {len(updated_categories) - len(frameworks)} new categories")
    save_categories_to_json(updated_categories, "./theory_data/reviewed_categories.json")

# %%
# Merge result_df columns into theory_df using 'article_id' and 'section_title' for alignment, prefixing with 'theory_'
merge_cols = [col for col in result_df.columns if col not in ['article_id', 'section_title']]
theory_df_merged = theory_df.merge(
    result_df.rename(columns={col: f"theory_{col}" for col in merge_cols}),
    on=['article_id', 'section_title'],
    how='left'
)

# %%
import numpy as np

# Count the rows in theory_df_merged with a NaN value in 'theory_classification_gpt_4.1-mini'
nan_count = theory_df_merged['theory_probabilities_gpt-4.1-mini'].isna().sum()
print(f"Number of rows with NaN in 'theory_classification_gpt_4.1-mini': {nan_count}")
# Out:
# Number of rows with NaN in 'theory_classification_gpt_4.1-mini': 0

# %%
theory_df_merged
# Out:
#                                       article_abstract article_articleType  \
# 0    {'value': '<p>Decades of education research ha...             article
# 1    {'value': '<p>Decades of education research ha...             article
# 2    {'value': '<p>The Brief Electricity and Magnet...             article
# 3    {'value': '<p>Previous studies have demonstrat...             article
# 4    {'value': '<p>The paper introduces a set of fo...             article
# ..                                                 ...                 ...
# 584  {'value': '<p>The COVID-19 pandemic has increa...             article
# 585  {'value': '<p>In this paper, we demonstrate th...             article
# 586  {'value': '<p>In this paper, we demonstrate th...             article
# 587  {'value': '<p>Evidence from physics education ...             article
# 588  {'value': '<p>[This paper is part of the Focus...             article
#
#                                        article_authors  \
# 0    [{'type': 'Person', 'name': 'Lei Bao', 'firstn...
# 1    [{'type': 'Person', 'name': 'Lei Bao', 'firstn...
# 2    [{'type': 'Person', 'name': 'Lin Ding', 'first...
# 3    [{'type': 'Person', 'name': 'Noah S. Podolefsk...
# 4    [{'type': 'Person', 'name': 'Eugenia Etkina', ...
# ..                                                 ...
# 584  [{'type': 'Person', 'name': 'Walter Sciarretta...
# 585  [{'type': 'Person', 'name': 'Ofek Sivan', 'fir...
# 586  [{'type': 'Person', 'name': 'Ofek Sivan', 'fir...
# 587  [{'type': 'Person', 'name': 'Fabian Hennig', '...
# 588  [{'type': 'Person', 'name': 'Nilüfer Didiş Kör...
#
#                                   article_affiliations article_date  \
# 0    [{'name': 'Department of Physics, The Ohio Sta...   2006-02-02
# 1    [{'name': 'Department of Physics, The Ohio Sta...   2006-02-02
# 2    [{'name': 'Department of Physics, North Caroli...   2006-03-15
# 3    [{'name': 'Department of Physics, University o...   2006-07-18
# 4    [{'name': 'Department of Physics and Astronomy...   2006-08-01
# ..                                                 ...          ...
# 584  [{'name': '<a href="https://ror.org/05290cv24"...   2024-11-22
# 585  [{'name': 'Department of Science Teaching, <a ...   2024-11-25
# 586  [{'name': 'Department of Science Teaching, <a ...   2024-11-25
# 587  [{'name': '<a href="https://ror.org/00f7hpc57"...   2024-11-26
# 588  [{'name': 'Department of Mathematics and Scien...   2024-12-26
#
#     article_type article_metadata_last_modified_at  article_last_modified_at  \
# 0        article          2006-03-02T15:44:54+0000 2014-08-22 11:32:06+00:00
# 1        article          2006-03-02T15:44:54+0000 2014-08-22 11:32:06+00:00
# 2        article          2006-03-15T15:52:03+0000 2014-08-22 04:01:44+00:00
# 3        article          2006-07-18T17:56:03+0000 2014-08-22 04:01:46+00:00
# 4        article          2006-08-01T19:34:02+0000 2014-08-22 04:19:22+00:00
# ..           ...                               ...                       ...
# 584      article          2024-11-22T15:05:29+0000 2024-11-22 15:05:29+00:00
# 585      article          2024-11-25T15:05:41+0000 2024-11-25 15:05:41+00:00
# 586      article          2024-11-25T15:05:41+0000 2024-11-25 15:05:41+00:00
# 587      article          2024-11-26T19:12:26+0000 2024-11-26 19:12:26+00:00
# 588      article          2024-12-26T14:57:19+0000 2024-12-26 14:57:19+00:00
#
#                                article_id  \
# 0           10.1103/PhysRevSTPER.2.010103
# 1           10.1103/PhysRevSTPER.2.010103
# 2           10.1103/PhysRevSTPER.2.010105
# 3           10.1103/PhysRevSTPER.2.020101
# 4           10.1103/PhysRevSTPER.2.020103
# ..                                    ...
# 584  10.1103/PhysRevPhysEducRes.20.020145
# 585  10.1103/PhysRevPhysEducRes.20.020146
# 586  10.1103/PhysRevPhysEducRes.20.020146
# 587  10.1103/PhysRevPhysEducRes.20.020147
# 588  10.1103/PhysRevPhysEducRes.20.020153
#
#                                  article_identifiers  ...  \
# 0           {'doi': '10.1103/PhysRevSTPER.2.010103'}  ...
# 1           {'doi': '10.1103/PhysRevSTPER.2.010103'}  ...
# 2           {'doi': '10.1103/PhysRevSTPER.2.010105'}  ...
# 3           {'doi': '10.1103/PhysRevSTPER.2.020101'}  ...
# 4           {'doi': '10.1103/PhysRevSTPER.2.020103'}  ...
# ..                                               ...  ...
# 584  {'doi': '10.1103/PhysRevPhysEducRes.20.020145'}  ...
# 585  {'doi': '10.1103/PhysRevPhysEducRes.20.020146'}  ...
# 586  {'doi': '10.1103/PhysRevPhysEducRes.20.020146'}  ...
# 587  {'doi': '10.1103/PhysRevPhysEducRes.20.020147'}  ...
# 588  {'doi': '10.1103/PhysRevPhysEducRes.20.020153'}  ...
#
#                                section_title_embedding  \
# 0    [-0.05480332672595978, 0.024843383580446243, 0...
# 1    [-0.064679816365242, 0.023139355704188347, 0.0...
# 2    [0.0021336465142667294, 0.039801325649023056, ...
# 3    [-0.05005525052547455, -0.011595192365348339, ...
# 4    [-0.04178931564092636, 0.032831691205501556, -...
# ..                                                 ...
# 584  [-0.05440903455018997, 0.025425761938095093, 0...
# 585  [-0.03745094686746597, 0.0264377873390913, 0.0...
# 586  [-0.05633138492703438, 0.03367773815989494, 0....
# 587  [-0.05372088402509689, 0.061712078750133514, -...
# 588  [-0.06772062182426453, 0.048955220729112625, 0...
#
#                              section_content_embedding  \
# 0    [-0.06690618395805359, 0.023494919762015343, 0...
# 1    [-0.07020589709281921, 0.03362146019935608, 0....
# 2    [-0.0529276579618454, 0.04701779782772064, 0.0...
# 3    [-0.07176671177148819, -0.0012164521031081676,...
# 4    [-0.07951419055461884, 0.03167480602860451, -0...
# ..                                                 ...
# 584  [-0.05885731428861618, 0.04646742343902588, -0...
# 585  [-0.06726039201021194, 0.02099861577153206, 0....
# 586  [-0.061981599777936935, 0.049642641097307205, ...
# 587  [-0.044971249997615814, 0.03139623999595642, -...
# 588  [-0.04591209813952446, 0.017132602632045746, 0...
#
#                          probability_dist_gpt-4.1-mini  \
# 0    {'Theoretical Framework': 0.9, 'Literature Rev...
# 1    {'Theoretical Framework': 0.6, 'Methods': 0.35...
# 2    {'Introduction / Motivation': 0.05, 'Theoretic...
# 3    {'Theoretical Framework': 0.9, 'Literature Rev...
# 4    {'Introduction / Motivation': 0.1, 'Theoretica...
# ..                                                 ...
# 584  {'Introduction / Motivation': 0.05, 'Theoretic...
# 585  {'Introduction / Motivation': 0.05, 'Theoretic...
# 586  {'Introduction / Motivation': 0.01, 'Theoretic...
# 587  {'Introduction / Motivation': 0.05, 'Theoretic...
# 588  {'Theoretical Framework': 0.6, 'Literature Rev...
#
#                            classification_gpt-4.1-mini  \
# 0                              [Theoretical Framework]
# 1                     [Theoretical Framework, Methods]
# 2                     [Theoretical Framework, Methods]
# 3                              [Theoretical Framework]
# 4                              [Theoretical Framework]
# ..                                                 ...
# 584  [Theoretical Framework, Literature Review/Rean...
# 585                            [Theoretical Framework]
# 586  [Theoretical Framework, Literature Review/Rean...
# 587                   [Theoretical Framework, Methods]
# 588  [Theoretical Framework, Literature Review/Rean...
#
#     classification_highest_prob_gpt-4.1-mini failed_validation_gpt-4.1-mini  \
# 0                      Theoretical Framework                          False
# 1                      Theoretical Framework                          False
# 2                      Theoretical Framework                          False
# 3                      Theoretical Framework                          False
# 4                      Theoretical Framework                          False
# ..                                       ...                            ...
# 584                    Theoretical Framework                          False
# 585                    Theoretical Framework                          False
# 586                    Theoretical Framework                          False
# 587                    Theoretical Framework                          False
# 588                    Theoretical Framework                          False
#
#                    theory_classifications_gpt-4.1-mini  \
# 0    [Resource Framing, Knowledge Integration Frame...
# 1    [Mathematical Modeling Framework, Postpositivism]
# 2    [Measurement Theory Framework, Formative Asses...
# 3    [Modeling, Structure Mapping, and Conceptual B...
# 4    [Formative Assessment Framework (Assessment fo...
# ..                                                 ...
# 584  [Philosophy & History of Science Framework, Ep...
# 585                              [Commognitive Theory]
# 586  [Model of Educational Reconstruction (MER), Co...
# 587  [Johnson-Laird Mental Representation Framework...
# 588  [Sociocultural Identity and Gender Performativ...
#
#                      theory_probabilities_gpt-4.1-mini  \
# 0    {'Resource Framing': 0.6, 'Knowledge Integrati...
# 1    {'Mathematical Modeling Framework': 0.85, 'Pos...
# 2    {'Measurement Theory Framework': 0.75, 'Format...
# 3    {'Modeling, Structure Mapping, and Conceptual ...
# 4    {'Formative Assessment Framework (Assessment f...
# ..                                                 ...
# 584  {'Philosophy & History of Science Framework': ...
# 585                       {'Commognitive Theory': 1.0}
# 586  {'Model of Educational Reconstruction (MER)': ...
# 587  {'Johnson-Laird Mental Representation Framewor...
# 588  {'Sociocultural Identity and Gender Performati...
#
#                       theory_highest_prob_gpt-4.1-mini  \
# 0                                     Resource Framing
# 1                      Mathematical Modeling Framework
# 2                         Measurement Theory Framework
# 3    Modeling, Structure Mapping, and Conceptual Bl...
# 4    Formative Assessment Framework (Assessment for...
# ..                                                 ...
# 584          Philosophy & History of Science Framework
# 585                                Commognitive Theory
# 586          Model of Educational Reconstruction (MER)
# 587      Johnson-Laird Mental Representation Framework
# 588   Metacognitive Critical Affective (MCA) Framework
#
#                      theory_text_excerpts_gpt-4.1-mini
# 0    {'Resource Framing': [{'excerpt': 'We are inte...
# 1    {'Mathematical Modeling Framework': [{'excerpt...
# 2    {'Measurement Theory Framework': [{'excerpt': ...
# 3    {'Modeling, Structure Mapping, and Conceptual ...
# 4    {'Formative Assessment Framework (Assessment f...
# ..                                                 ...
# 584  {'Philosophy & History of Science Framework': ...
# 585  {'Commognitive Theory': [{'excerpt': 'Rooted i...
# 586  {'Model of Educational Reconstruction (MER)': ...
# 587  {'Johnson-Laird Mental Representation Framewor...
# 588  {'Sociocultural Identity and Gender Performati...
#
# [589 rows x 42 columns]

# %%
helpers.save_processed_embeddings(theory_df_merged, "./theory_data/theory_classification_df")
# Out:
# Saved processed_embeddings to theory_classification_df_20250806_192015.pkl
# 'theory_classification_df_20250806_192015.pkl'

# %% [markdown]
# ## Review categories

# %% [markdown]
# ### Load classified data (to avoid rerunning)

# %%
theory_df_merged = pd.read_pickle("./theory_data/theory_classification_df_20250806_192015.pkl")
updated_categories = load_categories_from_json("./theory_data/reviewed_categories_20250721_163329.json")
print(theory_df_merged.keys())
print(len(updated_categories))
# Out:
# Successfully loaded 135 categories from ./reviewed_categories_20250721_163329.json
# Index(['article_abstract', 'article_articleType', 'article_authors',
#        'article_affiliations', 'article_date', 'article_type',
#        'article_metadata_last_modified_at', 'article_last_modified_at',
#        'article_id', 'article_identifiers', 'article_issue',
#        'article_pageStart', 'article_hasArticleId', 'article_numPages',
#        'article_publisher', 'article_rights', 'article_journal',
#        'article_title', 'article_volume', 'article_notes',
#        'article_tocSection', 'article_fundings',
#        'article_classificationSchemes', 'article_doi', 'article_full_text_xml',
#        'article_full_text', 'article_year', 'section_relative_position',
#        'section_label', 'section_title', 'section_content', 'section_id',
#        'section_title_embedding', 'section_content_embedding',
#        'probability_dist_gpt-4.1-mini', 'classification_gpt-4.1-mini',
#        'classification_highest_prob_gpt-4.1-mini',
#        'failed_validation_gpt-4.1-mini', 'theory_classifications_gpt-4.1-mini',
#        'theory_probabilities_gpt-4.1-mini', 'theory_highest_prob_gpt-4.1-mini',
#        'theory_text_excerpts_gpt-4.1-mini'],
#       dtype='object')
# 135

# %% [markdown]
# ### Run Cleaning

# %%
reviewed_categories = classifier.review_and_clean_categories(updated_categories)
# Out:
# Category review using model: o3-mini
# Reviewing 144 categories
# Input tokens used: 7284
# Output tokens used: 6774
# Review summary:
#   - Original categories: 144
#   - Cleaned categories: 118
#   - Removed categories: 16
#   - Merge suggestions: 7
#   - Removed: Curriculum Documents Framework, Participatory Design Framework, Practice-Based Teacher Education, Postpositivism, Epistemic Network Analysis Framework, Innovation-decision Process Framework, Human Capital Theory, How Learning Works (HLW) Principles Framework, Adaptation and Reinvention (ARI) Model, Philosophy & History of Science Framework, Organizational Theory in Educational Contexts, Design-Based Research (DBR) Methodology, Research Ethics and Questionable Research Practices in Science Education, Pragmatism in Research, Interpretivist Case Study, Natural Language Processing Framework
#   - Suggested merges: Sociocultural Participation and Situated Learning Framework, Critical Race Theoretical Perspectives, Constructivism Framework, Cultural-Historical Activity Theory (CHAT), Group Work Practices Framework, Physics Identity Framework, Conceptual Metaphor and Cognitive Linguistics Framework

# %%
from IPython.display import Markdown
issues = classifier._validate_review_result(reviewed_categories, updated_categories)
report = classifier.generate_validation_report(reviewed_categories, updated_categories, issues)
with open("review_report.md", "w") as f:
    f.write(report)
# display(Markdown(report))

# %%
save_categories_to_json(reviewed_categories.cleaned_categories, "./theory_data/reviewed_categories.json")
# Out:
# Categories saved to reviewed_categories_20250721_163329.json

# %% [markdown]
# ## Create Meta-Categories

# %%
from theory_classifiers import FrameworkClassifier


classifier = FrameworkClassifier(api_key=api_key, temperature=0.5,
                                max_tokens=1000, general_model="gpt-4.1", reasoning_model="o3-mini")
                                # OBS! We are using gpt-4.1 here because of the low token length

# %%
frameworks = load_categories_from_json("./theory_data/reviewed_categories_20250721_163329.json")
# Out:
# Successfully loaded 135 categories from reviewed_categories_20250721_163329.json

# %% [markdown]
# #### Discover/load initial categories
#
# The classifier can pass the raw data, in this case the framework titles and descriptions, to a LLM to discover a initial set of categories.

# %%
preped_discovery_data = [f"{cat.title}: {cat.description}" for cat in frameworks]
# discovered_meta_categories = classifier.discover_categories(preped_discovery_data)

# %% [markdown]
# Let us instead load the initial categories suggested by Tor Ole and print them out for a overview.

# %%
meta_categories = load_categories_from_json("./theory_data/meta_categories_TOOB.json")
# Out:
# Successfully loaded 5 categories from meta_categories_TOOB.json

# %%
for x in meta_categories:
    print(x.title)
    print(x.description)
    print("-"*100)
# Out:
# Cognitive
# Theories focusing on individual mental processes, knowledge structures, and reasoning. Examples include Symbolic forms, epistemic games, Dual process theory, and misconceptions research.
# ----------------------------------------------------------------------------------------------------
# Sociocultural
# Theories emphasizing learning as social participation and enculturation into a community's practices. Examples include Cultural-Historical Activity Theory (CHAT), Participationist learning, and Communities of Practice.
# ----------------------------------------------------------------------------------------------------
# Social Justice
# Theories that examine and critique systems of power, privilege, and oppression within educational contexts. Examples include Critical Race Theory and Culturally Relevant Pedagogy.
# ----------------------------------------------------------------------------------------------------
# Organizational
# Theories that analyze the structures, systems, and processes of educational institutions and how they impact student and faculty experiences. Examples include the Dissemination of Curriculum and Tinto's model of student integration.
# ----------------------------------------------------------------------------------------------------
# Motivation and Identity
# Theories centered on students' beliefs, values, goals, and sense of self in relation to physics. An example is Expectancy-Value Theory.
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Review and clean the initial categories
#
# The classifier can also review and clean up the categories. Since the amount of tokens used for this process is negligible in the case of meta-categorization, we can run it on the initial categories just for the sake of it.

# %%
review_response = classifier.review_and_clean_categories(meta_categories)
reviewed_meta_cat = review_response.cleaned_categories
# Out:
# Category review using model: o3-mini
# Reviewing 5 categories
# Input tokens used: 800
# Output tokens used: 829
# Review summary:
#   - Original categories: 5
#   - Cleaned categories: 5
#   - Removed categories: 0
#   - Merge suggestions: 0

# %% [markdown]
# We can also save these if we'd like.

# %%
# save_categories_to_json(reviewed_meta_cat, "reviewed_meta_cat.json")

# %% [markdown]
# ### Run meta-categorization
#
# We can now run the classification on the frameworks using this set of meta-categories.
#
# #### Cost estimate
#
# Let us first estimate the cost of running our classifier with the selected models.

# %%
cost_classifier = CostEstimationWrapper(classifier)

estimates = cost_classifier.estimate_full_workflow(frameworks, reviewed_meta_cat, preped_discovery_data)
display(Markdown(cost_classifier.generate_cost_report(estimates)))
# Out:
# # Cost Estimation Report
# Generated: 2025-08-06 23:35:44
#
# ## Category Discovery
#
# - **Cost**: $0.0219
# - **Model**: gpt-4.1
# - **Input Tokens**: 7,619
# - **Output Tokens**: 830
#
# ## Category Review
#
# - **Cost**: $0.0004
# - **Model**: o3-mini
# - **Input Tokens**: 525
# - **Output Tokens**: 470
#
# ## Batch Classification
#
# - **Total Cost**: $0.2255
# - **Items Processed**: 135
# - **Average Cost per Item**: $0.0017
# - **Total Input Tokens**: 69,546
# - **Total Output Tokens**: 10,800
#
# ## Summary
#
# - **Total Estimated Cost**: $0.2477
# - **Total Input Tokens**: 77,690
# - **Total Output Tokens**: 12,100
#
# *Note: These are estimates based on current pricing and may vary.*

# %% [markdown]
# #### Classifying

# %%
classification_response = classifier.batch_classify(frameworks, reviewed_meta_cat, "balanced")
# Out:
# Processing element 1/135
# Input tokens used: 603
# Output tokens used: 53
# Processing element 2/135
# Input tokens used: 601
# Output tokens used: 54
# Processing element 3/135
# Input tokens used: 598
# Output tokens used: 52
# Processing element 4/135
# Input tokens used: 600
# Output tokens used: 54
# Processing element 5/135
# Input tokens used: 603
# Output tokens used: 48
# Processing element 6/135
# Input tokens used: 608
# Output tokens used: 57
# Processing element 7/135
# Input tokens used: 610
# Output tokens used: 55
# Processing element 8/135
# Input tokens used: 601
# Output tokens used: 34
# Processing element 9/135
# Input tokens used: 612
# Output tokens used: 48
# Processing element 10/135
# Input tokens used: 632
# Output tokens used: 52
# Processing element 11/135
# Input tokens used: 611
# Output tokens used: 55
# Processing element 12/135
# Input tokens used: 610
# Output tokens used: 48
# Processing element 13/135
# Input tokens used: 627
# Output tokens used: 62
# Processing element 14/135
# Input tokens used: 610
# Output tokens used: 48
# Processing element 15/135
# Input tokens used: 614
# Output tokens used: 55
# Processing element 16/135
# Input tokens used: 628
# Output tokens used: 61
# Processing element 17/135
# Input tokens used: 640
# Output tokens used: 52
# Processing element 18/135
# Input tokens used: 623
# Output tokens used: 55
# Processing element 19/135
# Input tokens used: 646
# Output tokens used: 48
# Processing element 20/135
# Input tokens used: 614
# Output tokens used: 52
# Processing element 21/135
# Input tokens used: 625
# Output tokens used: 53
# Processing element 22/135
# Input tokens used: 625
# Output tokens used: 62
# Processing element 23/135
# Input tokens used: 618
# Output tokens used: 55
# Processing element 24/135
# Input tokens used: 623
# Output tokens used: 52
# Processing element 25/135
# Input tokens used: 616
# Output tokens used: 53
# Processing element 26/135
# Input tokens used: 605
# Output tokens used: 51
# Processing element 27/135
# Input tokens used: 602
# Output tokens used: 83
# Processing element 28/135
# Input tokens used: 618
# Output tokens used: 51
# Processing element 29/135
# Input tokens used: 625
# Output tokens used: 53
# Processing element 30/135
# Input tokens used: 617
# Output tokens used: 51
# Processing element 31/135
# Input tokens used: 623
# Output tokens used: 53
# Processing element 32/135
# Input tokens used: 621
# Output tokens used: 53
# Processing element 33/135
# Input tokens used: 614
# Output tokens used: 48
# Processing element 34/135
# Input tokens used: 639
# Output tokens used: 56
# Processing element 35/135
# Input tokens used: 610
# Output tokens used: 53
# Processing element 36/135
# Input tokens used: 623
# Output tokens used: 61
# Processing element 37/135
# Input tokens used: 622
# Output tokens used: 52
# Processing element 38/135
# Input tokens used: 600
# Output tokens used: 48
# Processing element 39/135
# Input tokens used: 607
# Output tokens used: 62
# Processing element 40/135
# Input tokens used: 609
# Output tokens used: 48
# Processing element 41/135
# Input tokens used: 614
# Output tokens used: 53
# Processing element 42/135
# Input tokens used: 624
# Output tokens used: 48
# Processing element 43/135
# Input tokens used: 606
# Output tokens used: 90
# Processing element 44/135
# Input tokens used: 622
# Output tokens used: 61
# Processing element 45/135
# Input tokens used: 609
# Output tokens used: 48
# Processing element 46/135
# Input tokens used: 637
# Output tokens used: 55
# Processing element 47/135
# Input tokens used: 653
# Output tokens used: 48
# Processing element 48/135
# Input tokens used: 606
# Output tokens used: 80
# Processing element 49/135
# Input tokens used: 619
# Output tokens used: 48
# Processing element 50/135
# Input tokens used: 617
# Output tokens used: 62
# Processing element 51/135
# Input tokens used: 615
# Output tokens used: 55
# Processing element 52/135
# Input tokens used: 606
# Output tokens used: 86
# Processing element 53/135
# Input tokens used: 616
# Output tokens used: 57
# Processing element 54/135
# Input tokens used: 625
# Output tokens used: 48
# Processing element 55/135
# Input tokens used: 615
# Output tokens used: 57
# Processing element 56/135
# Input tokens used: 624
# Output tokens used: 51
# Processing element 57/135
# Input tokens used: 613
# Output tokens used: 53
# Processing element 58/135
# Input tokens used: 652
# Output tokens used: 62
# Processing element 59/135
# Input tokens used: 622
# Output tokens used: 53
# Processing element 60/135
# Input tokens used: 652
# Output tokens used: 52
# Processing element 61/135
# Input tokens used: 615
# Output tokens used: 48
# Processing element 62/135
# Input tokens used: 625
# Output tokens used: 116
# Processing element 63/135
# Input tokens used: 656
# Output tokens used: 52
# Processing element 64/135
# Input tokens used: 631
# Output tokens used: 62
# Processing element 65/135
# Input tokens used: 639
# Output tokens used: 48
# Processing element 66/135
# Input tokens used: 623
# Output tokens used: 53
# Processing element 67/135
# Input tokens used: 634
# Output tokens used: 56
# Processing element 68/135
# Input tokens used: 628
# Output tokens used: 59
# Processing element 69/135
# Input tokens used: 608
# Output tokens used: 56
# Processing element 70/135
# Input tokens used: 603
# Output tokens used: 56
# Processing element 71/135
# Input tokens used: 604
# Output tokens used: 65
# Processing element 72/135
# Input tokens used: 610
# Output tokens used: 47
# Processing element 73/135
# Input tokens used: 614
# Output tokens used: 48
# Processing element 74/135
# Input tokens used: 643
# Output tokens used: 52
# Processing element 75/135
# Input tokens used: 619
# Output tokens used: 59
# Processing element 76/135
# Input tokens used: 665
# Output tokens used: 48
# Processing element 77/135
# Input tokens used: 616
# Output tokens used: 48
# Processing element 78/135
# Input tokens used: 642
# Output tokens used: 103
# Added new category: Epistemological/Philosophical
# Processing element 79/135
# Input tokens used: 655
# Output tokens used: 52
# Processing element 80/135
# Input tokens used: 663
# Output tokens used: 129
# Processing element 81/135
# Input tokens used: 669
# Output tokens used: 90
# Processing element 82/135
# Input tokens used: 681
# Output tokens used: 90
# Processing element 83/135
# Input tokens used: 686
# Output tokens used: 52
# Processing element 84/135
# Input tokens used: 670
# Output tokens used: 93
# Processing element 85/135
# Input tokens used: 668
# Output tokens used: 106
# Processing element 86/135
# Input tokens used: 674
# Output tokens used: 98
# Processing element 87/135
# Input tokens used: 673
# Output tokens used: 87
# Processing element 88/135
# Input tokens used: 683
# Output tokens used: 122
# Processing element 89/135
# Input tokens used: 659
# Output tokens used: 90
# Processing element 90/135
# Input tokens used: 654
# Output tokens used: 65
# Processing element 91/135
# Input tokens used: 676
# Output tokens used: 80
# Processing element 92/135
# Input tokens used: 691
# Output tokens used: 53
# Processing element 93/135
# Input tokens used: 684
# Output tokens used: 59
# Processing element 94/135
# Input tokens used: 661
# Output tokens used: 121
# Processing element 95/135
# Input tokens used: 696
# Output tokens used: 87
# Processing element 96/135
# Input tokens used: 658
# Output tokens used: 77
# Processing element 97/135
# Input tokens used: 655
# Output tokens used: 52
# Processing element 98/135
# Input tokens used: 686
# Output tokens used: 121
# Processing element 99/135
# Input tokens used: 693
# Output tokens used: 52
# Processing element 100/135
# Input tokens used: 664
# Output tokens used: 115
# Processing element 101/135
# Input tokens used: 672
# Output tokens used: 59
# Processing element 102/135
# Input tokens used: 670
# Output tokens used: 98
# Processing element 103/135
# Input tokens used: 659
# Output tokens used: 67
# Processing element 104/135
# Input tokens used: 667
# Output tokens used: 51
# Processing element 105/135
# Input tokens used: 674
# Output tokens used: 51
# Processing element 106/135
# Input tokens used: 666
# Output tokens used: 98
# Processing element 107/135
# Input tokens used: 675
# Output tokens used: 96
# Processing element 108/135
# Input tokens used: 670
# Output tokens used: 128
# Processing element 109/135
# Input tokens used: 669
# Output tokens used: 53
# Processing element 110/135
# Input tokens used: 659
# Output tokens used: 61
# Processing element 111/135
# Input tokens used: 659
# Output tokens used: 52
# Processing element 112/135
# Input tokens used: 652
# Output tokens used: 87
# Processing element 113/135
# Input tokens used: 644
# Output tokens used: 52
# Processing element 114/135
# Input tokens used: 651
# Output tokens used: 82
# Processing element 115/135
# Input tokens used: 647
# Output tokens used: 117
# Processing element 116/135
# Input tokens used: 647
# Output tokens used: 87
# Processing element 117/135
# Input tokens used: 658
# Output tokens used: 55
# Processing element 118/135
# Input tokens used: 674
# Output tokens used: 55
# Processing element 119/135
# Input tokens used: 685
# Output tokens used: 93
# Processing element 120/135
# Input tokens used: 674
# Output tokens used: 55
# Processing element 121/135
# Input tokens used: 651
# Output tokens used: 64
# Processing element 122/135
# Input tokens used: 656
# Output tokens used: 52
# Processing element 123/135
# Input tokens used: 663
# Output tokens used: 55
# Processing element 124/135
# Input tokens used: 648
# Output tokens used: 52
# Processing element 125/135
# Input tokens used: 650
# Output tokens used: 61
# Processing element 126/135
# Input tokens used: 654
# Output tokens used: 86
# Processing element 127/135
# Input tokens used: 647
# Output tokens used: 52
# Processing element 128/135
# Input tokens used: 646
# Output tokens used: 53
# Processing element 129/135
# Input tokens used: 648
# Output tokens used: 64
# Processing element 130/135
# Input tokens used: 651
# Output tokens used: 56
# Processing element 131/135
# Input tokens used: 645
# Output tokens used: 66
# Processing element 132/135
# Input tokens used: 639
# Output tokens used: 48
# Processing element 133/135
# Input tokens used: 649
# Output tokens used: 64
# Processing element 134/135
# Input tokens used: 661
# Output tokens used: 52
# Processing element 135/135
# Input tokens used: 649
# Output tokens used: 53

# %%
classification = classification_response[0]
extended_categories = classification_response[1]

len(extended_categories)
categories_diff = len(extended_categories) - len(meta_categories)
print(f"{categories_diff} new meta-categories generated during classification!")
# Out:
# 1 new meta-categories generated during classification!

# %% [markdown]
# ### Analyzing
#
# With these classifications of the frameworks, we can now see if we can find any patterns using these meta-categories.
#
# Let us first add a new column to our dataframe. For this, we need a mapping from frameworks to meta-categories.

# %%
category_mapping = {}

for cat in classification:
    cat_title = cat[0].title
    cat_prob = cat[1].probabilities  # This is a list of ProbabilityScore objects
    # Find the ProbabilityScore object with the highest probability
    max_prob_obj = max(cat_prob, key=lambda p: p.probability)
    category_mapping[cat_title] = max_prob_obj.category

# Now, map the old column to the new one
# theory_df_merged['classification_meta_framework_category'] = theory_df_merged['theory_highest_prob_gpt-4.1-mini'].map(category_mapping.get)
theory_df_merged['classification_meta_framework_category'] = theory_df_merged['theory_classifications_gpt-4.1-mini'].map(lambda r: [category_mapping.get(el) for el in r])

# %%
theory_df_merged['theory_classifications_gpt-4.1-mini']
# Out:
# 0      [Resource Framing, Knowledge Integration Frame...
# 1                      [Mathematical Modeling Framework]
# 2      [Measurement Theory Framework, Formative Asses...
# 3      [Modeling, Structure Mapping, and Conceptual B...
# 4                       [Formative Assessment Framework]
#                              ...
# 584          [Philosophy & History of Science Framework]
# 585                                [Commognitive Theory]
# 586    [Model of Educational Reconstruction (MER), Co...
# 587    [Mental Models Framework, Mathematical Modelin...
# 588    [Sociocultural Learning Theory, Metacognition ...
# Name: theory_classifications_gpt-4.1-mini, Length: 589, dtype: object

# %%
reversed_map = {}

for key,val in category_mapping.items():
    reversed_map.setdefault(val, []).append(key)

with open(create_timestamped_path("./theory_data/category_map.json"), "w") as fp:
    json.dump(reversed_map, fp)


# pd.DataFrame({"Meta Category":reversed_map.keys(), "Frameworks": reversed_map.values()})

# %% [markdown]
# Using this, we can now plot the development over time.

# %%
import plotly.express as px
from LLM_classifier.utils import create_timestamped_path
import pandas as pd # It's good practice to import pandas

# Ensure the relevant columns exist
category_col = "classification_meta_framework_category"
year_col = 'article_year'

# 1. Start with the original DataFrame and drop rows with NaN values
plot_df = theory_df_merged.dropna(subset=[category_col, year_col]).copy()

# 2. Filter out rows where the category_col list is empty.
#    The condition is changed to > 0 to KEEP rows with non-empty lists.
is_not_empty_mask = plot_df[category_col].str.len() > 0
plot_df = plot_df[is_not_empty_mask].copy()

print(f"Number of sections: {len(plot_df)}")

# 3. THE KEY STEP: Explode the DataFrame.
#    This creates a new row for each category in the list, repeating the year.
plot_df = plot_df.explode(category_col)

print(f"Number of exploded entries: {len(plot_df)}")

# 4. Convert year to integer
plot_df[year_col] = plot_df[year_col].astype(int)

# 5. Get category counts. This groupby now works correctly on the exploded data.
category_counts = (
    plot_df.groupby([year_col, category_col])
    .size()
    .reset_index(name='count')
)

# 6. Create interactive plot (This part remains the same)
fig = px.line(
    category_counts,
    x=year_col,
    y='count',
    color=category_col,
    markers=True,
    labels={
        year_col: 'Year',
        'count': 'Number of Sections',
        category_col: 'Theory Category'
    },
    title='Theory Category Counts by Year (Exploded Data)'
)

fig.update_layout(
    legend_title_text='Theory Category',
    legend=dict(
        orientation="v",
        yanchor="top",
        y=1,
        xanchor="left",
        x=1.01
    ),
    width=1000,
    height=500
)

# output_path = create_timestamped_path("plotly_theory_year_exploded.html")
# fig.write_html(output_path)
# print(f"Plot saved to: {output_path}")
fig.show()
# Out:
# Number of sections: 582
# Number of exploded entries: 1310
