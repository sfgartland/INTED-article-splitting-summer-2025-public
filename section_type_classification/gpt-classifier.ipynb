# %% [markdown]
# #### Note
# This classifier could be re-implemented easily using the new LLM_classifier framework used for theory and methods identification.
#
# This notebook with legacy-code is only included because it is what we used to actually generate the classifications

# %% [markdown]
# # LLM (GPT) section type classification

# %% [markdown]
# ## Imports and general setup

# %%
import pandas as pd

from openai import OpenAI
import json
import datetime

import sys
import os

# In a Jupyter notebook, __file__ is not defined. Use the current working directory instead.
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..")))


from section_classification.gpt_classification_helpers import (
    prepare_articles_dataframe,
    expand_classified_articles_dataframe,
    classify_articles_with_validation,
)
from python_code.helpers import recombine_chunks, apply_in_chunks, safe_load_env_variable

# %%
df = pd.read_pickle("./data/processed_embeddings_light_20250702_142821.pkl")
df.keys()

# %%
prepared_df = prepare_articles_dataframe(df)

# %%
# The following block dynamically inserts categories and their descriptions loaded from a JSON file.
with open("./classifiers_LLM_generated.json", "r") as f:
    categories_json = json.load(f)

category_lines = []
for cat in categories_json:
    category_lines.append(f"- {cat['category']}: {cat['description']}")
    # category_lines.append(f"- {cat['category']}")

categories_prompt = "\n".join(category_lines)

# %% [markdown]
# #### Initialize OpenAI

# %%
api_key = safe_load_env_variable("OPENAI_API_KEY", "..")
client = OpenAI(api_key)

# %% [markdown]
# ## Categorize whole articles

# %%
whole_article_system_prompt = f"""
You are a expert in the field of physics education research. 
You are given a whole article of a physics education research article. You will be given the article formatted as markdown with each section marked by a subheading.
Your task is to classify each section into one of the following categories:

{categories_prompt}
 
Each article can match multiple categories. Consider both title, content and the context of the section to make the best classification.
 

Return an array of all the sections with the fields
- section: the section title
- classifications: the classifications for the section
- probabilities: the probability distribution for the classifications

Generate a probability distribution for the classification of each section. After generating all of the distribution review them and refine 
them if need be.
Return  the probability distribution for each classification in the json field "probabilities". Make sure that these probabilties reflect the ambiguities of the data.
Return the classifications as a array of strings in the json field "classifications". 
"""

# %%
model = "gpt-4.1-mini"   # Update to change model
data: pd.DataFrame = prepared_df


def classify(data):
    res = classify_articles_with_validation(
        data, system_prompt=whole_article_system_prompt, model=model, client=client, verbose=True)
    print(res)
    return res

# Use the chunking helper function in case we encounter a failure
classified_df = apply_in_chunks(data, classify, chunk_size=50,
                                output_dir="classified_sections")
# Out:
# Processing 1222 rows in chunks of 50 for a total of 25 chunks...
# Processing chunk 0-49...
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation', 'Literature Review/Reanalysis'], 'probabilities': {'Introduction / Motivation': 0.75, 'Literature Review/Reanalysis': 0.2, 'Theoretical Framework': 0.03, 'Methods': 0.01, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.01}}, {'section': 'CU IMPLEMENTATION', 'classifications': ['Methods'], 'probabilities': {'Methods': 0.9, 'Introduction / Motivation': 0.05, 'Results': 0.03, 'Discussion': 0.01, 'Theoretical Framework': 0.01}}, {'section': 'DATA AND RESULTS', 'classifications': ['Results'], 'probabilities': {'Results': 0.95, 'Discussion': 0.03, 'Methods': 0.02}}, {'section': 'DISCUSSION', 'classifications': ['Discussion', 'Theoretical Framework'], 'probabilities': {'Discussion': 0.8, 'Theoretical Framework': 0.15, 'Implications': 0.04, 'Results': 0.01}}, {'section': 'CONCLUDING REMARKS', 'classifications': ['Conclusion / Summary', 'Implications'], 'probabilities': {'Conclusion / Summary': 0.7, 'Implications': 0.25, 'Discussion': 0.05}}]}
# Processed article 10.1103/PhysRevSTPER.1.010101: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation'], 'probabilities': {'Introduction / Motivation': 0.95, 'Literature Review/Reanalysis': 0.03, 'Theoretical Framework': 0.01, 'Methods': 0.01, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'METHOD', 'classifications': ['Methods'], 'probabilities': {'Methods': 0.97, 'Introduction / Motivation': 0.01, 'Results': 0.01, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.01, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'DEMONSTRATION-BASED INTERVIEW TASKS', 'classifications': ['Methods'], 'probabilities': {'Methods': 0.9, 'Results': 0.05, 'Introduction / Motivation': 0.02, 'Theoretical Framework': 0.01, 'Discussion': 0.01, 'Literature Review/Reanalysis': 0.01, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'STUDENT RESPONSE TO THE INTERVIEW QUESTIONS', 'classifications': ['Results', 'Discussion'], 'probabilities': {'Results': 0.7, 'Discussion': 0.25, 'Methods': 0.02, 'Introduction / Motivation': 0.01, 'Literature Review/Reanalysis': 0.01, 'Implications': 0.0, 'Theoretical Framework': 0.0, 'Conclusion / Summary': 0.01, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'RESPONSE TO MULTIPLE-CHOICE AND FREE-RESPONSE QUESTIONS', 'classifications': ['Results', 'Discussion'], 'probabilities': {'Results': 0.75, 'Discussion': 0.2, 'Methods': 0.02, 'Introduction / Motivation': 0.01, 'Implications': 0.01, 'Literature Review/Reanalysis': 0.01, 'Conclusion / Summary': 0.0, 'Theoretical Framework': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'SUMMARY', 'classifications': ['Conclusion / Summary', 'Implications'], 'probabilities': {'Conclusion / Summary': 0.8, 'Implications': 0.15, 'Discussion': 0.03, 'Introduction / Motivation': 0.01, 'Limitations': 0.01, 'Methods': 0.0, 'Results': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.1.010102: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation', 'Theoretical Framework', 'Literature Review/Reanalysis', 'Methods'], 'probabilities': {'Introduction / Motivation': 0.55, 'Theoretical Framework': 0.2, 'Literature Review/Reanalysis': 0.15, 'Methods': 0.1, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'EXPERIMENTAL DESIGN', 'classifications': ['Methods'], 'probabilities': {'Methods': 0.85, 'Introduction / Motivation': 0.1, 'Limitations': 0.03, 'Ethical Considerations': 0.02, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'RESULTS', 'classifications': ['Results', 'Discussion', 'Implications', 'Conclusion / Summary'], 'probabilities': {'Results': 0.6, 'Discussion': 0.25, 'Implications': 0.1, 'Conclusion / Summary': 0.05, 'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.1.010103: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation'], 'probabilities': {'Introduction / Motivation': 0.95, 'Theoretical Framework': 0.03, 'Literature Review/Reanalysis': 0.02, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'METHODS', 'classifications': ['Methods'], 'probabilities': {'Introduction / Motivation': 0.05, 'Theoretical Framework': 0.05, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.9, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'DATA AND RESULTS', 'classifications': ['Results', 'Discussion'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.8, 'Discussion': 0.2, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'DISCUSSION AND CONCLUSION', 'classifications': ['Discussion', 'Conclusion / Summary', 'Limitations', 'Implications'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.55, 'Implications': 0.15, 'Conclusion / Summary': 0.2, 'Limitations': 0.1, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.1.010104: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation'], 'probabilities': {'Introduction / Motivation': 0.95, 'Theoretical Framework': 0.02, 'Literature Review/Reanalysis': 0.02, 'Methods': 0.01, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'POTENTIAL REQUIREMENTS AND NEEDS', 'classifications': ['Methods'], 'probabilities': {'Introduction / Motivation': 0.1, 'Theoretical Framework': 0.05, 'Literature Review/Reanalysis': 0.05, 'Methods': 0.75, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.05, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'BENEFITS OF DVD VIDEO RECORDERS', 'classifications': ['Methods', 'Implications'], 'probabilities': {'Introduction / Motivation': 0.05, 'Theoretical Framework': 0.05, 'Literature Review/Reanalysis': 0.05, 'Methods': 0.7, 'Results': 0.0, 'Discussion': 0.05, 'Implications': 0.1, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'SYSTEM SETUP CONSIDERATIONS', 'classifications': ['Methods'], 'probabilities': {'Introduction / Motivation': 0.05, 'Theoretical Framework': 0.05, 'Literature Review/Reanalysis': 0.05, 'Methods': 0.8, 'Results': 0.0, 'Discussion': 0.05, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'COMPONENT LAYOUT', 'classifications': ['Methods'], 'probabilities': {'Introduction / Motivation': 0.05, 'Theoretical Framework': 0.05, 'Literature Review/Reanalysis': 0.05, 'Methods': 0.8, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'HARDWARE CONSIDERATIONS', 'classifications': ['Methods'], 'probabilities': {'Introduction / Motivation': 0.05, 'Theoretical Framework': 0.05, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.85, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'GENERAL CONCLUSIONS', 'classifications': ['Conclusion / Summary', 'Implications'], 'probabilities': {'Introduction / Motivation': 0.01, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.05, 'Results': 0.0, 'Discussion': 0.1, 'Implications': 0.5, 'Conclusion / Summary': 0.3, 'Limitations': 0.03, 'Ethical Considerations': 0.01, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.1.010105: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation', 'Literature Review/Reanalysis'], 'probabilities': {'Introduction / Motivation': 0.75, 'Literature Review/Reanalysis': 0.2, 'Theoretical Framework': 0.03, 'Methods': 0.01, 'Results': 0.01, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'DESIGN', 'classifications': ['Methods'], 'probabilities': {'Methods': 0.9, 'Introduction / Motivation': 0.05, 'Theoretical Framework': 0.03, 'Literature Review/Reanalysis': 0.01, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'SCORING', 'classifications': ['Methods', 'Results'], 'probabilities': {'Methods': 0.65, 'Results': 0.3, 'Discussion': 0.04, 'Introduction / Motivation': 0.01, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'ADMINISTRATION', 'classifications': ['Methods'], 'probabilities': {'Methods': 0.95, 'Introduction / Motivation': 0.03, 'Discussion': 0.02, 'Results': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'VALIDITY AND RELIABILITY', 'classifications': ['Methods', 'Discussion'], 'probabilities': {'Methods': 0.7, 'Discussion': 0.25, 'Introduction / Motivation': 0.02, 'Results': 0.02, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'APPLICATIONS', 'classifications': ['Implications', 'Results'], 'probabilities': {'Implications': 0.75, 'Results': 0.2, 'Discussion': 0.04, 'Methods': 0.01, 'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'CONCLUSIONS, CAVEATS, AND FUTURE WORK', 'classifications': ['Conclusion / Summary', 'Limitations', 'Implications'], 'probabilities': {'Conclusion / Summary': 0.65, 'Limitations': 0.2, 'Implications': 0.15, 'Discussion': 0.0, 'Methods': 0.0, 'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Results': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.2.010101: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation'], 'probabilities': {'Introduction / Motivation': 0.95, 'Literature Review/Reanalysis': 0.05, 'Theoretical Framework': 0.0, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'STUDY: SEPARATING THE EFFECTS OF CONTENT AND INSTRUCTION', 'classifications': ['Methods', 'Results'], 'probabilities': {'Methods': 0.6, 'Results': 0.4, 'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'STUDY: ANALYSIS OF COURSE ENVIRONMENTS', 'classifications': ['Methods', 'Results'], 'probabilities': {'Methods': 0.7, 'Results': 0.3, 'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'DISCUSSION', 'classifications': ['Discussion'], 'probabilities': {'Discussion': 0.95, 'Implications': 0.05, 'Results': 0.0, 'Methods': 0.0, 'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'CONCLUSION', 'classifications': ['Conclusion / Summary', 'Implications'], 'probabilities': {'Conclusion / Summary': 0.7, 'Implications': 0.3, 'Discussion': 0.0, 'Results': 0.0, 'Methods': 0.0, 'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.2.010102: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation'], 'probabilities': {'Introduction / Motivation': 0.95, 'Theoretical Framework': 0.02, 'Literature Review/Reanalysis': 0.02, 'Methods': 0.01, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'THEORETICAL FRAME: A MODEL OF COGNITION', 'classifications': ['Theoretical Framework'], 'probabilities': {'Theoretical Framework': 0.9, 'Literature Review/Reanalysis': 0.07, 'Introduction / Motivation': 0.03, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'STUDENT MODEL SPACE: A MATHEMATICAL REPRESENTATION', 'classifications': ['Theoretical Framework', 'Methods'], 'probabilities': {'Theoretical Framework': 0.6, 'Methods': 0.35, 'Results': 0.05, 'Introduction / Motivation': 0.0, 'Literature Review/Reanalysis': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'ANALYZING STUDENT MODELS WITH MULTIPLE-CHOICE INSTRUMENTS', 'classifications': ['Methods', 'Results'], 'probabilities': {'Methods': 0.7, 'Results': 0.25, 'Discussion': 0.05, 'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'MODEL ANALYSIS OF FCI DATA', 'classifications': ['Results', 'Discussion'], 'probabilities': {'Results': 0.8, 'Discussion': 0.15, 'Methods': 0.05, 'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'COMPARING MODEL ANALYSIS AND FACTOR ANALYSIS', 'classifications': ['Discussion'], 'probabilities': {'Discussion': 0.85, 'Results': 0.1, 'Introduction / Motivation': 0.05, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'SUMMARY AND DISCUSSION', 'classifications': ['Conclusion / Summary', 'Discussion', 'Implications'], 'probabilities': {'Conclusion / Summary': 0.7, 'Discussion': 0.2, 'Implications': 0.1, 'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.2.010103: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation'], 'probabilities': {'Introduction / Motivation': 0.95, 'Theoretical Framework': 0.03, 'Literature Review/Reanalysis': 0.01, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.01, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'REVIEW OF THE LITERATURE', 'classifications': ['Literature Review/Reanalysis'], 'probabilities': {'Introduction / Motivation': 0.05, 'Theoretical Framework': 0.1, 'Literature Review/Reanalysis': 0.8, 'Methods': 0.02, 'Results': 0.0, 'Discussion': 0.02, 'Implications': 0.0, 'Conclusion / Summary': 0.01, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'METHOD', 'classifications': ['Methods'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.05, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.9, 'Results': 0.01, 'Discussion': 0.01, 'Implications': 0.0, 'Conclusion / Summary': 0.01, 'Limitations': 0.01, 'Ethical Considerations': 0.01, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'RESULTS', 'classifications': ['Results', 'Discussion'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.01, 'Methods': 0.01, 'Results': 0.85, 'Discussion': 0.1, 'Implications': 0.0, 'Conclusion / Summary': 0.01, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.02, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'DISCUSSION', 'classifications': ['Discussion', 'Implications'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.01, 'Methods': 0.0, 'Results': 0.03, 'Discussion': 0.8, 'Implications': 0.15, 'Conclusion / Summary': 0.01, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'FUTURE RESEARCH', 'classifications': ['Implications', 'Conclusion / Summary'], 'probabilities': {'Introduction / Motivation': 0.01, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.1, 'Implications': 0.7, 'Conclusion / Summary': 0.19, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.2.010104: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation'], 'probabilities': {'Introduction / Motivation': 0.9, 'Theoretical Framework': 0.05, 'Literature Review/Reanalysis': 0.03, 'Methods': 0.01, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.01}}, {'section': 'BACKGROUND AND VALIDITY OF BEMA', 'classifications': ['Theoretical Framework', 'Methods'], 'probabilities': {'Introduction / Motivation': 0.05, 'Theoretical Framework': 0.6, 'Literature Review/Reanalysis': 0.05, 'Methods': 0.25, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.05, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'STATISTICAL EVALUATION OF BEMA', 'classifications': ['Methods', 'Results'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.05, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.7, 'Results': 0.25, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'SUMMARY', 'classifications': ['Conclusion / Summary'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.1, 'Discussion': 0.05, 'Implications': 0.05, 'Conclusion / Summary': 0.8, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.2.010105: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation', 'Literature Review/Reanalysis'], 'probabilities': {'Introduction / Motivation': 0.7, 'Literoretical Framework': 0.05, 'Literature Review/Reanalysis': 0.25, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'METHODS', 'classifications': ['Methods'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 1.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'DATA AND ANALYSIS', 'classifications': ['Results', 'Discussion'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.05, 'Methods': 0.0, 'Results': 0.85, 'Discussion': 0.1, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'DISCUSSION', 'classifications': ['Discussion', 'Implications'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.7, 'Implications': 0.3, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'CONCLUSIONS', 'classifications': ['Conclusion / Summary', 'Implications'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.4, 'Conclusion / Summary': 0.6, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.2.010106: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation'], 'probabilities': {'Introduction / Motivation': 0.95, 'Literature Review/Reanalysis': 0.05, 'Theoretical Framework': 0.0, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'THEORETICAL FRAMES', 'classifications': ['Theoretical Framework'], 'probabilities': {'Theoretical Framework': 0.9, 'Literature Review/Reanalysis': 0.1, 'Introduction / Motivation': 0.0, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'RESEARCH QUESTIONS', 'classifications': ['Introduction / Motivation'], 'probabilities': {'Introduction / Motivation': 0.8, 'Methods': 0.1, 'Theoretical Framework': 0.1, 'Literature Review/Reanalysis': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'COURSE DESCRIPTION', 'classifications': ['Methods'], 'probabilities': {'Methods': 0.95, 'Introduction / Motivation': 0.05, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'PART I: TEACHING WITH ANALOGIES', 'classifications': ['Methods', 'Results'], 'probabilities': {'Methods': 0.7, 'Results': 0.3, 'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'PART II: REPRESENTATION AND ANALOGY', 'classifications': ['Methods', 'Results'], 'probabilities': {'Methods': 0.65, 'Results': 0.35, 'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'DISCUSSION', 'classifications': ['Discussion', 'Implications'], 'probabilities': {'Discussion': 0.8, 'Implications': 0.2, 'Conclusion / Summary': 0.0, 'Results': 0.0, 'Methods': 0.0, 'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'CONCLUSION', 'classifications': ['Conclusion / Summary', 'Implications'], 'probabilities': {'Conclusion / Summary': 0.85, 'Implications': 0.15, 'Discussion': 0.0, 'Methods': 0.0, 'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Results': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.2.020101: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation'], 'probabilities': {'Introduction / Motivation': 0.95, 'Literature Review/Reanalysis': 0.03, 'Theoretical Framework': 0.01, 'Methods': 0.005, 'Results': 0.005, 'Discussion': 0, 'Implications': 0, 'Conclusion / Summary': 0, 'Limitations': 0, 'Ethical Considerations': 0, 'Appendix / Supplementary Material': 0, 'Acknowledgments': 0, 'References': 0}}, {'section': 'RELIABILITY', 'classifications': ['Methods', 'Results'], 'probabilities': {'Methods': 0.6, 'Results': 0.35, 'Introduction / Motivation': 0.025, 'Discussion': 0.015, 'Theoretical Framework': 0.005, 'Implications': 0, 'Literature Review/Reanalysis': 0, 'Conclusion / Summary': 0, 'Limitations': 0, 'Ethical Considerations': 0, 'Appendix / Supplementary Material': 0, 'Acknowledgments': 0, 'References': 0}}, {'section': 'VALIDITY', 'classifications': ['Methods', 'Results', 'Discussion'], 'probabilities': {'Methods': 0.5, 'Results': 0.35, 'Discussion': 0.1, 'Introduction / Motivation': 0.025, 'Implications': 0.01, 'Literature Review/Reanalysis': 0.005, 'Theoretical Framework': 0.005, 'Conclusion / Summary': 0, 'Limitations': 0, 'Ethical Considerations': 0, 'Appendix / Supplementary Material': 0, 'Acknowledgments': 0, 'References': 0}}, {'section': 'DISCUSSION', 'classifications': ['Discussion', 'Implications'], 'probabilities': {'Discussion': 0.85, 'Implications': 0.15, 'Results': 0, 'Methods': 0, 'Conclusion / Summary': 0, 'Introduction / Motivation': 0, 'Theoretical Framework': 0, 'Literature Review/Reanalysis': 0, 'Limitations': 0, 'Ethical Considerations': 0, 'Appendix / Supplementary Material': 0, 'Acknowledgments': 0, 'References': 0}}, {'section': 'CONCLUSIONS', 'classifications': ['Conclusion / Summary', 'Implications'], 'probabilities': {'Conclusion / Summary': 0.85, 'Implications': 0.15, 'Discussion': 0, 'Results': 0, 'Methods': 0, 'Introduction / Motivation': 0, 'Theoretical Framework': 0, 'Literature Review/Reanalysis': 0, 'Limitations': 0, 'Ethical Considerations': 0, 'Appendix / Supplementary Material': 0, 'Acknowledgments': 0, 'References': 0}}]}
# Processed article 10.1103/PhysRevSTPER.2.020102: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation'], 'probabilities': {'Introduction / Motivation': 0.95, 'Theoretical Framework': 0.03, 'Literature Review/Reanalysis': 0.02, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'DEFINING SCIENTIFIC ABILITIES', 'classifications': ['Theoretical Framework'], 'probabilities': {'Introduction / Motivation': 0.1, 'Theoretical Framework': 0.85, 'Literature Review/Reanalysis': 0.05, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'FINE-TUNING SCIENTIFIC ABILITIES AND DEVISING RUBRICS TO ASSESS THEM', 'classifications': ['Methods'], 'probabilities': {'Introduction / Motivation': 0.05, 'Theoretical Framework': 0.15, 'Literature Review/Reanalysis': 0.1, 'Methods': 0.7, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'DO STUDENTS DEVELOP SCIENTIFIC ABILITIES?', 'classifications': ['Results', 'Discussion'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.1, 'Results': 0.7, 'Discussion': 0.2, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'SUMMARY', 'classifications': ['Conclusion / Summary', 'Implications'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.4, 'Conclusion / Summary': 0.6, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.2.020103: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation'], 'probabilities': {'Introduction / Motivation': 0.95, 'Theoretical Framework': 0.03, 'Literature Review/Reanalysis': 0.02, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'STUDENT DEMOGRAPHICS AND COURSE DESIGN', 'classifications': ['Methods'], 'probabilities': {'Introduction / Motivation': 0.1, 'Theoretical Framework': 0.1, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.75, 'Results': 0.0, 'Discussion': 0.05, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'TEACHING PROBABILITY', 'classifications': ['Methods'], 'probabilities': {'Introduction / Motivation': 0.05, 'Theoretical Framework': 0.1, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.8, 'Results': 0.05, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'STUDENT UNDERSTANDING OF PROBABILITY', 'classifications': ['Results'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.05, 'Methods': 0.1, 'Results': 0.8, 'Discussion': 0.05, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'DISCUSSION OF RESEARCH AND INSTRUCTION', 'classifications': ['Discussion'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.1, 'Discussion': 0.9, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.2.020104: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation'], 'probabilities': {'Introduction / Motivation': 0.9, 'Theoretical Framework': 0.05, 'Literature Review/Reanalysis': 0.02, 'Methods': 0.01, 'Results': 0.0, 'Discussion': 0.01, 'Implications': 0.0, 'Conclusion / Summary': 0.01, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'LAYING THE FOUNDATION FOR THE RESOURCE GRAPH REPRESENTATION', 'classifications': ['Theoretical Framework'], 'probabilities': {'Introduction / Motivation': 0.05, 'Theoretical Framework': 0.9, 'Literature Review/Reanalysis': 0.04, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.01, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'REPRESENTING COORDINATION CLASSES AS RESOURCE GRAPHS', 'classifications': ['Theoretical Framework', 'Methods'], 'probabilities': {'Introduction / Motivation': 0.02, 'Theoretical Framework': 0.7, 'Literature Review/Reanalysis': 0.05, 'Methods': 0.23, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'DESCRIBING CONCEPTUAL CHANGE USING RESOURCE GRAPHS', 'classifications': ['Results', 'Discussion'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.05, 'Literature Review/Reanalysis': 0.1, 'Methods': 0.0, 'Results': 0.65, 'Discussion': 0.2, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'APPLYING RESOURCE GRAPHS TO OTHER FORMS OF CONCEPTUAL CHANGE', 'classifications': ['Results', 'Implications', 'Discussion'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.05, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.5, 'Discussion': 0.25, 'Implications': 0.2, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'SUMMARY', 'classifications': ['Conclusion / Summary', 'Discussion', 'Implications'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.3, 'Implications': 0.2, 'Conclusion / Summary': 0.5, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.2.020105: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation'], 'probabilities': {'Introduction / Motivation': 0.95, 'Theoretical Framework': 0.03, 'Literature Review/Reanalysis': 0.02, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'THE MODEL', 'classifications': ['Theoretical Framework', 'Methods'], 'probabilities': {'Introduction / Motivation': 0.2, 'Theoretical Framework': 0.65, 'Literature Review/Reanalysis': 0.05, 'Methods': 0.1, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'THE STUDY', 'classifications': ['Methods'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.95, 'Results': 0.02, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.01, 'Limitations': 0.02, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'ANALYSIS AND RESULTS', 'classifications': ['Results', 'Discussion'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.05, 'Methods': 0.02, 'Results': 0.85, 'Discussion': 0.1, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.02, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'DISCUSSION', 'classifications': ['Discussion', 'Implications'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.75, 'Implications': 0.25, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.2.020106: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation'], 'probabilities': {'Introduction / Motivation': 0.95, 'Theoretical Framework': 0.03, 'Literature Review/Reanalysis': 0.02, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'COORDINATION CLASS CONSTRUCT', 'classifications': ['Theoretical Framework'], 'probabilities': {'Introduction / Motivation': 0.05, 'Theoretical Framework': 0.9, 'Literature Review/Reanalysis': 0.05, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'EXPERIMENT', 'classifications': ['Methods', 'Results', 'Discussion'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.5, 'Results': 0.3, 'Discussion': 0.2, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'CONCLUSION', 'classifications': ['Conclusion / Summary', 'Implications'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.1, 'Implications': 0.4, 'Conclusion / Summary': 0.5, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.2.020107: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation'], 'probabilities': {'Introduction / Motivation': 0.95, 'Theoretical Framework': 0.02, 'Literature Review/Reanalysis': 0.01, 'Methods': 0.01, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.01, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'THEORETICAL BACKGROUND', 'classifications': ['Literature Review/Reanalysis', 'Theoretical Framework'], 'probabilities': {'Introduction / Motivation': 0.05, 'Theoretical Framework': 0.6, 'Literature Review/Reanalysis': 0.35, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'CONTEXT FOR RESEARCH', 'classifications': ['Methods'], 'probabilities': {'Introduction / Motivation': 0.05, 'Theoretical Framework': 0.05, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.9, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'DATA SOURCE', 'classifications': ['Methods'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.95, 'Results': 0.05, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'METHOD', 'classifications': ['Methods'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.98, 'Results': 0.02, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'RESULTS', 'classifications': ['Results'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.95, 'Discussion': 0.05, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'SUMMARY', 'classifications': ['Conclusion / Summary'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.05, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.95, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'DISCUSSION', 'classifications': ['Discussion', 'Implications'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.7, 'Implications': 0.3, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'QUESTIONS FOR FUTURE RESEARCH', 'classifications': ['Implications'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.95, 'Conclusion / Summary': 0.05, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.2.020108: ✓
# ...
# Processed article 10.1103/PhysRevSTPER.8.020104: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation', 'Theoretical Framework'], 'probabilities': {'Introduction / Motivation': 0.75, 'Theoretical Framework': 0.2, 'Literature Review/Reanalysis': 0.03, 'Methods': 0.01, 'Results': 0.0, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'COLLECTION OF DATA', 'classifications': ['Methods'], 'probabilities': {'Introduction / Motivation': 0.05, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.9, 'Results': 0.04, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.01, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'EXPLORATORY FACTOR ANALYSIS', 'classifications': ['Results', 'Discussion', 'Theoretical Framework'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.1, 'Literature Review/Reanalysis': 0.03, 'Methods': 0.05, 'Results': 0.75, 'Discussion': 0.07, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'CONCLUSIONS', 'classifications': ['Conclusion / Summary', 'Implications', 'Discussion'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.1, 'Discussion': 0.3, 'Implications': 0.35, 'Conclusion / Summary': 0.25, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.8.020105: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation'], 'probabilities': {'Introduction / Motivation': 0.95, 'Theoretical Framework': 0.02, 'Literature Review/Reanalysis': 0.01, 'Methods': 0.01, 'Results': 0.005, 'Discussion': 0.005, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'APPROACHES TO IMPLEMENTING COMPUTATION', 'classifications': ['Literature Review/Reanalysis'], 'probabilities': {'Introduction / Motivation': 0.1, 'Theoretical Framework': 0.1, 'Literature Review/Reanalysis': 0.75, 'Methods': 0.03, 'Results': 0.0, 'Discussion': 0.01, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.01, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'DESIGN AND IMPLEMENTATION OF COMPUTATIONAL HOMEWORK', 'classifications': ['Methods'], 'probabilities': {'Introduction / Motivation': 0.05, 'Theoretical Framework': 0.03, 'Literature Review/Reanalysis': 0.05, 'Methods': 0.85, 'Results': 0.01, 'Discussion': 0.01, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'EVALUATING COMPUTATIONAL MODELING SKILLS', 'classifications': ['Results'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.05, 'Methods': 0.1, 'Results': 0.8, 'Discussion': 0.05, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'SYSTEMATICALLY UNFOLDING STUDENTS’ ERRORS', 'classifications': ['Methods', 'Results'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.05, 'Methods': 0.45, 'Results': 0.5, 'Discussion': 0.0, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'FREQUENCY OF ERRORS IN STUDENTS’ PROGRAMS', 'classifications': ['Results', 'Discussion'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.05, 'Methods': 0.05, 'Results': 0.75, 'Discussion': 0.15, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'COMMON ERROR PATTERNS IN STUDENTS’ PROGRAMS', 'classifications': ['Results', 'Discussion'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.05, 'Methods': 0.05, 'Results': 0.75, 'Discussion': 0.15, 'Implications': 0.0, 'Conclusion / Summary': 0.0, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}, {'section': 'CLOSING REMARKS', 'classifications': ['Discussion', 'Implications', 'Conclusion / Summary'], 'probabilities': {'Introduction / Motivation': 0.0, 'Theoretical Framework': 0.0, 'Literature Review/Reanalysis': 0.0, 'Methods': 0.0, 'Results': 0.0, 'Discussion': 0.6, 'Implications': 0.25, 'Conclusion / Summary': 0.15, 'Limitations': 0.0, 'Ethical Considerations': 0.0, 'Appendix / Supplementary Material': 0.0, 'Acknowledgments': 0.0, 'References': 0.0}}]}
# Processed article 10.1103/PhysRevSTPER.8.020106: ✓
# {'sections': [{'section': 'INTRODUCTION', 'classifications': ['Introduction / Motivation'], 'probabilities': {'Introduction / Motivation': 0.9, 'Literature Review/Reanalysis': 0.05, 'Theoretical Framework': 0.03, 'Ethical Considerations': 0.01, 'Methods': 0.01}}, {'section': 'OBJECTIVES OF THE TRANSFORMATION', 'classifications': ['Methods', 'Theoretical Framework'], 'probabilities': {'Methods': 0.6, 'Theoretical Framework': 0.35, 'Introduction / Motivation': 0.05}}, {'section': 'THE TRANSFORMED COURSE', 'classifications': ['Methods'], 'probabilities': {'Methods': 0.95, 'Results': 0.03, 'Discussion': 0.02}}, {'section': 'ASSESSMENT', 'classifications': ['Methods', 'Results', 'Discussion', 'Implications'], 'probabilities': {'Methods': 0.25, 'Results': 0.55, 'Discussion': 0.15, 'Implications': 0.05}}, {'section': 'DISCUSSION AND CONCLUSIONS', 'classifications': ['Discussion', 'Conclusion / Summary', 'Implications', 'Limitations'], 'probabilities': {'Discussion': 0.5, 'Conclusion / Summary': 0.3, 'Implications': 0.15, 'Limitations': 0.05}}]}
# Processed article 10.1103/PhysRevSTPER.8.020107: ✓
#                        article_id  \
# 0   10.1103/PhysRevSTPER.8.010114
# 1   10.1103/PhysRevSTPER.8.010112
# 2   10.1103/PhysRevSTPER.8.010113
# 3   10.1103/PhysRevSTPER.8.010115
# 4   10.1103/PhysRevSTPER.8.010116
# 5   10.1103/PhysRevSTPER.8.010118
# 6   10.1103/PhysRevSTPER.8.010117
# 7   10.1103/PhysRevSTPER.8.010120
# 8   10.1103/PhysRevSTPER.8.010121
# 9   10.1103/PhysRevSTPER.8.010122
# 10  10.1103/PhysRevSTPER.8.010123
# 11  10.1103/PhysRevSTPER.8.010124
# 12  10.1103/PhysRevSTPER.8.010125
# 13  10.1103/PhysRevSTPER.8.010126
# 14  10.1103/PhysRevSTPER.8.020101
# 15  10.1103/PhysRevSTPER.8.020102
# 16  10.1103/PhysRevSTPER.8.023101
# 17  10.1103/PhysRevSTPER.8.020103
# 18  10.1103/PhysRevSTPER.8.020104
# 19  10.1103/PhysRevSTPER.8.020105
# 20  10.1103/PhysRevSTPER.8.020106
# 21  10.1103/PhysRevSTPER.8.020107
#
#                                              sections  \
# 0   [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 1   [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 2   [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 3   [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 4   [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 5   [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 6   [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 7   [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 8   [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 9   [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 10  [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 11  [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 12  [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 13  [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 14  [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 15  [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 16  [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 17  [{'title': 'UNDERSTANDING EQUITY IN EDUCATION ...
# 18  [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 19  [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 20  [{'title': 'INTRODUCTION', 'content': 'I. INTR...
# 21  [{'title': 'INTRODUCTION', 'content': 'I. INTR...
#
#                                      probability_dist  \
# 0   [{'Introduction / Motivation': 0.65, 'Theoreti...
# 1   [{'Introduction / Motivation': 0.95, 'Theoreti...
# 2   [{'Introduction / Motivation': 0.7, 'Literatur...
# 3   [{'Introduction / Motivation': 0.9, 'Theoretic...
# 4   [{'Introduction / Motivation': 0.95, 'Theoreti...
# 5   [{'Introduction / Motivation': 0.95, 'Theoreti...
# 6   [{'Introduction / Motivation': 0.75, 'Theoreti...
# 7   [{'Introduction / Motivation': 0.75, 'Theoreti...
# 8                                                  []
# 9   [{'Introduction / Motivation': 0.7, 'Theoretic...
# 10  [{'Introduction / Motivation': 0.7, 'Literoret...
# 11  [{'Introduction / Motivation': 0.7, 'Literatur...
# 12  [{'Introduction / Motivation': 0.95, 'Methods'...
# 13  [{'Introduction / Motivation': 0.75, 'Literatu...
# 14  [{'Introduction / Motivation': 0.95, 'Literatu...
# 15  [{'Introduction / Motivation': 0.7, 'Literatur...
# 16  [{'Introduction / Motivation': 0.95, 'Theoreti...
# 17                                                 []
# 18  [{'Introduction / Motivation': 0.9, 'Literatur...
# 19  [{'Introduction / Motivation': 0.75, 'Theoreti...
# 20  [{'Introduction / Motivation': 0.95, 'Theoreti...
# 21  [{'Introduction / Motivation': 0.9, 'Literatur...
#
#                                    classification_gpt  \
# 0   [[Introduction / Motivation, Literature Review...
# 1   [[Introduction / Motivation], [Theoretical Fra...
# 2   [[Introduction / Motivation, Literature Review...
# 3   [[Introduction / Motivation], [Theoretical Fra...
# 4   [[Introduction / Motivation], [Theoretical Fra...
# 5   [[Introduction / Motivation], [Methods], [Meth...
# 6   [[Introduction / Motivation, Theoretical Frame...
# 7   [[Introduction / Motivation, Theoretical Frame...
# 8                                                  []
# 9   [[Introduction / Motivation, Theoretical Frame...
# 10  [[Introduction / Motivation, Literature Review...
# 11  [[Introduction / Motivation, Literature Review...
# 12  [[Introduction / Motivation], [Theoretical Fra...
# 13  [[Introduction / Motivation, Literature Review...
# 14  [[Introduction / Motivation], [Methods, Introd...
# 15  [[Introduction / Motivation, Literature Review...
# 16  [[Introduction / Motivation], [Methods], [Resu...
# 17                                                 []
# 18  [[Introduction / Motivation], [Introduction / ...
# 19  [[Introduction / Motivation, Theoretical Frame...
# 20  [[Introduction / Motivation], [Literature Revi...
# 21  [[Introduction / Motivation], [Methods, Theore...
#
#                           classification_highest_prob  failed_validation
# 0   [Introduction / Motivation, Methods, Results, ...              False
# 1   [Introduction / Motivation, Theoretical Framew...              False
# 2   [Introduction / Motivation, Theoretical Framew...              False
# 3   [Introduction / Motivation, Theoretical Framew...              False
# 4   [Introduction / Motivation, Theoretical Framew...              False
# 5   [Introduction / Motivation, Methods, Methods, ...              False
# 6   [Introduction / Motivation, Results, Conclusio...              False
# 7   [Introduction / Motivation, Methods, Methods, ...              False
# 8                                                  []               True
# 9   [Introduction / Motivation, Methods, Methods, ...              False
# 10  [Introduction / Motivation, Methods, Results, ...              False
# 11  [Introduction / Motivation, Literature Review/...              False
# 12  [Introduction / Motivation, Theoretical Framew...              False
# 13  [Introduction / Motivation, Methods, Results, ...              False
# 14  [Introduction / Motivation, Methods, Theoretic...              False
# 15  [Introduction / Motivation, Methods, Results, ...              False
# 16  [Introduction / Motivation, Methods, Results, ...              False
# 17                                                 []               True
# 18  [Introduction / Motivation, Introduction / Mot...              False
# 19  [Introduction / Motivation, Methods, Results, ...              False
# 20  [Introduction / Motivation, Literature Review/...              False
# 21  [Introduction / Motivation, Methods, Methods, ...              False
# Saved chunk to classified_sections\chunk_1200_1221.pkl
# Time estimate: 0.0 seconds remaining
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 16
#       9     return res
#      12 classified_df = apply_in_chunks(data, classify, chunk_size=50,
#      13                                 output_dir="classified_sections")
# ---> 16 expanded_classified_df = expand_classified_articles_dataframe(
#      17     classified_df)
#
# File c:\Users\sfgar\programing\INTED-article-splitting\Severin arbeidsområde\classify_sections\gpt_classification\gpt_classification_helpers.py:171, in expand_classified_articles_dataframe(classified_articles_df)
#     161 """
#     162 Expand a dataframe of classified articles to one row per section.
#     163
#    (...)    168     pd.DataFrame: Expanded dataframe with one row per section
#     169 """
#     170 expanded_rows = []
# --> 171 for _, row in classified_articles_df.iterrows():
#     172     article_id = row['article_id']
#     173     sections = row['sections']
#
# AttributeError: 'NoneType' object has no attribute 'iterrows'

# %%
classified_df = recombine_chunks("classified_sections")

# %% [markdown]
# ## Renaming, reformatting and saving the classifications

# %% [markdown]
# Having run the classifications we are left with one row per article. Since we are primarily interested in specific types of section, we should explode this df to have one row per section.

# %%
expanded_classified_df = expand_classified_articles_dataframe(
    classified_df)

# %%
expanded_classified_df
# Out:
#                                 article_id                      section_title  \
# 0            10.1103/PhysRevSTPER.1.010101                       INTRODUCTION
# 1            10.1103/PhysRevSTPER.1.010101                  CU IMPLEMENTATION
# 2            10.1103/PhysRevSTPER.1.010101                   DATA AND RESULTS
# 3            10.1103/PhysRevSTPER.1.010101                         DISCUSSION
# 4            10.1103/PhysRevSTPER.1.010101                 CONCLUDING REMARKS
# ...                                    ...                                ...
# 7308  10.1103/PhysRevPhysEducRes.19.020109                       INTRODUCTION
# 7309  10.1103/PhysRevPhysEducRes.19.020109                        METHODOLOGY
# 7310  10.1103/PhysRevPhysEducRes.19.020109             RESULTS AND DISCUSSION
# 7311  10.1103/PhysRevPhysEducRes.19.020109  LIMITATIONS AND FUTURE DIRECTIONS
# 7312  10.1103/PhysRevPhysEducRes.19.020109                         CONCLUSION
#
#                                         section_content  \
# 0     I. INTRODUCTION Both popular [bibr:c1] and res...
# 1     II. CU IMPLEMENTATION A. Background and course...
# 2     III. DATA AND RESULTS Data were collected in t...
# 3     IV. DISCUSSION A. Examining the how and why of...
# 4     V. CONCLUDING REMARKS Clearly, it is possible ...
# ...                                                 ...
# 7308  I. INTRODUCTION Gender disparity in the partic...
# 7309  II. METHODOLOGY In this study gender was defin...
# 7310  III. RESULTS AND DISCUSSION Figure [fig:f1] sh...
# 7311  IV. LIMITATIONS AND FUTURE DIRECTIONS This wor...
# 7312  V. CONCLUSION The presence of gender bias in f...
#
#                                        probability_dist  \
# 0     {'Introduction / Motivation': 0.75, 'Literatur...
# 1     {'Methods': 0.9, 'Introduction / Motivation': ...
# 2     {'Results': 0.95, 'Discussion': 0.03, 'Methods...
# 3     {'Discussion': 0.8, 'Theoretical Framework': 0...
# 4     {'Conclusion / Summary': 0.7, 'Implications': ...
# ...                                                 ...
# 7308  {'Introduction / Motivation': 0.7, 'Literature...
# 7309  {'Methods': 1.0, 'Introduction / Motivation': ...
# 7310  {'Results': 0.6, 'Discussion': 0.4, 'Introduct...
# 7311  {'Limitations': 0.65, 'Implications': 0.35, 'I...
# 7312  {'Conclusion / Summary': 1.0, 'Introduction / ...
#
#                                      classification_gpt  \
# 0     [Introduction / Motivation, Literature Review/...
# 1                                             [Methods]
# 2                                             [Results]
# 3                   [Discussion, Theoretical Framework]
# 4                  [Conclusion / Summary, Implications]
# ...                                                 ...
# 7308  [Introduction / Motivation, Literature Review/...
# 7309                                          [Methods]
# 7310                              [Results, Discussion]
# 7311                        [Limitations, Implications]
# 7312                             [Conclusion / Summary]
#
#      classification_highest_prob  failed_validation
# 0      Introduction / Motivation              False
# 1                        Methods              False
# 2                        Results              False
# 3                     Discussion              False
# 4           Conclusion / Summary              False
# ...                          ...                ...
# 7308   Introduction / Motivation              False
# 7309                     Methods              False
# 7310                     Results              False
# 7311                 Limitations              False
# 7312        Conclusion / Summary              False
#
# [7313 rows x 7 columns]

# %% [markdown]
# Now let us make the column names a bit more informative.

# %%
merged_df = df.merge(
    expanded_classified_df,
    how="left",
    left_on=["article_id", "section_title"],
    right_on=["article_id", "section_title"]
)

merged_df.rename(columns={"probability_dist": "probability_dist_gpt-4.1-mini"}, inplace=True)
merged_df.rename(columns={"classification_gpt": "classification_gpt-4.1-mini"}, inplace=True)
merged_df.rename(columns={"classification_highest_prob": "classification_highest_prob_gpt-4.1-mini"}, inplace=True)
merged_df.rename(columns={"failed_validation": "failed_validation_gpt-4.1-mini"}, inplace=True)

# %%
merged_df.drop(columns=["section_title"], inplace=True)

# %%
merged_df.keys()
# Out:
# Index(['section_label', 'article_title', 'section_title_raw', 'article_id',
#        'year', 'content_text', 'relative_position', 'title_embedding',
#        'content_embedding', 'section_content', 'probability_dist_gpt-4.1-mini',
#        'classification_gpt-4.1-mini',
#        'classification_highest_prob_gpt-4.1-mini',
#        'failed_validation_gpt-4.1-mini'],
#       dtype='object')

# %% [markdown]
# Finally, we can save our results!

# %%
timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
merged_df.to_pickle(f"./data/classified_sections_light_gpt-4.1-mini_{timestamp}.pkl")
